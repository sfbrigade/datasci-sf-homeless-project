# %% [markdown]
# Code for San Francisco
#
# # CTA Homelessness data
#
# ## Purpose
#
# The purpose of this notebook is to load and process the sample data. A few features are created. Some plots are made, mostly near the bottom of the notebook.
#
# A DataFrame can be saved with one row per person containing some features (might get used in a Sankey diagram).
#
# ### Requirements
#
# Each sheet from the sample data Excel file was saved out to a CSV with its corresponding name.
#
# - Author: Matt Mollison
# - Date: 2016-10-12

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# # the "1" means: always reload modules marked with "%aimport"
# %autoreload 1

from __future__ import absolute_import, division, print_function
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os, sys
# from tqdm import tqdm
# import warnings

sns.set_context("poster", font_scale=1.0)

# %%
pd.set_option('display.max_columns', 100)

# %%
# Example for adding path
# write code in ../source and add that to runtime path
# src_dir = os.path.join(os.getcwd(), os.pardir, '../source')
# sys.path.append(src_dir)

# Import like so
# # import my_module from the source directory
# %aimport my_module
# from my_module.build_features import remove_invalid_data

# %%
# where the data is stored

matt = 'SampleDataSet-MOSBE&SCz-2012-1001--2016-0531/USE THIS ONE/'
annalie = 'data/c4sf/DATA_CTA/'

datadir = os.path.join(os.getenv('HOME'), annalie)

# %%
def encode_boolean(df, col):
    '''Encode values as booleans.
    If the string is 'Yes', the new value will be True. Otherwise it will be False.
    '''
    df.loc[df[col] == 'Yes', col] = True
    df.loc[df[col] == 'No', col] = False
    df.loc[df[col] == 'Not Applicable - Child', col] = False
    df.loc[df[col].isin(['Client refused',
                         "Client doesn't know",
                         'Data not collected',
                         '',
                         np.nan]), col] = False
    return df

# %%
def encode_unknown(df, col):
    '''Change non-informative values to 'Unknown'.
    '''
    df.loc[df[col].isin(['Client refused',
                         'Refused',
                         "Client doesn't know",
                         'Data not collected']), col] = 'Unknown'
    return df

# %%
sheet = 'Client'

cols = [
    'Personal ID',
    'Race',
    'Ethnicity',
    'Gender',
    'Veteran Status',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_client = pd.read_csv(infile, header=0, index_col=0, usecols=cols, sep=';')
df_client = df_client.dropna(how='all')
df_client.index = df_client.index.astype('int')

# drop people that we don't have demographic information for
df_client = df_client.dropna(how='any', subset=['Race', 'Ethnicity', 'Gender'])

# fill in missing values
df_client['Veteran Status'] = df_client['Veteran Status'].fillna(value='')

# Remove "(HUD) from strings
cols = ['Race', 'Ethnicity', 'Veteran Status']
for col in cols:
    df_client[col] = df_client[col].apply(lambda x: x.replace(' (HUD)', ''))

# put the nans back
df_client.loc[df_client['Veteran Status'] == '', 'Veteran Status'] = np.nan

# and encode booleans
df_client = encode_boolean(df_client, 'Veteran Status')

# Some are unknown
df_client = encode_unknown(df_client, 'Race')
df_client = encode_unknown(df_client, 'Ethnicity')
df_client = encode_unknown(df_client, 'Gender')

# %%
df_client.head()
# Out:
#                                   Race                Ethnicity  Gender  \
# Personal ID
# 173781                           White          Hispanic/Latino  Female
# 173782                           White          Hispanic/Latino    Male
# 173783                           White          Hispanic/Latino  Female
# 173800       Black or African American  Non-Hispanic/Non-Latino  Female
# 173803                           White          Hispanic/Latino  Female
#
#             Veteran Status
# Personal ID
# 173781               False
# 173782               False
# 173783               False
# 173800               False
# 173803               False

# %%
sheet = 'Enrollment'

cols = [
    'Personal ID',
    'Project Entry ID',
    'Client Age at Entry',
    'Last Permanent Zip',
    'Entry Date',
    'Exit Date',
    'Project ID',
    'Housing Status @ Project Start',
    'Living situation before program entry?',
    'Client Location',
    'Household ID',
    'Relationship to HoH',
    'Disabling Condition',
    'Continuously Homeless One Year',
    'Times Homeless Past Three Years',
    'Months Homeless This Time',
    'Chronic Homeless',
    'In Permanent Housing',
    'Residential Move In Date',
    'Domestic Violence Victim',
    'DV When Occurred',
    'DV Currently Fleeing',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_enroll = pd.read_csv(infile, header=0, index_col=0, usecols=cols, sep=';',
                        parse_dates=['Entry Date', 'Exit Date', 'Residential Move In Date'],
                        infer_datetime_format=True)

df_enroll = df_enroll.dropna(axis=0, how='all')
df_enroll.index = df_enroll.index.astype('int')

# drop anyone for whom we don't have age
df_enroll = df_enroll.dropna(subset=['Client Age at Entry'])

# turn these into integers
cols = ['Project Entry ID', 'Client Age at Entry', 'Project ID', 'Household ID']
for col in cols:
    df_enroll[col] = df_enroll[col].astype('int')

# Remove "(HUD) from strings
cols = ['Housing Status @ Project Start',
        'Living situation before program entry?',
        'Disabling Condition',
        'Continuously Homeless One Year',
        'Domestic Violence Victim',
        'DV When Occurred',
        'DV Currently Fleeing',
        ]
for col in cols:
    df_enroll[col] = df_enroll[col].fillna(value='')
    df_enroll[col] = df_enroll[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_enroll.loc[df_enroll[col] == '', col] = np.nan

# encode booleans

# cols = [
#     'Disabling Condition',
#     'Continuously Homeless One Year',
#     'Chronic Homeless',
#     'In Permanent Housing',
#     'Domestic Violence Victim',
#     'DV Currently Fleeing', ]

col = 'Disabling Condition'
df_enroll = encode_boolean(df_enroll, col)

col = 'Continuously Homeless One Year'
df_enroll = encode_boolean(df_enroll, col)

col = 'Chronic Homeless'
df_enroll = encode_boolean(df_enroll, col)

col = 'In Permanent Housing'
df_enroll = encode_boolean(df_enroll, col)

col = 'Domestic Violence Victim'
df_enroll = encode_boolean(df_enroll, col)

col = 'DV Currently Fleeing'
df_enroll = encode_boolean(df_enroll, col)

# %%
# one person has a negative age. make it positive.
col = 'Client Age at Entry'
df_enroll.loc[df_enroll[col] < 0, col] = df_enroll.loc[df_enroll[col] < 0, col] * -1

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 6), sharey=True)

# Not many entries in the system until 2011
df_enroll[['Entry Date']].reset_index().groupby(['Entry Date']).count().plot(ax=ax1);

# plot starting at 2011
df_enroll[['Entry Date']].reset_index().groupby(['Entry Date']).count().ix['2011':].plot(ax=ax2);

ax1.set(ylabel='Number of enrollments',
        title='All time',
        );

ax2.set(ylabel='Number of enrollments',
        title='From 2011',
        );

ax1.legend(['Count'], loc='best');
ax2.legend(['Count'], loc='best');

fig.suptitle('Enrollments by day');

# %%
sheet = 'Disability'

cols = [
    'Personal ID',
    'Disability Type',
    'Receiving Services For',
    'Disabilities ID',
    'Project Entry ID',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_disability = pd.read_csv(infile, header=0, index_col=0, usecols=cols, sep=',')
df_disability = df_disability.dropna(axis=0, how='all')
# df_disability.index = df_disability.index.astype('int') # TypeError: Setting dtype to anything other than float64 or object is not supported

# turn these into integers
cols = ['Disabilities ID', 'Project Entry ID']
for col in cols:
    df_disability[col] = df_disability[col].astype('int')

# Remove "(HUD) from strings
cols = ['Disability Type',
        'Receiving Services For',
        ]
for col in cols:
    df_disability[col] = df_disability[col].fillna(value='')
    df_disability[col] = df_disability[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_disability.loc[df_disability[col] == '', col] = np.nan

# encode booleans
col = 'Receiving Services For'
df_disability = encode_boolean(df_disability, col)

# %%
df_disability.head()
# Out:
#             Disability Type Receiving Services For  Disabilities ID  \
# Personal ID
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
#
#              Project Entry ID
# Personal ID
# 173848                 382788
# 173848                 383070
# 173848                 383336
# 173848                 383701
# 173848                 383839

# %%
df_disability['Disability Type'].value_counts()
# Out:
# Mental Health Problem          10238
# Physical                        9474
# Chronic Health Condition        5816
# Both Alcohol and Drug Abuse     2586
# Alcohol Abuse                   1777
# Drug Abuse                      1749
# Developmental                   1320
# HIV/AIDS                         467
# Substance Abuse                  133
# Dual Diagnosis                    29
# Other                             13
# Vision Impaired                    5
# Hearing Impaired                   2
# dtype: int64

# %%
# drop column for Project Entry ID
df2_disability = df_disability.drop('Project Entry ID', axis=1)
# drop duplicate rows
df3_disability = df2_disability.drop_duplicates()

# value counts without duplicated rows
df3_disability['Disability Type'].value_counts()
# Out:
# Mental Health Problem          2103
# Physical                       1505
# Chronic Health Condition       1171
# Both Alcohol and Drug Abuse     602
# Drug Abuse                      563
# Alcohol Abuse                   419
# Developmental                   304
# HIV/AIDS                        213
# Substance Abuse                   9
# Other                             5
# Vision Impaired                   5
# Dual Diagnosis                    3
# Hearing Impaired                  2
# dtype: int64

# %%
sheet = 'HealthInsurance'

cols = [
    'Personal ID',
    'Health Insurance Information Date',
    'Health Insurance',
    'Data Collection Stage',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_healthins = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                           parse_dates=['Health Insurance Information Date'],
                           infer_datetime_format=True)

df_healthins = df_healthins.dropna(axis=0, how='all')
# df_healthins.index = df_healthins.index.astype('int')

# %%
df_healthins.head()
# Out:
#             Health Insurance Information Date  \
# Personal ID
# 173781                             2014-05-06
# 173782                             2014-05-06
# 173783                             2014-05-06
# 173848                             2014-08-22
# 173848                             2014-08-22
#
#                               Health Insurance Data Collection Stage
# Personal ID
# 173781                                MEDICAID         Project Entry
# 173782                                MEDICARE         Project Entry
# 173783                                MEDICAID         Project Entry
# 173848                                MEDICAID         Project Entry
# 173848       State Health Insurance for Adults         Project Entry

# %%
sheet = 'Benefit'

cols = [
    'Personal ID',
    'Non-Cash Benefit',
    'Data Collection Stage',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_benefit = pd.read_csv(infile, header=0, index_col=0, usecols=cols, sep=';')

df_benefit = df_benefit.dropna(axis=0, how='all')
df_benefit.index = df_benefit.index.astype('int')

# Drop any project missing the code
df_benefit = df_benefit.dropna(how='any', subset=['Non-Cash Benefit'])

# Remove "(HUD) from strings
cols = ['Non-Cash Benefit',
        ]
for col in cols:
    df_benefit[col] = df_benefit[col].fillna(value='')
    df_benefit[col] = df_benefit[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_benefit.loc[df_benefit[col] == '', col] = np.nan

# shorten some column values
col = 'Non-Cash Benefit'
df_benefit.loc[df_benefit[col] == 'Supplemental Nutrition Assistance Program (Food Stamps)', col] = 'Food Stamps'
df_benefit.loc[df_benefit[col] == 'Special Supplemental Nutrition Program for WIC', col] = 'WIC'
df_benefit.loc[df_benefit[col] == 'Section 8, Public Housing, or other ongoing rental assistance', col] = 'Section 8, Public Housing'

# %%
df_benefit.head()
# Out:
#             Non-Cash Benefit Data Collection Stage
# Personal ID
# 173781           Food Stamps         Project Entry
# 173781           Food Stamps         Project Entry
# 173803           Food Stamps         Project Entry
# 173848           Food Stamps         Project Entry
# 173848           Food Stamps         Project Entry

# %%
df_benefit['Non-Cash Benefit'].value_counts()
# Out:
# Food Stamps                     39412
# Other Source                     2860
# WIC                              2039
# Section 8, Public Housing        1462
# Other TANF-Funded Services        753
# TANF Transportation Services      507
# TANF Child Care Services          470
# Temporary rental assistance       281
# dtype: int64

# %%
df_benefit['Count'] = 1

# %%
# start making a pivot table of services that people get

# Count will probably correspond to the number of times someone has checked in

df_benefit.reset_index().groupby(by=['Personal ID', 'Non-Cash Benefit'], as_index=False).sum().pivot(
    index='Personal ID', columns='Non-Cash Benefit', values='Count').head()
# Out:
# Non-Cash Benefit  Food Stamps  Other Source  Other TANF-Funded Services  \
# Personal ID
# 173781                      4           NaN                         NaN
# 173803                      2           NaN                         NaN
# 173848                    782           NaN                         NaN
# 173885                      1           NaN                         NaN
# 173899                    114           NaN                         NaN
#
# Non-Cash Benefit  Section 8, Public Housing  TANF Child Care Services  \
# Personal ID
# 173781                                  NaN                       NaN
# 173803                                  NaN                       NaN
# 173848                                  NaN                       NaN
# 173885                                  NaN                       NaN
# 173899                                  NaN                       NaN
#
# Non-Cash Benefit  TANF Transportation Services  Temporary rental assistance  \
# Personal ID
# 173781                                     NaN                          NaN
# 173803                                     NaN                          NaN
# 173848                                     NaN                          NaN
# 173885                                     NaN                          NaN
# 173899                                     NaN                          NaN
#
# Non-Cash Benefit  WIC
# Personal ID
# 173781            NaN
# 173803            NaN
# 173848            NaN
# 173885            NaN
# 173899            NaN

# %%
sheet = 'Income Entry & Exit'

cols = [
    'Personal ID',
    'Project Entry ID',
    'Entry Alimony',
    'Entry Child Support',
    'Entry Earned',
    'Entry GA',
    'Entry Other',
    'Entry Pension',
    'Entry Private Disability',
    'Entry Social Security Retirement',
    'Entry SSDI',
    'Entry SSI',
    'Entry TANF',
    'Entry Unemployment',
    'Entry VA Non-Service',
    'Entry VA Service Connected',
    "Entry Worker's Compensation",
    'Entry Total Income',
    'Exit Alimony',
    'Exit Child Support',
    'Exit Earned',
    'Exit GA',
    'Exit Other',
    'Exit Pension',
    'Exit Private Disability',
    'Exit Social Security Retirement',
    'Exit SSDI',
    'Exit SSI',
    'Exit TANF',
    'Exit Unemployment',
    'Exit VA Non-Service',
    'Exit VA Service Connected',
    "Exit Worker's Compensation",
    'Exit Total Income',
    'Income Change',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_income = pd.read_csv(infile, header=0, index_col=0, usecols=cols)

df_income = df_income.dropna(axis=0, how='all')
# df_income.index = df_income.index.astype('int')

# turn these into integers
cols = ['Project Entry ID']
for col in cols:
    df_income[col] = df_income[col].astype('int')

# assume all nans are $0
df_income = df_income.fillna(value='0')

# turn the dollar strings into integers
for col in df_income.columns:
    if col != 'Project Entry ID':
        df_income[col] = df_income[col].str.replace(',', '')
        df_income[col] = df_income[col].str.replace(r'[^-+\d.]', '').astype(int)

# %%
df_income.head()
# Out:
#              Project Entry ID  Entry Alimony  Entry Child Support  \
# Personal ID
# 173781                 252608              0                    0
# 173781                 314080              0                    0
# 173782                 122915              0                    0
# 173782                 314084              0                    0
# 173783                 122916              0                    0
#
#              Entry Earned  Entry GA  Entry Other  Entry Pension  \
# Personal ID
# 173781                  0         0            0              0
# 173781                  0         0            0              0
# 173782                  0         0            0              0
# 173782                  0         0            0              0
# 173783                  0         0            0              0
#
#              Entry Private Disability  Entry Social Security Retirement  \
# Personal ID
# 173781                              0                                 0
# 173781                              0                                 0
# 173782                              0                                 0
# 173782                              0                                 0
# 173783                              0                                 0
#
#              Entry SSDI  Entry SSI  Entry TANF  Entry Unemployment  \
# Personal ID
# 173781                0          0         607                   0
# 173781                0          0        1143                   0
# 173782                0          0           0                   0
# 173782                0          0           0                   0
# 173783                0          0           0                   0
#
#              Entry VA Non-Service  Entry VA Service Connected  \
# Personal ID
# 173781                          0                           0
# 173781                          0                           0
# 173782                          0                           0
# 173782                          0                           0
# 173783                          0                           0
#
#              Entry Worker's Compensation  Entry Total Income  Exit Alimony  \
# Personal ID
# 173781                                 0                 607             0
# 173781                                 0                1143             0
# 173782                                 0                   0             0
# 173782                                 0                   0             0
# 173783                                 0                   0             0
#
#              Exit Child Support  Exit Earned  Exit GA  Exit Other  \
# Personal ID
# 173781                        0            0        0           0
# 173781                        0            0        0           0
# 173782                        0            0        0           0
# 173782                        0            0        0           0
# 173783                        0            0        0           0
#
#              Exit Pension  Exit Private Disability  \
# Personal ID
# 173781                  0                        0
# 173781                  0                        0
# 173782                  0                        0
# 173782                  0                        0
# 173783                  0                        0
#
#              Exit Social Security Retirement  Exit SSDI  Exit SSI  Exit TANF  \
# Personal ID
# 173781                                     0          0         0        607
# 173781                                     0          0         0       1143
# 173782                                     0          0         0          0
# 173782                                     0          0         0          0
# 173783                                     0          0         0          0
#
#              Exit Unemployment  Exit VA Non-Service  \
# Personal ID
# 173781                       0                    0
# 173781                       0                    0
# 173782                       0                    0
# 173782                       0                    0
# 173783                       0                    0
#
#              Exit VA Service Connected  Exit Worker's Compensation  \
# Personal ID
# 173781                               0                           0
# 173781                               0                           0
# 173782                               0                           0
# 173782                               0                           0
# 173783                               0                           0
#
#              Exit Total Income  Income Change
# Personal ID
# 173781                     607              0
# 173781                    1143              0
# 173782                       0              0
# 173782                       0              0
# 173783                       0              0

# %%
sheet = 'Service'

cols =  [
    'Personal ID',
    'Services ID',
    'Date Provided',
    'Date Ended',
    'Service Code',
    'Description',
    'Project ID',
    'Record Type',
    'Project Entry ID',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_service = pd.read_csv(infile, header=0, index_col=0, usecols=cols, sep=';',
                         parse_dates=['Date Provided', 'Date Ended'],
                         infer_datetime_format=True)

df_service = df_service.dropna(axis=0, how='all')
df_service.index = df_service.index.astype('int')

# Drop anyone missing these IDs
df_service = df_service.dropna(how='any', subset=['Project ID', 'Project Entry ID'])

# turn these into integers
cols = ['Project ID', 'Project Entry ID']
for col in cols:
    df_service[col] = df_service[col].astype('int')

# %%
df_service.head()
# Out:
#             Services ID Date Provided Date Ended Service Code  \
# Personal ID
# 175155          7312345    2013-04-01 2013-04-02      BH-1800
# 180665          7312348    2013-04-01 2013-04-02      BH-1800
# 184317          7312343    2013-04-01 2013-04-02      BH-1800
# 184431          7312350    2013-04-01 2013-04-02      BH-1800
# 184502          7312340    2013-04-01 2013-04-02      BH-1800
#
#                    Description  Project ID Record Type  Project Entry ID
# Personal ID
# 175155       Emergency Shelter        2840   Bed Night            382789
# 180665       Emergency Shelter        2840   Bed Night            382791
# 184317       Emergency Shelter        2840   Bed Night            382790
# 184431       Emergency Shelter        2840   Bed Night            483580
# 184502       Emergency Shelter        2840   Bed Night            382785

# %%
df_service.shape
# Out:
# (58441, 8)

# %%
df_service['Date Provided'].isnull().sum()
# Out:
# 21838

# %%
df_service['Date Ended'].isnull().sum()
# Out:
# 22454

# %%
# drop any null dates
df_service = df_service.dropna(subset=['Date Provided', 'Date Ended'])

# %%
df_service.shape
# Out:
# (35987, 8)

# %%
# calculate the number of days service was given
df_service['Days'] = ((df_service['Date Ended'] - df_service['Date Provided']) / np.timedelta64(1, 'D')).astype(int)

# %%
df_service['Days'].value_counts().head(10)
# Out:
# 1     26338
# 0      4802
# 2      1063
# 3       758
# 4       218
# 5       144
# 6       140
# 7        91
# 11       91
# 27       87
# dtype: int64

# %%
df_service['Date Provided'].min()
# Out:
# Timestamp('2012-03-08 00:00:00')

# %%
df_service['Date Provided'].max()
# Out:
# Timestamp('2016-05-31 00:00:00')

# %%
df_service['Date Provided'].mode()
# Out:
# 0   2016-01-14
# dtype: datetime64[ns]

# %%
df_service['Description'].value_counts()
# Out:
# Emergency Shelter    35987
# dtype: int64

# %%
# not sure what this corresponds to
df_service['Services ID'].value_counts().head(10)
# Out:
# 8127596    1
# 8916326    1
# 8400962    1
# 8916323    1
# 8378265    1
# 8916325    1
# 8916324    1
# 8916327    1
# 7855338    1
# 8196616    1
# dtype: int64

# %%
# each Services ID occurs once in the dataset, corresponding to the specific service given on a specific date
len(df_service['Services ID'].unique())
# Out:
# 35987

# %%
sheet = 'Project'

cols = [
    'Project ID',
    'Project Name',
    'Project Type Code',
    'Address City',
    'Organization Name',
    'Address Postal Code'
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_project = pd.read_csv(infile, header=0, index_col=1, usecols=cols, sep=';')

df_project.head()

df_project = df_project.dropna(axis=0, how='all')
df_project.index = df_project.index.astype('int')

# Drop any project missing the code
df_project = df_project.dropna(how='any', subset=['Project Type Code'])

# Remove "(HUD) from strings
cols = ['Project Type Code',
        ]
for col in cols:
    df_project[col] = df_project[col].fillna(value='')
    df_project[col] = df_project[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_project.loc[df_project[col] == '', col] = np.nan

# %%
df_project.head()
# Out:
#                           Project Name                     Organization Name  \
# Project ID
# 2142             MOSBE CHS - Elm House  MOSBE Community Human Services (CHS)
# 2142             MOSBE CHS - Elm House  MOSBE Community Human Services (CHS)
# 3417          MOSBE CHS - RHY - BCP ES  MOSBE Community Human Services (CHS)
# 3417          MOSBE CHS - RHY - BCP ES  MOSBE Community Human Services (CHS)
# 3418        MOSBE CHS - RHY - BCP - HP  MOSBE Community Human Services (CHS)
#
#                   Project Type Code Address City Address Postal Code
# Project ID
# 2142           Transitional housing          NaN               93942
# 2142           Transitional housing          NaN               93955
# 3417              Emergency Shelter     Monterey               93942
# 3417              Emergency Shelter      Seaside               93955
# 3418        Homelessness Prevention     Monterey               93942

# %%
df_project['Organization Name'].value_counts().head()
# Out:
# MOSBE Housing Resource Center (HRC)*     30
# MOSBE HRC - SSVF                         26
# MOSBE Interim                            24
# zzz*inactive*MOSBE CCHAS (John XXIII)    20
# MOSBE Community Human Services (CHS)     13
# dtype: int64

# %%
df_project['Project Name'].value_counts().head()
# Out:
# ZZZ* INACTIVE*ZZZ-MOSBE HRC - SSVF-P2 VRSi - Santa Cruz Clients            4
# MOSBE HRC - SSVF- P2 HRC - HP-  Monterey/San Benito Clients                4
# ZZZ*INACTIVE*ZZZ- MOSBE HRC - SSVF-P2 VRSi- Monterey/San Benito Clients    4
# SCz-Veterans Resource Center- HP SSVF -Santa Cruz Clients                  4
# MOSBE HRC - SSVF- P2 - HRC HP                                              4
# dtype: int64

# %%
sheet = 'BedInventory'

cols = [
    'Project ID',
    'Inventory ID',
    'Inventory Household Type',
    'HMIS Participating Beds',
    'Inventory Start Date',
    'Inventory End Date',
    'Unit Inventory',
    'Bed Inventory',
    'Vet Bed Inventory',
    'Youth Bed Inventory',
    'Youth Bed Age Group',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_bedinv = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                        parse_dates=['Inventory Start Date', 'Inventory End Date'],
                        infer_datetime_format=True)

df_bedinv = df_bedinv.dropna(axis=0, how='all')
# df_bedinv.index = df_bedinv.index.astype('int')

# turn these into integers, assume zero if NaN
cols = ['Inventory ID', 'HMIS Participating Beds', 'Unit Inventory', 'Bed Inventory', 'Vet Bed Inventory', 'Youth Bed Inventory']
for col in cols:
    # df_bedinv[col] = df_bedinv.loc[~df_bedinv[col].isnull(), col].apply(lambda x: int(x))
    df_bedinv[col] = df_bedinv[col].fillna(value=0)
    df_bedinv[col] = df_bedinv[col].astype('int')

# %%
df_bedinv.head()
# Out:
#             Inventory ID                          Inventory Household Type  \
# Project ID
# 2088                 144  Households with at least one adult and one child
# 2088                 655  Households with at least one adult and one child
# 2095                 194                       Households without children
# 2095                 678                       Households without children
# 2101                 145  Households with at least one adult and one child
#
#             HMIS Participating Beds Inventory Start Date Inventory End Date  \
# Project ID
# 2088                             36           2001-01-01         2013-09-30
# 2088                             36           2013-10-01                NaT
# 2095                              0           2004-01-01         2013-09-30
# 2095                              0           2013-10-01                NaT
# 2101                             24           1992-01-01         2013-09-30
#
#             Unit Inventory  Bed Inventory  Vet Bed Inventory  \
# Project ID
# 2088                     9             36                  0
# 2088                     9             36                  0
# 2095                     2              2                  0
# 2095                     4              4                  0
# 2101                     5             24                  0
#
#             Youth Bed Inventory Youth Bed Age Group
# Project ID
# 2088                          0                 NaN
# 2088                          0                 NaN
# 2095                          2     Only Ages 18-24
# 2095                          4   Only Under Age 18
# 2101                          0                 NaN

# %% [markdown]
# # Clean data and make some features

# %%
# Only keep rows with entry dates starting in 2011
df_enroll = df_enroll[df_enroll['Entry Date'] >= '2011']

# Only keep rows with exit date
df_enroll = df_enroll[df_enroll['Exit Date'].notnull()]

# %%
df_client.head()
# Out:
#                                   Race                Ethnicity  Gender  \
# Personal ID
# 173781                           White          Hispanic/Latino  Female
# 173782                           White          Hispanic/Latino    Male
# 173783                           White          Hispanic/Latino  Female
# 173800       Black or African American  Non-Hispanic/Non-Latino  Female
# 173803                           White          Hispanic/Latino  Female
#
#             Veteran Status
# Personal ID
# 173781               False
# 173782               False
# 173783               False
# 173800               False
# 173803               False

# %%
df_enroll.head()
# Out:
#              Project Entry ID  Client Age at Entry Last Permanent Zip  \
# Personal ID
# 173781                 252608                   34              93907
# 173781                 314080                   35              93907
# 173782                 314084                   10              93905
# 173783                 314085                   12              93905
# 173803                 201286                   32              93905
#
#             Entry Date  Exit Date  Project ID Housing Status @ Project Start  \
# Personal ID
# 173781      2014-02-28 2014-02-28        2104        At-risk of homelessness
# 173781      2014-05-06 2014-09-30        2101          Category 1 - Homeless
# 173782      2014-05-06 2014-09-30        2101          Category 1 - Homeless
# 173783      2014-05-06 2014-09-30        2101          Category 1 - Homeless
# 173803      2013-02-08 2013-04-27        2101          Category 1 - Homeless
#
#                         Living situation before program entry?  \
# Personal ID
# 173781            Rental by client, no ongoing housing subsidy
# 173781       Emergency shelter, including hotel or motel pa...
# 173782       Emergency shelter, including hotel or motel pa...
# 173783       Emergency shelter, including hotel or motel pa...
# 173803       Staying or living in a friend's room, apartmen...
#
#             Client Location  Household ID        Relationship to HoH  \
# Personal ID
# 173781                  NaN        252608                        NaN
# 173781               CA-506        314080  Head of household's child
# 173782               CA-506        314080  Head of household's child
# 173783               CA-506        314080  Head of household's child
# 173803                  NaN        201286                        NaN
#
#             Disabling Condition Continuously Homeless One Year  \
# Personal ID
# 173781                    False                          False
# 173781                    False                          False
# 173782                    False                           True
# 173783                    False                           True
# 173803                    False                          False
#
#             Times Homeless Past Three Years Months Homeless This Time  \
# Personal ID
# 173781                                  NaN                       NaN
# 173781                                    2                       NaN
# 173782                                    2                       NaN
# 173783                                    2                       NaN
# 173803                                  NaN                       NaN
#
#             Chronic Homeless In Permanent Housing Residential Move In Date  \
# Personal ID
# 173781                 False                False                      NaT
# 173781                 False                False                      NaT
# 173782                 False                False                      NaT
# 173783                 False                False                      NaT
# 173803                 False                False                      NaT
#
#             Domestic Violence Victim               DV When Occurred  \
# Personal ID
# 173781                          True           More than a year ago
# 173781                          True  From six to twelve months ago
# 173782                          True  From six to twelve months ago
# 173783                          True  From six to twelve months ago
# 173803                          True  From six to twelve months ago
#
#             DV Currently Fleeing
# Personal ID
# 173781                     False
# 173781                     False
# 173782                     False
# 173783                     False
# 173803                     False

# %%
# calculate the number of days that someone was enrolled
df_enroll['Days Enrolled'] = ((df_enroll['Exit Date'] - df_enroll['Entry Date']) / np.timedelta64(1, 'D')).astype(int)

# %%
df_enroll['Days Enrolled'].value_counts().sort_index(ascending=True).head(10)
# Out:
# -5        1
#  0      783
#  1    35584
#  2     1627
#  3     1141
#  4      496
#  5      380
#  6      324
#  7      270
#  8      200
# dtype: int64

# %%
# remove anyone with negative number of enrollment days
df_enroll = df_enroll[df_enroll['Days Enrolled'] >= 0]

# %%
df_enroll['Days Enrolled'].max()
# Out:
# 1744

# %%
fig, ax = plt.subplots(figsize=(6, 4))

df_enroll['Days Enrolled'].plot(ax=ax, kind='hist', bins=365);

ax.set(title='Number of days enrolled',
       xlabel='Number of days',
       xlim=(0, 365));

# %%
# Join the client information with enrollment information.
# Inner join because we need both.
df = df_client.merge(df_enroll, how='inner', left_index=True, right_index=True)

# %%
df.head()
# Out:
#               Race        Ethnicity  Gender Veteran Status  Project Entry ID  \
# Personal ID
# 173781       White  Hispanic/Latino  Female          False            252608
# 173781       White  Hispanic/Latino  Female          False            314080
# 173782       White  Hispanic/Latino    Male          False            314084
# 173783       White  Hispanic/Latino  Female          False            314085
# 173803       White  Hispanic/Latino  Female          False            201286
#
#              Client Age at Entry Last Permanent Zip Entry Date  Exit Date  \
# Personal ID
# 173781                        34              93907 2014-02-28 2014-02-28
# 173781                        35              93907 2014-05-06 2014-09-30
# 173782                        10              93905 2014-05-06 2014-09-30
# 173783                        12              93905 2014-05-06 2014-09-30
# 173803                        32              93905 2013-02-08 2013-04-27
#
#              Project ID Housing Status @ Project Start  \
# Personal ID
# 173781             2104        At-risk of homelessness
# 173781             2101          Category 1 - Homeless
# 173782             2101          Category 1 - Homeless
# 173783             2101          Category 1 - Homeless
# 173803             2101          Category 1 - Homeless
#
#                         Living situation before program entry?  \
# Personal ID
# 173781            Rental by client, no ongoing housing subsidy
# 173781       Emergency shelter, including hotel or motel pa...
# 173782       Emergency shelter, including hotel or motel pa...
# 173783       Emergency shelter, including hotel or motel pa...
# 173803       Staying or living in a friend's room, apartmen...
#
#             Client Location  Household ID        Relationship to HoH  \
# Personal ID
# 173781                  NaN        252608                        NaN
# 173781               CA-506        314080  Head of household's child
# 173782               CA-506        314080  Head of household's child
# 173783               CA-506        314080  Head of household's child
# 173803                  NaN        201286                        NaN
#
#             Disabling Condition Continuously Homeless One Year  \
# Personal ID
# 173781                    False                          False
# 173781                    False                          False
# 173782                    False                           True
# 173783                    False                           True
# 173803                    False                          False
#
#             Times Homeless Past Three Years Months Homeless This Time  \
# Personal ID
# 173781                                  NaN                       NaN
# 173781                                    2                       NaN
# 173782                                    2                       NaN
# 173783                                    2                       NaN
# 173803                                  NaN                       NaN
#
#             Chronic Homeless In Permanent Housing Residential Move In Date  \
# Personal ID
# 173781                 False                False                      NaT
# 173781                 False                False                      NaT
# 173782                 False                False                      NaT
# 173783                 False                False                      NaT
# 173803                 False                False                      NaT
#
#             Domestic Violence Victim               DV When Occurred  \
# Personal ID
# 173781                          True           More than a year ago
# 173781                          True  From six to twelve months ago
# 173782                          True  From six to twelve months ago
# 173783                          True  From six to twelve months ago
# 173803                          True  From six to twelve months ago
#
#             DV Currently Fleeing  Days Enrolled
# Personal ID
# 173781                     False              0
# 173781                     False            147
# 173782                     False            147
# 173783                     False            147
# 173803                     False             78

# %%
df = df.merge(df_benefit.reset_index().groupby(by=['Personal ID'])[['Non-Cash Benefit']].nth(0),
              how='left', left_index=True, right_index=True)

df['Non-Cash Benefit'] = df['Non-Cash Benefit'].fillna('None')

# %%
df = df.merge(df_disability.reset_index().groupby(by=['Personal ID'])[['Disability Type']].nth(0),
              how='left', left_index=True, right_index=True)

df['Disability Type'] = df['Disability Type'].fillna('None')

# %%
# sort by entry date
df = df.sort('Entry Date')

# %%
# set up to count the number of times a person was in the system
df['Enrollments'] = 1

# %%
agg = {'Enrollments': 'sum',
       'Race': 'first',
       'Ethnicity': 'first',
       'Gender': 'first',
       'Veteran Status': 'max',
       'Client Age at Entry': 'last',
       'Days Enrolled': 'sum',
       'Chronic Homeless': 'max',
       'Continuously Homeless One Year': 'max',
       'Domestic Violence Victim': 'max',
       'Disability Type': 'last',
       'Non-Cash Benefit': 'last',
      }
df_features = df.reset_index().groupby(by=['Personal ID']).agg(agg)

# %%
df_features.shape
# Out:
# (11536, 12)

# %%
df_features
# Out:
#              Gender Veteran Status              Disability Type  \
# Personal ID
# 173781       Female          False                         None
# 173782         Male          False                         None
# 173783       Female          False                         None
# 173803       Female          False                         None
# 173804       Female          False                         None
# 173805       Female          False                         None
# 173848       Female          False                     Physical
# 173849       Female          False                         None
# 173885       Female          False        Mental Health Problem
# 173899       Female          False                         None
# 173901       Female          False                         None
# 173903         Male          False                         None
# 173922       Female          False        Mental Health Problem
# 173950       Female          False                   Drug Abuse
# 173982       Female          False                         None
# 173984       Female          False                         None
# 173989         Male          False                     HIV/AIDS
# 174006       Female          False                   Drug Abuse
# 174018         Male          False                     HIV/AIDS
# 174019         Male          False                         None
# 174020         Male          False                     HIV/AIDS
# 174027         Male          False                     HIV/AIDS
# 174051       Female          False                         None
# 174064         Male          False                     HIV/AIDS
# 174086       Female          False                     HIV/AIDS
# 174091       Female          False  Both Alcohol and Drug Abuse
# 174112       Female          False                   Drug Abuse
# 174113       Female          False                         None
# 174114         Male          False                         None
# 174115         Male          False                         None
# ...             ...            ...                          ...
# 281033         Male          False                         None
# 281034         Male          False                         None
# 281035         Male          False                         None
# 281036       Female          False                         None
# 281038       Female          False  Both Alcohol and Drug Abuse
# 281054       Female          False                         None
# 281108       Female          False                         None
# 281109         Male          False                         None
# 281116         Male          False                         None
# 281119       Female          False                         None
# 281125         Male          False     Chronic Health Condition
# 281126       Female          False        Mental Health Problem
# 281129       Female          False        Mental Health Problem
# 281133         Male           True                   Drug Abuse
# 281135         Male          False                   Drug Abuse
# 281159         Male          False                         None
# 281211         Male          False                         None
# 281212       Female          False                         None
# 281213         Male          False                         None
# 281214         Male          False                         None
# 281215         Male          False                         None
# 281217       Female          False                     Physical
# 281218         Male          False        Mental Health Problem
# 281219         Male          False                         None
# 281220         Male          False                         None
# 281221         Male          False                         None
# 281229       Female          False                         None
# 281230         Male          False                         None
# 281231         Male          False                         None
# 281232       Female          False                         None
#
#                                                   Race  \
# Personal ID
# 173781                                           White
# 173782                                           White
# 173783                                           White
# 173803                                           White
# 173804                                           White
# 173805                                           White
# 173848                                           White
# 173849                                           White
# 173885                                           White
# 173899                                           White
# 173901                       Black or African American
# 173903                       Black or African American
# 173922                                           White
# 173950                                         Unknown
# 173982                                           White
# 173984                                           Other
# 173989                                           White
# 174006                                           White
# 174018                                           White
# 174019                                           White
# 174020                                           White
# 174027                                           White
# 174051                                           White
# 174064                       Black or African American
# 174086                                           White
# 174091                                           White
# 174112                                           White
# 174113                                           White
# 174114                                           White
# 174115                                           White
# ...                                                ...
# 281033                                           White
# 281034                                           White
# 281035                                           White
# 281036                                           White
# 281038                                           Asian
# 281054                       Black or African American
# 281108                                           White
# 281109                                           White
# 281116                                           White
# 281119                                           White
# 281125       Native Hawaiian or Other Pacific Islander
# 281126                                           White
# 281129                                           White
# 281133                                           White
# 281135                                           White
# 281159                                           White
# 281211                                           White
# 281212                                           White
# 281213                                           White
# 281214                                           White
# 281215                                           White
# 281217                                           White
# 281218                                           White
# 281219                                           White
# 281220                                           White
# 281221                                           White
# 281229                                           White
# 281230                                           White
# 281231                                           White
# 281232                                           White
#
#             Continuously Homeless One Year Chronic Homeless  \
# Personal ID
# 173781                               False            False
# 173782                                True            False
# 173783                                True            False
# 173803                               False            False
# 173804                               False            False
# 173805                               False            False
# 173848                               False            False
# 173849                               False            False
# 173885                                True            False
# 173899                                True            False
# 173901                               False            False
# 173903                               False            False
# 173922                                True            False
# 173950                               False            False
# 173982                               False            False
# 173984                               False            False
# 173989                                True             True
# 174006                               False            False
# 174018                               False            False
# 174019                               False            False
# 174020                               False            False
# 174027                               False            False
# 174051                               False            False
# 174064                                True            False
# 174086                               False            False
# 174091                               False            False
# 174112                               False            False
# 174113                               False            False
# 174114                               False            False
# 174115                               False            False
# ...                                    ...              ...
# 281033                               False            False
# 281034                               False            False
# 281035                               False            False
# 281036                               False            False
# 281038                               False            False
# 281054                               False            False
# 281108                               False            False
# 281109                               False            False
# 281116                               False            False
# 281119                               False            False
# 281125                               False            False
# 281126                               False            False
# 281129                               False            False
# 281133                               False            False
# 281135                               False            False
# 281159                               False            False
# 281211                               False            False
# 281212                               False            False
# 281213                               False            False
# 281214                               False            False
# 281215                               False            False
# 281217                               False            False
# 281218                               False            False
# 281219                               False            False
# 281220                               False            False
# 281221                               False            False
# 281229                               False            False
# 281230                               False            False
# 281231                               False            False
# 281232                               False            False
#
#             Domestic Violence Victim  Days Enrolled  \
# Personal ID
# 173781                          True            147
# 173782                          True            147
# 173783                          True            147
# 173803                          True             78
# 173804                         False             78
# 173805                         False             65
# 173848                          True            763
# 173849                         False            159
# 173885                          True            546
# 173899                         False             69
# 173901                          True             48
# 173903                          True             14
# 173922                         False              7
# 173950                          True              2
# 173982                          True            288
# 173984                          True              1
# 173989                         False            398
# 174006                          True            750
# 174018                         False           1551
# 174019                         False           1551
# 174020                         False            223
# 174027                         False            587
# 174051                         False             23
# 174064                         False            222
# 174086                         False            176
# 174091                          True            288
# 174112                          True             30
# 174113                          True             30
# 174114                          True             30
# 174115                          True             30
# ...                              ...            ...
# 281033                         False              1
# 281034                         False              1
# 281035                         False              1
# 281036                         False              1
# 281038                          True              2
# 281054                          True              2
# 281108                          True             59
# 281109                         False             59
# 281116                         False            165
# 281119                         False            165
# 281125                         False              2
# 281126                         False             28
# 281129                          True              6
# 281133                          True              2
# 281135                         False              4
# 281159                         False              5
# 281211                         False              1
# 281212                         False              1
# 281213                         False              1
# 281214                         False              1
# 281215                         False              1
# 281217                          True              1
# 281218                         False              1
# 281219                         False              1
# 281220                         False              1
# 281221                         False              1
# 281229                         False              1
# 281230                         False              1
# 281231                         False              1
# 281232                         False              1
#
#                       Non-Cash Benefit  Client Age at Entry  Enrollments  \
# Personal ID
# 173781                     Food Stamps                   35            2
# 173782                            None                   10            1
# 173783                            None                   12            1
# 173803                     Food Stamps                   32            1
# 173804                            None                   11            1
# 173805                            None                   10            1
# 173848                     Food Stamps                   48          196
# 173849                            None                   10            1
# 173885                     Food Stamps                   34            5
# 173899                     Food Stamps                   49           69
# 173901                     Food Stamps                   29            2
# 173903                            None                    9            1
# 173922                            None                   65            7
# 173950                            None                   34            2
# 173982                     Food Stamps                   20            1
# 173984                     Food Stamps                   33            1
# 173989                            None                   34            3
# 174006                            None                   39            1
# 174018                            None                   46            1
# 174019                            None                   38            1
# 174020                    Other Source                   51            1
# 174027                    Other Source                   58            2
# 174051                     Food Stamps                   30            1
# 174064                    Other Source                   46            1
# 174086                    Other Source                   42            1
# 174091                     Food Stamps                   27            2
# 174112                     Food Stamps                   39            1
# 174113                            None                   14            1
# 174114                            None                   13            1
# 174115                            None                   12            1
# ...                                ...                  ...          ...
# 281033                     Food Stamps                   40            1
# 281034                            None                   14            1
# 281035                            None                   17            1
# 281036                            None                   11            1
# 281038                     Food Stamps                   45            2
# 281054                     Food Stamps                    0            2
# 281108                     Food Stamps                   22            1
# 281109                            None                    3            1
# 281116                            None                   25            1
# 281119                            None                    8            1
# 281125                            None                   45            2
# 281126                            None                   27            2
# 281129                            None                   70            2
# 281133                            None                   53            2
# 281135                            None                   23            2
# 281159                            None                   64            1
# 281211                     Food Stamps                   50            1
# 281212                     Food Stamps                   46            1
# 281213                            None                   16            1
# 281214                            None                   10            1
# 281215                            None                   19            1
# 281217                            None                   43            1
# 281218                            None                   43            1
# 281219                            None                   20            1
# 281220                            None                    7            1
# 281221                            None                   57            1
# 281229       Section 8, Public Housing                   38            1
# 281230                            None                   15            1
# 281231                            None                   13            1
# 281232                            None                   12            1
#
#                            Ethnicity
# Personal ID
# 173781               Hispanic/Latino
# 173782               Hispanic/Latino
# 173783               Hispanic/Latino
# 173803               Hispanic/Latino
# 173804               Hispanic/Latino
# 173805               Hispanic/Latino
# 173848       Non-Hispanic/Non-Latino
# 173849       Non-Hispanic/Non-Latino
# 173885               Hispanic/Latino
# 173899               Hispanic/Latino
# 173901       Non-Hispanic/Non-Latino
# 173903       Non-Hispanic/Non-Latino
# 173922       Non-Hispanic/Non-Latino
# 173950               Hispanic/Latino
# 173982       Non-Hispanic/Non-Latino
# 173984               Hispanic/Latino
# 173989               Hispanic/Latino
# 174006       Non-Hispanic/Non-Latino
# 174018               Hispanic/Latino
# 174019               Hispanic/Latino
# 174020               Hispanic/Latino
# 174027               Hispanic/Latino
# 174051               Hispanic/Latino
# 174064       Non-Hispanic/Non-Latino
# 174086               Hispanic/Latino
# 174091               Hispanic/Latino
# 174112               Hispanic/Latino
# 174113               Hispanic/Latino
# 174114               Hispanic/Latino
# 174115               Hispanic/Latino
# ...                              ...
# 281033               Hispanic/Latino
# 281034               Hispanic/Latino
# 281035               Hispanic/Latino
# 281036               Hispanic/Latino
# 281038       Non-Hispanic/Non-Latino
# 281054       Non-Hispanic/Non-Latino
# 281108       Non-Hispanic/Non-Latino
# 281109               Hispanic/Latino
# 281116               Hispanic/Latino
# 281119               Hispanic/Latino
# 281125                       Unknown
# 281126       Non-Hispanic/Non-Latino
# 281129                       Unknown
# 281133                       Unknown
# 281135       Non-Hispanic/Non-Latino
# 281159       Non-Hispanic/Non-Latino
# 281211               Hispanic/Latino
# 281212               Hispanic/Latino
# 281213               Hispanic/Latino
# 281214               Hispanic/Latino
# 281215               Hispanic/Latino
# 281217               Hispanic/Latino
# 281218               Hispanic/Latino
# 281219               Hispanic/Latino
# 281220               Hispanic/Latino
# 281221       Non-Hispanic/Non-Latino
# 281229               Hispanic/Latino
# 281230               Hispanic/Latino
# 281231               Hispanic/Latino
# 281232               Hispanic/Latino
#
# [11536 rows x 12 columns]

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Enrollments'
df_features[col].plot(ax=ax, kind='hist', bins=df_features[col].max())

ax.set(xlim=(0, 30),
       xlabel=col,
       title='Lifetime enrollments');

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Days Enrolled'
df_features[df_features[col] <= 1000][col].plot(ax=ax, kind='hist', bins=200)

ax.set(xlabel='Days',
       title='Lifetime days enrolled',
       #xlim=(0, 600),
       );

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Client Age at Entry'

df_features[col].plot(ax=ax, kind='hist',bins=101, normed=False)

ax.set(xlim=(0, 101),
       xlabel='Age (at latest enrollment)',
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Race'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Ethnicity'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Gender'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Non-Cash Benefit'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Veteran Status'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
df_features.columns
# Out:
# Index([u'Gender', u'Veteran Status', u'Disability Type', u'Race',
#        u'Continuously Homeless One Year', u'Chronic Homeless',
#        u'Domestic Violence Victim', u'Days Enrolled', u'Non-Cash Benefit',
#        u'Client Age at Entry', u'Enrollments', u'Ethnicity'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Chronic Homeless'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Continuously Homeless One Year'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Domestic Violence Victim'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Disability Type'
(df_features[col].value_counts() / df_features[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
df_features.columns
# Out:
# Index([u'Gender', u'Veteran Status', u'Disability Type', u'Race',
#        u'Continuously Homeless One Year', u'Chronic Homeless',
#        u'Domestic Violence Victim', u'Days Enrolled', u'Non-Cash Benefit',
#        u'Client Age at Entry', u'Enrollments', u'Ethnicity'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(6, 4))

group = 'Gender'
col = 'Domestic Violence Victim'

count_group = df_features.groupby(by=[group]).size()
count_col = df_features.groupby(by=[group, col]).size()

prop_group = pd.DataFrame(count_col / count_group).unstack()[0]

prop_group.plot(ax=ax, kind='bar');

xlabels = ['{r}\nn={n}'.format(r=x.get_text(), n=count_group[x.get_text()]) for x in ax.get_xticklabels()];
ax.set_xticklabels(xlabels, rotation=90);

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col,
       );

ax.legend(bbox_to_anchor=(1.3, 1.0));

# %%
fig, ax = plt.subplots(figsize=(6, 4))

group = 'Race'
col = 'Veteran Status'

count_group = df_features.groupby(by=[group]).size()
count_col = df_features.groupby(by=[group, col]).size()

prop_group = pd.DataFrame(count_col / count_group).unstack()[0]

prop_group.plot(ax=ax, kind='bar');

xlabels = ['{r}\nn={n}'.format(r=x.get_text(), n=count_group[x.get_text()]) for x in ax.get_xticklabels()];
ax.set_xticklabels(xlabels, rotation=90);

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col,
       );

ax.legend(bbox_to_anchor=(1.3, 1.0));

# %%
# for col in df_features.columns:
#     print('\n')
#     print(df_features[col].value_counts().head(10))
#     print(df_features[col].value_counts().sum())

# %%
# # turn into unique strings by prepending column name

# df_features_out = df_features.copy()

# # cols = ['Ethnicity',
# #         'Race',
# #         'Domestic Violence Victim',
# #         'Gender',
# #         'Continuously Homeless One Year',
# #         'Veteran Status',
# #         'Chronic Homeless',
# #         ]
# # for col in cols:

# for col in df_features.columns:
#     df_features_out[col] = df_features[col].apply(lambda x: '{}: {}'.format(col, x))

# %%
# df_features_out.head()

# %%
# df_features_out.to_csv(os.path.join(datadir, 'SFHomeless_2016-10-12_individ_features_strings.csv'))

# %% [markdown]
# # Ideas for plots
#
# - Enrollments by zip code
# - Enrollments by project
# - Clients by project and organization
# - Clients by organization zip code

# %%
# merge organizations from the project dataframe with the merged client and enrollment dataframe

# make column of index from df dataframe (Personal ID)
df_resetindex = df.reset_index()
# make column of index from project dataframe (Project ID)
df_project_resetindex = df_project.reset_index()

# merge new df dataframe with project dataframe on Project ID
df_dfProject = df_resetindex.merge(df_project_resetindex, how='left', on='Project ID').set_index('Personal ID').sort_index()

# %%
len(df_dfProject)
# Out:
# 63666

# %%
df_dfProject.head(n=3)
# Out:
#               Race        Ethnicity  Gender Veteran Status  Project Entry ID  \
# Personal ID
# 173781       White  Hispanic/Latino  Female          False            314080
# 173781       White  Hispanic/Latino  Female          False            252608
# 173782       White  Hispanic/Latino    Male          False            314084
#
#              Client Age at Entry Last Permanent Zip Entry Date  Exit Date  \
# Personal ID
# 173781                        35              93907 2014-05-06 2014-09-30
# 173781                        34              93907 2014-02-28 2014-02-28
# 173782                        10              93905 2014-05-06 2014-09-30
#
#              Project ID Housing Status @ Project Start  \
# Personal ID
# 173781             2101          Category 1 - Homeless
# 173781             2104        At-risk of homelessness
# 173782             2101          Category 1 - Homeless
#
#                         Living situation before program entry?  \
# Personal ID
# 173781       Emergency shelter, including hotel or motel pa...
# 173781            Rental by client, no ongoing housing subsidy
# 173782       Emergency shelter, including hotel or motel pa...
#
#             Client Location  Household ID        Relationship to HoH  \
# Personal ID
# 173781               CA-506        314080  Head of household's child
# 173781                  NaN        252608                        NaN
# 173782               CA-506        314080  Head of household's child
#
#             Disabling Condition Continuously Homeless One Year  \
# Personal ID
# 173781                    False                          False
# 173781                    False                          False
# 173782                    False                           True
#
#             Times Homeless Past Three Years Months Homeless This Time  \
# Personal ID
# 173781                                    2                       NaN
# 173781                                  NaN                       NaN
# 173782                                    2                       NaN
#
#             Chronic Homeless In Permanent Housing Residential Move In Date  \
# Personal ID
# 173781                 False                False                      NaT
# 173781                 False                False                      NaT
# 173782                 False                False                      NaT
#
#             Domestic Violence Victim               DV When Occurred  \
# Personal ID
# 173781                          True  From six to twelve months ago
# 173781                          True           More than a year ago
# 173782                          True  From six to twelve months ago
#
#             DV Currently Fleeing  Days Enrolled Non-Cash Benefit  \
# Personal ID
# 173781                     False            147      Food Stamps
# 173781                     False              0      Food Stamps
# 173782                     False            147             None
#
#             Disability Type  Enrollments  \
# Personal ID
# 173781                 None            1
# 173781                 None            1
# 173782                 None            1
#
#                                                   Project Name  \
# Personal ID
# 173781                           MOSBE SOP - Natividad Shelter
# 173781       MOSBE SOP - Mobile Outreach Shelter Program - ...
# 173782                           MOSBE SOP - Natividad Shelter
#
#                                              Organization Name  \
# Personal ID
# 173781                                               MOSBE SOP
# 173781       zzz*no data entry* MOSBE Shelter Outreach Plus...
# 173782                                               MOSBE SOP
#
#              Project Type Code Address City Address Postal Code
# Personal ID
# 173781       Emergency Shelter       Marina               93933
# 173781         Street Outreach          NaN               93933
# 173782       Emergency Shelter       Marina               93933

# %%
df_dfProject['Organization Name'].value_counts().nlargest(10)
# Out:
# SCz - HSC - NO DATA HERE                                     24018
# MOSBE San Benito Homeless Coalition                           8149
# MOSBE Franciscan Workers of Junipero Serra                    7114
# MOSBE Housing Resource Center (HRC)*                          4048
# SCz-Veterans Resource Center- HP SSVF -San Mateo Clients      2535
# SCz - Encompass                                               2315
# SCz-Veterans Resource Center- HP SSVF -Santa Cruz Clients     1942
# MOSBE SOP                                                     1907
# SCz-Veterans Resource Center                                  1746
# MOSBE HRC - SSVF                                              1590
# dtype: int64

# %%
df_dfProject['Address Postal Code'].value_counts().nlargest(10)
# Out:
# 95060    25956
# 93901     9861
# 95023     8143
# 93933     4478
# 93902     2826
# 93940     2621
# 95062     2572
# 94025     2535
# 95076     1746
# 93942     1390
# dtype: int64

# %%
df_dfProject['Project Type Code'].value_counts()
# Out:
# Emergency Shelter                                                    43916
# Homelessness Prevention                                               5792
# Services Only                                                         4856
# PH - Rapid Re-Housing                                                 2922
# Other                                                                 2636
# Transitional housing                                                  2238
# Street Outreach                                                       1076
# PH - Permanent Supportive Housing (disability required for entry)      211
# dtype: int64

# %%
df_dfProject['Project Type Code'].value_counts()
# Out:
# Emergency Shelter                                                    43916
# Homelessness Prevention                                               5792
# Services Only                                                         4856
# PH - Rapid Re-Housing                                                 2922
# Other                                                                 2636
# Transitional housing                                                  2238
# Street Outreach                                                       1076
# PH - Permanent Supportive Housing (disability required for entry)      211
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6, 4))

col = 'Project Type Code'
(df_dfProject[col].value_counts() / df_dfProject[col].value_counts().sum()).plot(ax=ax, kind='bar');

ax.set(ylabel='Proportion',
       ylim=(0, 1),
       title=col);

# %%
df_dfProject.head(n=2)
# Out:
#               Race        Ethnicity  Gender Veteran Status  Project Entry ID  \
# Personal ID
# 173781       White  Hispanic/Latino  Female          False            314080
# 173781       White  Hispanic/Latino  Female          False            252608
#
#              Client Age at Entry Last Permanent Zip Entry Date  Exit Date  \
# Personal ID
# 173781                        35              93907 2014-05-06 2014-09-30
# 173781                        34              93907 2014-02-28 2014-02-28
#
#              Project ID Housing Status @ Project Start  \
# Personal ID
# 173781             2101          Category 1 - Homeless
# 173781             2104        At-risk of homelessness
#
#                         Living situation before program entry?  \
# Personal ID
# 173781       Emergency shelter, including hotel or motel pa...
# 173781            Rental by client, no ongoing housing subsidy
#
#             Client Location  Household ID        Relationship to HoH  \
# Personal ID
# 173781               CA-506        314080  Head of household's child
# 173781                  NaN        252608                        NaN
#
#             Disabling Condition Continuously Homeless One Year  \
# Personal ID
# 173781                    False                          False
# 173781                    False                          False
#
#             Times Homeless Past Three Years Months Homeless This Time  \
# Personal ID
# 173781                                    2                       NaN
# 173781                                  NaN                       NaN
#
#             Chronic Homeless In Permanent Housing Residential Move In Date  \
# Personal ID
# 173781                 False                False                      NaT
# 173781                 False                False                      NaT
#
#             Domestic Violence Victim               DV When Occurred  \
# Personal ID
# 173781                          True  From six to twelve months ago
# 173781                          True           More than a year ago
#
#             DV Currently Fleeing  Days Enrolled Non-Cash Benefit  \
# Personal ID
# 173781                     False            147      Food Stamps
# 173781                     False              0      Food Stamps
#
#             Disability Type  Enrollments  \
# Personal ID
# 173781                 None            1
# 173781                 None            1
#
#                                                   Project Name  \
# Personal ID
# 173781                           MOSBE SOP - Natividad Shelter
# 173781       MOSBE SOP - Mobile Outreach Shelter Program - ...
#
#                                              Organization Name  \
# Personal ID
# 173781                                               MOSBE SOP
# 173781       zzz*no data entry* MOSBE Shelter Outreach Plus...
#
#              Project Type Code Address City Address Postal Code  Count  \
# Personal ID
# 173781       Emergency Shelter       Marina               93933      1
# 173781         Street Outreach          NaN               93933      1
#
#              service  Count2
# Personal ID
# 173781             1       1
# 173781             1       1

# %%
df_dfProject['Non-Cash Benefit'].value_counts()
# Out:
# None                            39890
# Food Stamps                     20938
# Other Source                      992
# Section 8, Public Housing         964
# WIC                               611
# Other TANF-Funded Services        183
# TANF Transportation Services       42
# TANF Child Care Services           33
# Temporary rental assistance        13
# dtype: int64

# %%
df_dfProject['Housing Status @ Project Start'].value_counts()
# Out:
# Category 1 - Homeless                                      49462
# Category 2 - At imminent risk of losing housing             4230
# Stably housed                                               2506
# At-risk of homelessness                                     1671
# Client refused                                               758
# Client doesn't know                                          757
# Data not collected                                           466
# Category 3 - Homeless only under other federal statutes       97
# Category 4 - Fleeing domestic violence                        41
# dtype: int64

# %%
df_dfProject['Project Type Code'].value_counts()
# Out:
# Emergency Shelter                                                    43916
# Homelessness Prevention                                               5792
# Services Only                                                         4856
# PH - Rapid Re-Housing                                                 2922
# Other                                                                 2636
# Transitional housing                                                  2238
# Street Outreach                                                       1076
# PH - Permanent Supportive Housing (disability required for entry)      211
# dtype: int64

# %%
df_dfProject['Count2'] = 1
df_dfProject.reset_index().groupby(by=['Housing Status @ Project Start', 'Project Type Code'], as_index=False).sum().pivot(
    index='Housing Status @ Project Start', columns='Project Type Code', values='Count2').head()
# Out:
# Project Type Code                                   Emergency Shelter  \
# Housing Status @ Project Start
# At-risk of homelessness                                           312
# Category 1 - Homeless                                           39058
# Category 2 - At imminent risk of losing housing                   398
# Category 3 - Homeless only under other federal ...                 84
# Category 4 - Fleeing domestic violence                             35
#
# Project Type Code                                   Homelessness Prevention  \
# Housing Status @ Project Start
# At-risk of homelessness                                                 872
# Category 1 - Homeless                                                  2210
# Category 2 - At imminent risk of losing housing                        1722
# Category 3 - Homeless only under other federal ...                      NaN
# Category 4 - Fleeing domestic violence                                  NaN
#
# Project Type Code                                   Other  \
# Housing Status @ Project Start
# At-risk of homelessness                               109
# Category 1 - Homeless                                1288
# Category 2 - At imminent risk of losing housing       294
# Category 3 - Homeless only under other federal ...      4
# Category 4 - Fleeing domestic violence                NaN
#
# Project Type Code                                   PH - Permanent Supportive Housing (disability required for entry)  \
# Housing Status @ Project Start
# At-risk of homelessness                                                                            26
# Category 1 - Homeless                                                                             114
# Category 2 - At imminent risk of losing housing                                                     9
# Category 3 - Homeless only under other federal ...                                                NaN
# Category 4 - Fleeing domestic violence                                                            NaN
#
# Project Type Code                                   PH - Rapid Re-Housing  \
# Housing Status @ Project Start
# At-risk of homelessness                                                19
# Category 1 - Homeless                                                1416
# Category 2 - At imminent risk of losing housing                       100
# Category 3 - Homeless only under other federal ...                    NaN
# Category 4 - Fleeing domestic violence                                NaN
#
# Project Type Code                                   Services Only  \
# Housing Status @ Project Start
# At-risk of homelessness                                       208
# Category 1 - Homeless                                        2531
# Category 2 - At imminent risk of losing housing              1552
# Category 3 - Homeless only under other federal ...              4
# Category 4 - Fleeing domestic violence                          1
#
# Project Type Code                                   Street Outreach  \
# Housing Status @ Project Start
# At-risk of homelessness                                          51
# Category 1 - Homeless                                           884
# Category 2 - At imminent risk of losing housing                  60
# Category 3 - Homeless only under other federal ...                5
# Category 4 - Fleeing domestic violence                            3
#
# Project Type Code                                   Transitional housing
# Housing Status @ Project Start
# At-risk of homelessness                                               74
# Category 1 - Homeless                                               1950
# Category 2 - At imminent risk of losing housing                       94
# Category 3 - Homeless only under other federal ...                   NaN
# Category 4 - Fleeing domestic violence                                 2

# %%
# count of each benefit per organization
df_dfProject.groupby(['Organization Name', 'Non-Cash Benefit'])['Non-Cash Benefit'].count()
# Out:
# Organization Name                                                   Non-Cash Benefit
# MOSBE Community Human Services (CHS)                                Food Stamps                      121
#                                                                     None                             460
#                                                                     Other Source                       4
#                                                                     TANF Transportation Services      14
# MOSBE Franciscan Workers of Junipero Serra                          Food Stamps                     2607
#                                                                     None                            4130
#                                                                     Other Source                       3
#                                                                     Section 8, Public Housing        171
#                                                                     TANF Transportation Services       8
#                                                                     WIC                              195
# MOSBE HRC - SSVF                                                    Food Stamps                      394
#                                                                     None                            1058
#                                                                     Other Source                      36
#                                                                     Section 8, Public Housing         30
#                                                                     WIC                               72
# MOSBE Housing Authority - County of Monterey                        Food Stamps                        5
#                                                                     None                               1
#                                                                     Section 8, Public Housing          8
# MOSBE Housing Authority - Pueblo del Mar Family Recovery Community  Food Stamps                      214
#                                                                     None                             490
#                                                                     Other Source                       4
#                                                                     TANF Child Care Services           4
#                                                                     TANF Transportation Services       4
#                                                                     WIC                               14
# MOSBE Housing Resource Center (HRC)*                                Food Stamps                      920
#                                                                     None                            3066
#                                                                     Other Source                      12
#                                                                     Other TANF-Funded Services        26
#                                                                     Section 8, Public Housing         12
#                                                                     TANF Child Care Services           2
#                                                                                                     ...
# SCz-Veterans Resource Center                                        Other Source                      54
#                                                                     Other TANF-Funded Services         3
#                                                                     Section 8, Public Housing         15
#                                                                     WIC                               48
# SCz-Veterans Resource Center- HP SSVF -San Mateo Clients            Food Stamps                      177
#                                                                     None                            2316
#                                                                     Other Source                       3
#                                                                     Other TANF-Funded Services         3
#                                                                     Section 8, Public Housing          9
#                                                                     WIC                               27
# SCz-Veterans Resource Center- HP SSVF -Santa Cruz Clients           Food Stamps                      539
#                                                                     None                            1088
#                                                                     Other Source                      41
#                                                                     Section 8, Public Housing        244
#                                                                     Temporary rental assistance       10
#                                                                     WIC                               20
# zzz*inactive*MOSBE CCHAS                                            Food Stamps                       64
#                                                                     None                             332
#                                                                     Other Source                      20
#                                                                     Section 8, Public Housing         28
# zzz*inactive*MOSBE CCHAS (John XXIII)                               Food Stamps                       44
#                                                                     None                             244
#                                                                     Other Source                      22
#                                                                     Section 8, Public Housing         14
# zzz*no data entry* MOSBE Shelter Outreach Plus (SOP)                Food Stamps                      685
#                                                                     None                             703
#                                                                     Other Source                       4
#                                                                     Other TANF-Funded Services         2
#                                                                     Section 8, Public Housing          2
#                                                                     Temporary rental assistance        1
# Name: Non-Cash Benefit, dtype: int64

# %%
# count of each benefit per zipcode
df_dfProject.groupby(['Address Postal Code', 'Non-Cash Benefit'])['Non-Cash Benefit'].count()
# Out:
# Address Postal Code  Non-Cash Benefit
# 92940                Food Stamps                        21
#                      None                               36
#                      TANF Transportation Services        7
# 93901                Food Stamps                      3225
#                      None                             6162
#                      Other Source                       27
#                      Other TANF-Funded Services         13
#                      Section 8, Public Housing         192
#                      TANF Child Care Services            1
#                      TANF Transportation Services        9
#                      WIC                               232
# 93902                Food Stamps                       657
#                      None                             2069
#                      Other Source                       24
#                      Other TANF-Funded Services         13
#                      Section 8, Public Housing          21
#                      TANF Child Care Services            1
#                      TANF Transportation Services        1
#                      WIC                                40
# 93905                Food Stamps                        39
#                      None                               23
#                      WIC                                 3
# 93906                Food Stamps                        54
#                      None                              288
#                      Other Source                       21
#                      Section 8, Public Housing          21
# 93907                Food Stamps                         5
#                      None                                1
#                      Section 8, Public Housing           8
# 93912                Food Stamps                       107
#                                                      ...
# 95023                Other Source                       46
#                      Other TANF-Funded Services         21
#                      Section 8, Public Housing           1
#                      TANF Child Care Services            2
#                      TANF Transportation Services        1
#                      WIC                                 5
# 95060                Food Stamps                      8578
#                      None                            16240
#                      Other Source                      559
#                      Other TANF-Funded Services        115
#                      Section 8, Public Housing         337
#                      TANF Child Care Services            8
#                      TANF Transportation Services        8
#                      WIC                               111
# 95062                Food Stamps                       749
#                      None                             1447
#                      Other Source                       64
#                      Section 8, Public Housing         266
#                      TANF Child Care Services            2
#                      Temporary rental assistance        10
#                      WIC                                34
# 95076                Food Stamps                       493
#                      None                             1098
#                      Other Source                       19
#                      Other TANF-Funded Services          4
#                      Section 8, Public Housing          37
#                      TANF Child Care Services           10
#                      TANF Transportation Services        2
#                      Temporary rental assistance         1
#                      WIC                                82
# Name: Non-Cash Benefit, dtype: int64

# %%
# show entry and exit date for the people that were/are homeless

dates_homeless_category = df_dfProject.loc[df_dfProject['Housing Status @ Project Start'].isin(['Category 1 - Homeless'])]
dates_homeless_category = dates_homeless_category[['Entry Date', 'Exit Date', 'Days Enrolled', 'Housing Status @ Project Start']]
dates_homeless_category.head()
# Out:
#             Entry Date  Exit Date  Days Enrolled  \
# Personal ID
# 173781      2014-05-06 2014-09-30            147
# 173782      2014-05-06 2014-09-30            147
# 173783      2014-05-06 2014-09-30            147
# 173803      2013-02-08 2013-04-27             78
# 173804      2013-02-08 2013-04-27             78
#
#             Housing Status @ Project Start
# Personal ID
# 173781               Category 1 - Homeless
# 173782               Category 1 - Homeless
# 173783               Category 1 - Homeless
# 173803               Category 1 - Homeless
# 173804               Category 1 - Homeless
