# %% [markdown]
# The purpose of this notebook is to create a one-hot encoding of the dataset

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# # the "1" means: always reload modules marked with "%aimport"
# %autoreload 2

from __future__ import absolute_import, division, print_function
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os, sys
# from tqdm import tqdm
# import warnings

# sns.set_context("poster", font_scale=0.9)
sns.set_context("notebook", font_scale=1.0)
pd.set_option('display.max_columns', 100)

# add the data functions to the path
src_data_dir = os.path.join(os.getcwd(), os.pardir, 'src/data')
sys.path.append(src_data_dir)

# functions to load the data
import homeless_dataset as hd

# %%
# load in and process the data in separate sheets

df_client = hd.process_data_client(simplify_strings=True)

df_enroll = hd.process_data_enrollment(simplify_strings=True)

# Only keep rows with entry dates starting in 2012
df_enroll = df_enroll[df_enroll['Entry Date'] >= '2012']
# Only keep rows with exit dates before 2016-06-01
df_enroll = df_enroll[df_enroll['Exit Date'] <= '2016-06-01']

df_disability = hd.process_data_disability(simplify_strings=True)

df_healthins = hd.process_data_healthins(simplify_strings=True)

df_benefit = hd.process_data_benefit(simplify_strings=True)

df_income = hd.process_data_income(simplify_strings=True)

df_project = hd.process_data_project(simplify_strings=True)

df_service = hd.process_data_service(simplify_strings=True)

df_bedinv = hd.process_data_bedinventory(simplify_strings=True)

# %%
# Join the client information with enrollment information.
# Inner join because we want to only keep individuals
# for whom we have both client and enrollment information.
df = df_client.merge(df_enroll, how='inner', left_index=True, right_index=True)

# just choose the first non-cash benefit; this is too simple!
# TODO: join on the exact Project ID, and possible Date
df = df.merge(df_benefit.reset_index().groupby(by=['Personal ID'])[['Non-Cash Benefit']].nth(0),
              how='left', left_index=True, right_index=True)
# # possible fix for above, but this isn't working properly (results in too many rows);
# # probably need date too, but they do not align
# df.reset_index().merge(df_benefit.reset_index()[['Personal ID', 'Project Entry ID', 'Non-Cash Benefit']].drop_duplicates(),
#                        how='left',
#                        on=['Personal ID', 'Project Entry ID'],
#                       ).drop_duplicates().set_index('Personal ID')

df['Non-Cash Benefit'] = df['Non-Cash Benefit'].fillna('None')

# add information about their disability status
# just choose the first disability; this is too simple!
# TODO: join on the exact Project ID
df = df.merge(df_disability.reset_index().groupby(by=['Personal ID'])[['Disability Type']].nth(0),
              how='left', left_index=True, right_index=True)
# # possible fix for above, but this isn't working properly (results in too many rows);
# # probably need date too, but they do not align
# df.reset_index().merge(df_disability.reset_index()[['Personal ID', 'Project Entry ID', 'Disability Type']].drop_duplicates(),
#                        how='left',
#                        on=['Personal ID', 'Project Entry ID'],
#                       ).drop_duplicates().set_index('Personal ID')

df['Disability Type'] = df['Disability Type'].fillna('None')

# add Project Type Code to DataFrame
df = df.merge(df_project[['Project Name',
                          'Project Type Code',
                          'Address City',
                          'Address Postal Code',
                         ]], left_on=['Project ID'], right_index=True)

# sort by entry date
df = df.sort_values('Entry Date')

# %%
# rename the columns to have no spaces
df = hd.rename_columns(df)

# %%
df.shape
# Out:
# (58209, 33)

# %%
df.head(2)
# Out:
#               race  ethnicity gender veteran_status  project_entry_id  \
# Personal ID
# 214224       white  nonlatino   male          False            203474
# 194592       white  nonlatino   male           True            150135
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 214224                        60              00000 2012-01-01 2013-09-08
# 194592                        53              91103 2012-01-02 2013-08-31
#
#              project_id housing_status_project_start  \
# Personal ID
# 214224             2938                 cat1homeless
# 194592             2134                 cat1homeless
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 214224                                      hotel             NaN
# 194592                                     family             NaN
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 214224             203474                True                          False
# 194592             150135                True                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 214224                                  NaN                       NaN
# 194592                                  NaN                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 214224                 False                False                      NaT
# 194592                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 214224                         False                    NaN
# 194592                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 214224                     False            616                          NaN
# 194592                     False            607                          NaN
#
#             head_of_household noncash_benefit disability_type  \
# Personal ID
# 214224                  False            None        physical
# 194592                  False      foodstamps    mentalhealth
#
#                                             project_name    project_type_code  \
# Personal ID
# 214224            SCz - HSC - Page Smith Community House  transitionalhousing
# 194592       MOSBE Veterans Transition Center - Outreach                other
#
#             address_city  address_postal_code
# Personal ID
# 214224        Santa Cruz                95060
# 194592            Marina                93933

# %%
df['project_type_code'].value_counts()
# Out:
# emergencyshelter              43815
# servicesonly                   4652
# other                          2529
# homelessnessprevention         2213
# transitionalhousing            2012
# rapidrehousing                 1767
# streetoutreach                 1049
# permanentsupportivehousing      172
# Name: project_type_code, dtype: int64

# %%
df['noncash_benefit'].value_counts()
# Out:
# None                  36075
# foodstamps            19760
# other                   880
# publichousing           696
# wic                     542
# tanfother               179
# tanftransportation       40
# tanfchildcare            32
# temprental                5
# Name: noncash_benefit, dtype: int64

# %% [markdown]
# # One-hot encoding

# %%
features_binary = [
    'veteran_status',
    'disabling_condition',
    'continuously_homeless_one_year',
    'chronic_homeless',
    'in_permanent_housing',
    'domestic_violence_victim',
    'dv_currently_fleeing',
    'head_of_household',
]

features_quant = [
    'client_age_at_entry',
    'times_homeless_past_three_years',
    'months_homeless_this_time',
    'months_ago_dv_occurred',
    'days_enrolled',
    'days_to_residential_move_in',
]

features_date = [
    'entry_date',
    'exit_date',
    'residential_move_in_date',
    ]

features_one_hot = [
    'race',
    'ethnicity',
    'gender',
    'housing_status_project_start',
    'living_situation_before_program_entry',
    'noncash_benefit',
    'disability_type',
    'project_type_code',
]

features_not_using = [
    'project_entry_id',
    'last_permanent_zip',
    'project_id',
    'client_location',
    'household_id',
    'project_name',
    'address_city',
    'address_postal_code',
]

# %%
df = df.drop(features_not_using, axis=1)

df, cols = hd.encode_categorical_features(df, features_one_hot, astype='int')

# %%
df.head()
# Out:
#               race  ethnicity  gender veteran_status  client_age_at_entry  \
# Personal ID
# 214224       white  nonlatino    male          False                   60
# 194592       white  nonlatino    male           True                   53
# 179384       white     latino  female          False                   50
# 183019       white     latino    male          False                   28
# 182885       black  nonlatino    male          False                   48
#
#             entry_date  exit_date housing_status_project_start  \
# Personal ID
# 214224      2012-01-01 2013-09-08                 cat1homeless
# 194592      2012-01-02 2013-08-31                 cat1homeless
# 179384      2012-01-03 2016-01-28                 cat1homeless
# 183019      2012-01-03 2012-10-26                 cat1homeless
# 182885      2012-01-04 2013-05-02                 cat1homeless
#
#             living_situation_before_program_entry disabling_condition  \
# Personal ID
# 214224                                      hotel                True
# 194592                                     family                True
# 179384                                    streets               False
# 183019                                    streets               False
# 182885                                emershelter               False
#
#             continuously_homeless_one_year times_homeless_past_three_years  \
# Personal ID
# 214224                               False                             NaN
# 194592                               False                             NaN
# 179384                               False                             NaN
# 183019                               False                             NaN
# 182885                               False                             NaN
#
#             months_homeless_this_time chronic_homeless in_permanent_housing  \
# Personal ID
# 214224                            NaN            False                False
# 194592                            NaN            False                False
# 179384                            NaN            False                False
# 183019                            NaN            False                False
# 182885                            NaN            False                False
#
#             residential_move_in_date domestic_violence_victim  \
# Personal ID
# 214224                           NaT                    False
# 194592                           NaT                    False
# 179384                           NaT                    False
# 183019                           NaT                    False
# 182885                           NaT                    False
#
#             months_ago_dv_occurred dv_currently_fleeing  days_enrolled  \
# Personal ID
# 214224                         NaN                False            616
# 194592                         NaN                False            607
# 179384                         NaN                False           1486
# 183019                         NaN                False            297
# 182885                         NaN                False            484
#
#              days_to_residential_move_in head_of_household noncash_benefit  \
# Personal ID
# 214224                               NaN             False            None
# 194592                               NaN             False      foodstamps
# 179384                               NaN              True            None
# 183019                               NaN             False            None
# 182885                               NaN             False            None
#
#             disability_type    project_type_code  race_other  race_pacificisl  \
# Personal ID
# 214224             physical  transitionalhousing           0                0
# 194592         mentalhealth                other           0                0
# 179384                 None         servicesonly           0                0
# 183019                 None         servicesonly           0                0
# 182885                 None         servicesonly           0                0
#
#              race_black  race_asian  race_unknown  race_amerindian  \
# Personal ID
# 214224                0           0             0                0
# 194592                0           0             0                0
# 179384                0           0             0                0
# 183019                0           0             0                0
# 182885                1           0             0                0
#
#              race_white  ethnicity_nonlatino  ethnicity_unknown  \
# Personal ID
# 214224                1                    1                  0
# 194592                1                    1                  0
# 179384                1                    0                  0
# 183019                1                    0                  0
# 182885                0                    1                  0
#
#              ethnicity_latino  gender_transftom  gender_transmtof  \
# Personal ID
# 214224                      0                 0                 0
# 194592                      0                 0                 0
# 179384                      1                 0                 0
# 183019                      1                 0                 0
# 182885                      0                 0                 0
#
#              gender_male  gender_female  gender_other  gender_unknown  \
# Personal ID
# 214224                 1              0             0               0
# 194592                 1              0             0               0
# 179384                 0              1             0               0
# 183019                 1              0             0               0
# 182885                 1              0             0               0
#
#              housing_status_project_start_cat4fleeingdv  \
# Personal ID
# 214224                                                0
# 194592                                                0
# 179384                                                0
# 183019                                                0
# 182885                                                0
#
#              housing_status_project_start_unknown  \
# Personal ID
# 214224                                          0
# 194592                                          0
# 179384                                          0
# 183019                                          0
# 182885                                          0
#
#              housing_status_project_start_cat1homeless  \
# Personal ID
# 214224                                               1
# 194592                                               1
# 179384                                               1
# 183019                                               1
# 182885                                               1
#
#              housing_status_project_start_cat2risklosing  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
# 183019                                                 0
# 182885                                                 0
#
#              housing_status_project_start_cat3homelessfedstatutes  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              housing_status_project_start_atrisk  \
# Personal ID
# 214224                                         0
# 194592                                         0
# 179384                                         0
# 183019                                         0
# 182885                                         0
#
#              housing_status_project_start_housed  \
# Personal ID
# 214224                                         0
# 194592                                         0
# 179384                                         0
# 183019                                         0
# 182885                                         0
#
#              living_situation_before_program_entry_unknown  \
# Personal ID
# 214224                                                   0
# 194592                                                   0
# 179384                                                   0
# 183019                                                   0
# 182885                                                   0
#
#              living_situation_before_program_entry_permanenthousing  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_rentalvash  \
# Personal ID
# 214224                                                      0
# 194592                                                      0
# 179384                                                      0
# 183019                                                      0
# 182885                                                      0
#
#              living_situation_before_program_entry_hotel  \
# Personal ID
# 214224                                                 1
# 194592                                                 0
# 179384                                                 0
# 183019                                                 0
# 182885                                                 0
#
#              living_situation_before_program_entry_family  \
# Personal ID
# 214224                                                  0
# 194592                                                  1
# 179384                                                  0
# 183019                                                  0
# 182885                                                  0
#
#              living_situation_before_program_entry_friend  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
# 183019                                                  0
# 182885                                                  0
#
#              living_situation_before_program_entry_streets  \
# Personal ID
# 214224                                                   0
# 194592                                                   0
# 179384                                                   1
# 183019                                                   1
# 182885                                                   0
#
#              living_situation_before_program_entry_owned  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
# 183019                                                 0
# 182885                                                 0
#
#              living_situation_before_program_entry_detoxcenter  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_safehaven  \
# Personal ID
# 214224                                                     0
# 194592                                                     0
# 179384                                                     0
# 183019                                                     0
# 182885                                                     0
#
#              living_situation_before_program_entry_hospital  \
# Personal ID
# 214224                                                    0
# 194592                                                    0
# 179384                                                    0
# 183019                                                    0
# 182885                                                    0
#
#              living_situation_before_program_entry_jail  \
# Personal ID
# 214224                                                0
# 194592                                                0
# 179384                                                0
# 183019                                                0
# 182885                                                0
#
#              living_situation_before_program_entry_rentalother  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_transitionalhousing  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_rental  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
# 183019                                                  0
# 182885                                                  0
#
#              living_situation_before_program_entry_other  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
# 183019                                                 0
# 182885                                                 0
#
#              living_situation_before_program_entry_rentalgdptip  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_ownedsubsidy  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_longtermcare  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_hospitalpsych  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_foster  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
# 183019                                                  0
# 182885                                                  0
#
#              living_situation_before_program_entry_halfwayhouse  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       0
#
#              living_situation_before_program_entry_emershelter  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
# 183019                                                       0
# 182885                                                       1
#
#              noncash_benefit_tanfchildcare  noncash_benefit_publichousing  \
# Personal ID
# 214224                                   0                              0
# 194592                                   0                              0
# 179384                                   0                              0
# 183019                                   0                              0
# 182885                                   0                              0
#
#              noncash_benefit_foodstamps  noncash_benefit_tanfother  \
# Personal ID
# 214224                                0                          0
# 194592                                1                          0
# 179384                                0                          0
# 183019                                0                          0
# 182885                                0                          0
#
#              noncash_benefit_none  noncash_benefit_tanftransportation  \
# Personal ID
# 214224                          1                                   0
# 194592                          0                                   0
# 179384                          1                                   0
# 183019                          1                                   0
# 182885                          1                                   0
#
#              noncash_benefit_other  noncash_benefit_wic  \
# Personal ID
# 214224                           0                    0
# 194592                           0                    0
# 179384                           0                    0
# 183019                           0                    0
# 182885                           0                    0
#
#              noncash_benefit_temprental  disability_type_alcohol  \
# Personal ID
# 214224                                0                        0
# 194592                                0                        0
# 179384                                0                        0
# 183019                                0                        0
# 182885                                0                        0
#
#              disability_type_substance  disability_type_mentalhealth  \
# Personal ID
# 214224                               0                             0
# 194592                               0                             1
# 179384                               0                             0
# 183019                               0                             0
# 182885                               0                             0
#
#              disability_type_hivaids  disability_type_developmental  \
# Personal ID
# 214224                             0                              0
# 194592                             0                              0
# 179384                             0                              0
# 183019                             0                              0
# 182885                             0                              0
#
#              disability_type_drug  disability_type_alcoholdrug  \
# Personal ID
# 214224                          0                            0
# 194592                          0                            0
# 179384                          0                            0
# 183019                          0                            0
# 182885                          0                            0
#
#              disability_type_none  disability_type_physical  \
# Personal ID
# 214224                          0                         1
# 194592                          0                         0
# 179384                          1                         0
# 183019                          1                         0
# 182885                          1                         0
#
#              disability_type_chronichealth  \
# Personal ID
# 214224                                   0
# 194592                                   0
# 179384                                   0
# 183019                                   0
# 182885                                   0
#
#              project_type_code_emergencyshelter  project_type_code_other  \
# Personal ID
# 214224                                        0                        0
# 194592                                        0                        1
# 179384                                        0                        0
# 183019                                        0                        0
# 182885                                        0                        0
#
#              project_type_code_streetoutreach  project_type_code_servicesonly  \
# Personal ID
# 214224                                      0                               0
# 194592                                      0                               0
# 179384                                      0                               1
# 183019                                      0                               1
# 182885                                      0                               1
#
#              project_type_code_rapidrehousing  \
# Personal ID
# 214224                                      0
# 194592                                      0
# 179384                                      0
# 183019                                      0
# 182885                                      0
#
#              project_type_code_transitionalhousing  \
# Personal ID
# 214224                                           1
# 194592                                           0
# 179384                                           0
# 183019                                           0
# 182885                                           0
#
#              project_type_code_permanentsupportivehousing  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
# 183019                                                  0
# 182885                                                  0
#
#              project_type_code_homelessnessprevention
# Personal ID
# 214224                                              0
# 194592                                              0
# 179384                                              0
# 183019                                              0
# 182885                                              0

# %%
df = df.drop(features_one_hot, axis=1)

# %%
df.shape
# Out:
# (58209, 90)

# %%
# save it for easy loading
filename = os.path.join(os.getenv('HOME'), 'Dropbox', 'C4SF-datasci-homeless', 'processed', 'homeless_row_per_enrollment_one_hot_encode.csv')
df.to_csv(filename)

# %%
# set up to count the number of times a person was in the system
df['enrollments'] = 1

# for each person, calculate the mean for their one-hot encoded features
agg_one_hot = {}
for col in cols:
    agg_one_hot[col] = 'mean'

# create feature vectors for each person by subselecting or aggregating their enrollments;
# one row per person
agg = {
    # binary
    'veteran_status': 'max',
    'disabling_condition': 'max',
    'continuously_homeless_one_year': 'max',
    'chronic_homeless': 'max',
    'domestic_violence_victim': 'max',
    'dv_currently_fleeing': 'max',
    'head_of_household': 'max',
    # quantitative
    'enrollments': 'sum',
    'client_age_at_entry': 'last',
    'times_homeless_past_three_years': 'last',
    'months_homeless_this_time': 'last',
    'months_ago_dv_occurred': 'last',
    'days_enrolled': 'sum',
    #     # categorical
    #     'race': 'first',
    #     'ethnicity': 'first',
    #     'gender': 'first',
    #     'housing_status_project_start': 'last',
    #     'living_situation_before_program_entry': 'last',
    #     'non_cash_benefit': 'last',
    #     'disability_type': 'last',
    #     'project_type_code': 'last',
    # outcome related
    'in_permanent_housing': 'last',
    'days_to_residential_move_in': 'last',
    }
agg.update(agg_one_hot)
df_features = df.reset_index().groupby(by=['Personal ID']).agg(agg)

# convert booleans to integers
for col in features_binary:
    df_features[col] = df_features[col].astype(int)

# %%
# number of people in the dataset
df_features.shape
# Out:
# (11362, 88)

# %%
# glance at the data
df_features.head()
# Out:
#              race_unknown  \
# Personal ID
# 173781                  0
# 173782                  0
# 173783                  0
# 173803                  0
# 173804                  0
#
#              living_situation_before_program_entry_transitionalhousing  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              client_age_at_entry  months_ago_dv_occurred  \
# Personal ID
# 173781                        35                    12.0
# 173782                        10                    12.0
# 173783                        12                    12.0
# 173803                        32                    12.0
# 173804                        11                     NaN
#
#              disability_type_substance  \
# Personal ID
# 173781                               0
# 173782                               0
# 173783                               0
# 173803                               0
# 173804                               0
#
#              housing_status_project_start_cat1homeless  disability_type_none  \
# Personal ID
# 173781                                             0.5                     1
# 173782                                             1.0                     1
# 173783                                             1.0                     1
# 173803                                             1.0                     1
# 173804                                             1.0                     1
#
#              living_situation_before_program_entry_rental  race_amerindian  \
# Personal ID
# 173781                                                0.5                0
# 173782                                                0.0                0
# 173783                                                0.0                0
# 173803                                                0.0                0
# 173804                                                0.0                0
#
#              ethnicity_unknown  gender_transmtof  ethnicity_latino  \
# Personal ID
# 173781                       0                 0                 1
# 173782                       0                 0                 1
# 173783                       0                 0                 1
# 173803                       0                 0                 1
# 173804                       0                 0                 1
#
#              living_situation_before_program_entry_emershelter  \
# Personal ID
# 173781                                                     0.5
# 173782                                                     1.0
# 173783                                                     1.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              project_type_code_homelessnessprevention  \
# Personal ID
# 173781                                            0.0
# 173782                                            0.0
# 173783                                            0.0
# 173803                                            0.0
# 173804                                            0.0
#
#              noncash_benefit_publichousing  race_other  \
# Personal ID
# 173781                                   0           0
# 173782                                   0           0
# 173783                                   0           0
# 173803                                   0           0
# 173804                                   0           0
#
#              continuously_homeless_one_year  race_asian  \
# Personal ID
# 173781                                    0           0
# 173782                                    1           0
# 173783                                    1           0
# 173803                                    0           0
# 173804                                    0           0
#
#              noncash_benefit_tanfchildcare  gender_male  \
# Personal ID
# 173781                                   0            0
# 173782                                   0            1
# 173783                                   0            0
# 173803                                   0            0
# 173804                                   0            0
#
#              living_situation_before_program_entry_rentalgdptip  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              disability_type_chronichealth  project_type_code_rapidrehousing  \
# Personal ID
# 173781                                   0                               0.0
# 173782                                   0                               0.0
# 173783                                   0                               0.0
# 173803                                   0                               0.0
# 173804                                   0                               0.0
#
#              noncash_benefit_temprental  race_black  veteran_status  \
# Personal ID
# 173781                                0           0               0
# 173782                                0           0               0
# 173783                                0           0               0
# 173803                                0           0               0
# 173804                                0           0               0
#
#              noncash_benefit_tanftransportation  \
# Personal ID
# 173781                                        0
# 173782                                        0
# 173783                                        0
# 173803                                        0
# 173804                                        0
#
#              living_situation_before_program_entry_longtermcare  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              dv_currently_fleeing  \
# Personal ID
# 173781                          0
# 173782                          0
# 173783                          0
# 173803                          0
# 173804                          0
#
#              living_situation_before_program_entry_rentalother  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              living_situation_before_program_entry_hospitalpsych  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              housing_status_project_start_cat2risklosing  \
# Personal ID
# 173781                                               0.0
# 173782                                               0.0
# 173783                                               0.0
# 173803                                               0.0
# 173804                                               0.0
#
#              project_type_code_transitionalhousing  in_permanent_housing  \
# Personal ID
# 173781                                         0.0                     0
# 173782                                         0.0                     0
# 173783                                         0.0                     0
# 173803                                         0.0                     0
# 173804                                         0.0                     0
#
#              gender_other  noncash_benefit_other  head_of_household  \
# Personal ID
# 173781                  0                      0                  0
# 173782                  0                      0                  0
# 173783                  0                      0                  0
# 173803                  0                      0                  0
# 173804                  0                      0                  0
#
#              living_situation_before_program_entry_hotel  \
# Personal ID
# 173781                                               0.0
# 173782                                               0.0
# 173783                                               0.0
# 173803                                               0.0
# 173804                                               0.0
#
#              living_situation_before_program_entry_permanenthousing  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              living_situation_before_program_entry_friend  \
# Personal ID
# 173781                                                0.0
# 173782                                                0.0
# 173783                                                0.0
# 173803                                                1.0
# 173804                                                1.0
#
#              noncash_benefit_none  \
# Personal ID
# 173781                          0
# 173782                          1
# 173783                          1
# 173803                          0
# 173804                          1
#
#              living_situation_before_program_entry_safehaven  race_white  \
# Personal ID
# 173781                                                   0.0           1
# 173782                                                   0.0           1
# 173783                                                   0.0           1
# 173803                                                   0.0           1
# 173804                                                   0.0           1
#
#              disability_type_alcohol  noncash_benefit_tanfother  \
# Personal ID
# 173781                             0                          0
# 173782                             0                          0
# 173783                             0                          0
# 173803                             0                          0
# 173804                             0                          0
#
#              disability_type_physical  project_type_code_emergencyshelter  \
# Personal ID
# 173781                              0                                 0.5
# 173782                              0                                 1.0
# 173783                              0                                 1.0
# 173803                              0                                 1.0
# 173804                              0                                 1.0
#
#              gender_transftom  enrollments  times_homeless_past_three_years  \
# Personal ID
# 173781                      0            2                              2.0
# 173782                      0            1                              2.0
# 173783                      0            1                              2.0
# 173803                      0            1                              NaN
# 173804                      0            1                              NaN
#
#              living_situation_before_program_entry_streets  \
# Personal ID
# 173781                                                 0.0
# 173782                                                 0.0
# 173783                                                 0.0
# 173803                                                 0.0
# 173804                                                 0.0
#
#              days_to_residential_move_in  \
# Personal ID
# 173781                               NaN
# 173782                               NaN
# 173783                               NaN
# 173803                               NaN
# 173804                               NaN
#
#              housing_status_project_start_cat4fleeingdv  \
# Personal ID
# 173781                                              0.0
# 173782                                              0.0
# 173783                                              0.0
# 173803                                              0.0
# 173804                                              0.0
#
#              living_situation_before_program_entry_unknown  \
# Personal ID
# 173781                                                 0.0
# 173782                                                 0.0
# 173783                                                 0.0
# 173803                                                 0.0
# 173804                                                 0.0
#
#              living_situation_before_program_entry_detoxcenter  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              living_situation_before_program_entry_ownedsubsidy  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              chronic_homeless  \
# Personal ID
# 173781                      0
# 173782                      0
# 173783                      0
# 173803                      0
# 173804                      0
#
#              living_situation_before_program_entry_halfwayhouse  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              housing_status_project_start_cat3homelessfedstatutes  \
# Personal ID
# 173781                                                     0.0
# 173782                                                     0.0
# 173783                                                     0.0
# 173803                                                     0.0
# 173804                                                     0.0
#
#              housing_status_project_start_atrisk  \
# Personal ID
# 173781                                       0.5
# 173782                                       0.0
# 173783                                       0.0
# 173803                                       0.0
# 173804                                       0.0
#
#              living_situation_before_program_entry_family  \
# Personal ID
# 173781                                                0.0
# 173782                                                0.0
# 173783                                                0.0
# 173803                                                0.0
# 173804                                                0.0
#
#              months_homeless_this_time  ethnicity_nonlatino  \
# Personal ID
# 173781                             NaN                    0
# 173782                             NaN                    0
# 173783                             NaN                    0
# 173803                             NaN                    0
# 173804                             NaN                    0
#
#              project_type_code_permanentsupportivehousing  \
# Personal ID
# 173781                                                0.0
# 173782                                                0.0
# 173783                                                0.0
# 173803                                                0.0
# 173804                                                0.0
#
#              living_situation_before_program_entry_hospital  \
# Personal ID
# 173781                                                  0.0
# 173782                                                  0.0
# 173783                                                  0.0
# 173803                                                  0.0
# 173804                                                  0.0
#
#              project_type_code_streetoutreach  disability_type_developmental  \
# Personal ID
# 173781                                    0.5                              0
# 173782                                    0.0                              0
# 173783                                    0.0                              0
# 173803                                    0.0                              0
# 173804                                    0.0                              0
#
#              housing_status_project_start_unknown  \
# Personal ID
# 173781                                        0.0
# 173782                                        0.0
# 173783                                        0.0
# 173803                                        0.0
# 173804                                        0.0
#
#              living_situation_before_program_entry_rentalvash  \
# Personal ID
# 173781                                                    0.0
# 173782                                                    0.0
# 173783                                                    0.0
# 173803                                                    0.0
# 173804                                                    0.0
#
#              housing_status_project_start_housed  gender_unknown  \
# Personal ID
# 173781                                       0.0               0
# 173782                                       0.0               0
# 173783                                       0.0               0
# 173803                                       0.0               0
# 173804                                       0.0               0
#
#              disability_type_hivaids  \
# Personal ID
# 173781                             0
# 173782                             0
# 173783                             0
# 173803                             0
# 173804                             0
#
#              living_situation_before_program_entry_other  \
# Personal ID
# 173781                                               0.0
# 173782                                               0.0
# 173783                                               0.0
# 173803                                               0.0
# 173804                                               0.0
#
#              domestic_violence_victim  noncash_benefit_wic  \
# Personal ID
# 173781                              1                    0
# 173782                              1                    0
# 173783                              1                    0
# 173803                              1                    0
# 173804                              0                    0
#
#              living_situation_before_program_entry_owned  \
# Personal ID
# 173781                                               0.0
# 173782                                               0.0
# 173783                                               0.0
# 173803                                               0.0
# 173804                                               0.0
#
#              project_type_code_other  disability_type_mentalhealth  \
# Personal ID
# 173781                           0.0                             0
# 173782                           0.0                             0
# 173783                           0.0                             0
# 173803                           0.0                             0
# 173804                           0.0                             0
#
#              disability_type_drug  gender_female  \
# Personal ID
# 173781                          0              1
# 173782                          0              0
# 173783                          0              1
# 173803                          0              1
# 173804                          0              1
#
#              living_situation_before_program_entry_foster  race_pacificisl  \
# Personal ID
# 173781                                                0.0                0
# 173782                                                0.0                0
# 173783                                                0.0                0
# 173803                                                0.0                0
# 173804                                                0.0                0
#
#              noncash_benefit_foodstamps  disabling_condition  \
# Personal ID
# 173781                                1                    0
# 173782                                0                    0
# 173783                                0                    0
# 173803                                1                    0
# 173804                                0                    0
#
#              project_type_code_servicesonly  days_enrolled  \
# Personal ID
# 173781                                  0.0            147
# 173782                                  0.0            147
# 173783                                  0.0            147
# 173803                                  0.0             78
# 173804                                  0.0             78
#
#              living_situation_before_program_entry_jail  \
# Personal ID
# 173781                                              0.0
# 173782                                              0.0
# 173783                                              0.0
# 173803                                              0.0
# 173804                                              0.0
#
#              disability_type_alcoholdrug
# Personal ID
# 173781                                 0
# 173782                                 0
# 173783                                 0
# 173803                                 0
# 173804                                 0

# %%
df_features[sorted(df_features.columns)].describe()
# Out:
#        chronic_homeless  client_age_at_entry  continuously_homeless_one_year  \
# count      11362.000000         11362.000000                    11362.000000
# mean           0.059849            33.622250                        0.185443
# std            0.237217            20.246602                        0.388673
# min            0.000000             0.000000                        0.000000
# 25%            0.000000            16.000000                        0.000000
# 50%            0.000000            34.000000                        0.000000
# 75%            0.000000            51.000000                        0.000000
# max            1.000000           101.000000                        1.000000
#
#        days_enrolled  days_to_residential_move_in  disability_type_alcohol  \
# count   11362.000000                   747.000000             11362.000000
# mean      207.853459                    72.552878                 0.027196
# std       330.189494                    81.557515                 0.162661
# min         0.000000                     1.000000                 0.000000
# 25%        26.000000                    16.000000                 0.000000
# 50%        96.000000                    48.000000                 0.000000
# 75%       258.000000                    97.000000                 0.000000
# max      5040.000000                   730.000000                 1.000000
#
#        disability_type_alcoholdrug  disability_type_chronichealth  \
# count                 11362.000000                   11362.000000
# mean                      0.038021                       0.058704
# std                       0.191257                       0.235081
# min                       0.000000                       0.000000
# 25%                       0.000000                       0.000000
# 50%                       0.000000                       0.000000
# 75%                       0.000000                       0.000000
# max                       1.000000                       1.000000
#
#        disability_type_developmental  disability_type_drug  \
# count                   11362.000000          11362.000000
# mean                        0.012322              0.019275
# std                         0.110322              0.137495
# min                         0.000000              0.000000
# 25%                         0.000000              0.000000
# 50%                         0.000000              0.000000
# 75%                         0.000000              0.000000
# max                         1.000000              1.000000
#
#        disability_type_hivaids  disability_type_mentalhealth  \
# count             11362.000000                  11362.000000
# mean                  0.014082                      0.049375
# std                   0.117834                      0.216660
# min                   0.000000                      0.000000
# 25%                   0.000000                      0.000000
# 50%                   0.000000                      0.000000
# 75%                   0.000000                      0.000000
# max                   1.000000                      1.000000
#
#        disability_type_none  disability_type_physical  \
# count          11362.000000              11362.000000
# mean               0.748108                  0.032741
# std                0.434119                  0.177965
# min                0.000000                  0.000000
# 25%                0.000000                  0.000000
# 50%                1.000000                  0.000000
# 75%                1.000000                  0.000000
# max                1.000000                  1.000000
#
#        disability_type_substance  disabling_condition  \
# count               11362.000000         11362.000000
# mean                    0.000176             0.390512
# std                     0.013267             0.487887
# min                     0.000000             0.000000
# 25%                     0.000000             0.000000
# 50%                     0.000000             0.000000
# 75%                     0.000000             1.000000
# max                     1.000000             1.000000
#
#        domestic_violence_victim  dv_currently_fleeing   enrollments  \
# count              11362.000000          11362.000000  11362.000000
# mean                   0.183154              0.001672      5.123130
# std                    0.386810              0.040861     18.586563
# min                    0.000000              0.000000      1.000000
# 25%                    0.000000              0.000000      1.000000
# 50%                    0.000000              0.000000      2.000000
# 75%                    0.000000              0.000000      2.000000
# max                    1.000000              1.000000    577.000000
#
#        ethnicity_latino  ethnicity_nonlatino  ethnicity_unknown  \
# count      11362.000000         11362.000000       11362.000000
# mean           0.458282             0.521827           0.019891
# std            0.498278             0.499545           0.139631
# min            0.000000             0.000000           0.000000
# 25%            0.000000             0.000000           0.000000
# 50%            0.000000             1.000000           0.000000
# 75%            1.000000             1.000000           0.000000
# max            1.000000             1.000000           1.000000
#
#        gender_female   gender_male  gender_other  gender_transftom  \
# count   11362.000000  11362.000000  11362.000000      11362.000000
# mean        0.424749      0.571642      0.000440          0.000704
# std         0.494327      0.494863      0.020974          0.026527
# min         0.000000      0.000000      0.000000          0.000000
# 25%         0.000000      0.000000      0.000000          0.000000
# 50%         0.000000      1.000000      0.000000          0.000000
# 75%         1.000000      1.000000      0.000000          0.000000
# max         1.000000      1.000000      1.000000          1.000000
#
#        gender_transmtof  gender_unknown  head_of_household  \
# count      11362.000000    11362.000000       11362.000000
# mean           0.001936        0.000528           0.409347
# std            0.043962        0.022975           0.491735
# min            0.000000        0.000000           0.000000
# 25%            0.000000        0.000000           0.000000
# 50%            0.000000        0.000000           0.000000
# 75%            0.000000        0.000000           1.000000
# max            1.000000        1.000000           1.000000
#
#        housing_status_project_start_atrisk  \
# count                         11362.000000
# mean                              0.040058
# std                               0.188670
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        housing_status_project_start_cat1homeless  \
# count                               11362.000000
# mean                                    0.637567
# std                                     0.467006
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     1.000000
# 75%                                     1.000000
# max                                     1.000000
#
#        housing_status_project_start_cat2risklosing  \
# count                                 11362.000000
# mean                                      0.138795
# std                                       0.338497
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        housing_status_project_start_cat3homelessfedstatutes  \
# count                                       11362.000000
# mean                                            0.000668
# std                                             0.024080
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        housing_status_project_start_cat4fleeingdv  \
# count                                11362.000000
# mean                                     0.002992
# std                                      0.053675
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        housing_status_project_start_housed  \
# count                         11362.000000
# mean                              0.067985
# std                               0.238917
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               1.000000
#
#        housing_status_project_start_unknown  in_permanent_housing  \
# count                          11362.000000          11362.000000
# mean                               0.111934              0.101039
# std                                0.306790              0.301393
# min                                0.000000              0.000000
# 25%                                0.000000              0.000000
# 50%                                0.000000              0.000000
# 75%                                0.000000              0.000000
# max                                1.000000              1.000000
#
#        living_situation_before_program_entry_detoxcenter  \
# count                                       11362.000000
# mean                                            0.021072
# std                                             0.138403
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_emershelter  \
# count                                       11362.000000
# mean                                            0.127916
# std                                             0.318047
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_family  \
# count                                  11362.000000
# mean                                       0.139699
# std                                        0.339390
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        living_situation_before_program_entry_foster  \
# count                                  11362.000000
# mean                                       0.003000
# std                                        0.053441
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        living_situation_before_program_entry_friend  \
# count                                  11362.000000
# mean                                       0.074934
# std                                        0.254198
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        living_situation_before_program_entry_halfwayhouse  \
# count                                       11362.000000
# mean                                            0.001227
# std                                             0.033638
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_hospital  \
# count                                    11362.000000
# mean                                         0.009835
# std                                          0.095248
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        living_situation_before_program_entry_hospitalpsych  \
# count                                       11362.000000
# mean                                            0.007196
# std                                             0.079153
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_hotel  \
# count                                 11362.000000
# mean                                      0.048752
# std                                       0.208796
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        living_situation_before_program_entry_jail  \
# count                                11362.000000
# mean                                     0.008951
# std                                      0.090282
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      1.000000
#
#        living_situation_before_program_entry_longtermcare  \
# count                                       11362.000000
# mean                                            0.000198
# std                                             0.013472
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_other  \
# count                                 11362.000000
# mean                                      0.024681
# std                                       0.149394
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        living_situation_before_program_entry_owned  \
# count                                 11362.000000
# mean                                      0.004601
# std                                       0.066101
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        living_situation_before_program_entry_ownedsubsidy  \
# count                                       11362.000000
# mean                                            0.000502
# std                                             0.020654
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_permanenthousing  \
# count                                       11362.000000
# mean                                            0.002629
# std                                             0.048399
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_rental  \
# count                                  11362.000000
# mean                                       0.168741
# std                                        0.367939
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        living_situation_before_program_entry_rentalgdptip  \
# count                                       11362.000000
# mean                                            0.000088
# std                                             0.009382
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_rentalother  \
# count                                       11362.000000
# mean                                            0.025968
# std                                             0.155115
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_rentalvash  \
# count                                      11362.000000
# mean                                           0.015308
# std                                            0.113651
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                            1.000000
#
#        living_situation_before_program_entry_safehaven  \
# count                                     11362.000000
# mean                                          0.004257
# std                                           0.062561
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        living_situation_before_program_entry_streets  \
# count                                   11362.000000
# mean                                        0.189169
# std                                         0.378361
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                         1.000000
#
#        living_situation_before_program_entry_transitionalhousing  \
# count                                       11362.000000
# mean                                            0.038544
# std                                             0.181653
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_unknown  months_ago_dv_occurred  \
# count                                   11362.000000             1910.000000
# mean                                        0.082733               16.102618
# std                                         0.265918                9.192029
# min                                         0.000000                3.000000
# 25%                                         0.000000                6.000000
# 50%                                         0.000000               24.000000
# 75%                                         0.000000               24.000000
# max                                         1.000000               24.000000
#
#        months_homeless_this_time  noncash_benefit_foodstamps  \
# count                1726.000000                11362.000000
# mean                    6.976246                    0.251364
# std                     9.969520                    0.433817
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     1.000000                    0.000000
# 75%                    12.000000                    1.000000
# max                    24.000000                    1.000000
#
#        noncash_benefit_none  noncash_benefit_other  \
# count          11362.000000           11362.000000
# mean               0.707446               0.012850
# std                0.454955               0.112631
# min                0.000000               0.000000
# 25%                0.000000               0.000000
# 50%                1.000000               0.000000
# 75%                1.000000               0.000000
# max                1.000000               1.000000
#
#        noncash_benefit_publichousing  noncash_benefit_tanfchildcare  \
# count                   11362.000000                   11362.000000
# mean                        0.009505                       0.001496
# std                         0.097035                       0.038654
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                         1.000000                       1.000000
#
#        noncash_benefit_tanfother  noncash_benefit_tanftransportation  \
# count               11362.000000                        11362.000000
# mean                    0.002552                            0.000880
# std                     0.050459                            0.029655
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     0.000000                            0.000000
# 75%                     0.000000                            0.000000
# max                     1.000000                            1.000000
#
#        noncash_benefit_temprental  noncash_benefit_wic  \
# count                11362.000000         11362.000000
# mean                     0.000264             0.013642
# std                      0.016248             0.116005
# min                      0.000000             0.000000
# 25%                      0.000000             0.000000
# 50%                      0.000000             0.000000
# 75%                      0.000000             0.000000
# max                      1.000000             1.000000
#
#        project_type_code_emergencyshelter  \
# count                        11362.000000
# mean                             0.385074
# std                              0.465628
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              1.000000
# max                              1.000000
#
#        project_type_code_homelessnessprevention  project_type_code_other  \
# count                              11362.000000             11362.000000
# mean                                   0.130945                 0.078596
# std                                    0.327913                 0.251764
# min                                    0.000000                 0.000000
# 25%                                    0.000000                 0.000000
# 50%                                    0.000000                 0.000000
# 75%                                    0.000000                 0.000000
# max                                    1.000000                 1.000000
#
#        project_type_code_permanentsupportivehousing  \
# count                                  11362.000000
# mean                                       0.005743
# std                                        0.068417
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        1.000000
#
#        project_type_code_rapidrehousing  project_type_code_servicesonly  \
# count                      11362.000000                    11362.000000
# mean                           0.076366                        0.173960
# std                            0.250502                        0.366711
# min                            0.000000                        0.000000
# 25%                            0.000000                        0.000000
# 50%                            0.000000                        0.000000
# 75%                            0.000000                        0.000000
# max                            1.000000                        1.000000
#
#        project_type_code_streetoutreach  \
# count                      11362.000000
# mean                           0.055596
# std                            0.217953
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.000000
#
#        project_type_code_transitionalhousing  race_amerindian    race_asian  \
# count                           11362.000000     11362.000000  11362.000000
# mean                                0.093721         0.064601      0.020419
# std                                 0.270303         0.245832      0.141435
# min                                 0.000000         0.000000      0.000000
# 25%                                 0.000000         0.000000      0.000000
# 50%                                 0.000000         0.000000      0.000000
# 75%                                 0.000000         0.000000      0.000000
# max                                 1.000000         1.000000      1.000000
#
#          race_black    race_other  race_pacificisl  race_unknown  \
# count  11362.000000  11362.000000     11362.000000  11362.000000
# mean       0.107551      0.001232         0.015842      0.020243
# std        0.309827      0.035082         0.124871      0.140836
# min        0.000000      0.000000         0.000000      0.000000
# 25%        0.000000      0.000000         0.000000      0.000000
# 50%        0.000000      0.000000         0.000000      0.000000
# 75%        0.000000      0.000000         0.000000      0.000000
# max        1.000000      1.000000         1.000000      1.000000
#
#          race_white  times_homeless_past_three_years  veteran_status
# count  11362.000000                      5202.000000    11362.000000
# mean       0.770111                         1.346790        0.192836
# std        0.420780                         1.122937        0.394543
# min        0.000000                         0.000000        0.000000
# 25%        1.000000                         1.000000        0.000000
# 50%        1.000000                         1.000000        0.000000
# 75%        1.000000                         2.000000        0.000000
# max        1.000000                         4.000000        1.000000
