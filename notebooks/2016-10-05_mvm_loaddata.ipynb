# %% [markdown]
# Code for San Francisco
#
# # CTA Homelessness data
#
# ## Purpose
#
# The purpose of this notebook is to load in the sample data. Each sheet from the Excel file was saved out to a CSV with the corresponding name.
#
# - Author: Matt Mollison
# - Date: 2016-10-05

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# # the "1" means: always reload modules marked with "%aimport"
# %autoreload 1

from __future__ import absolute_import, division, print_function
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os, sys
# from tqdm import tqdm
# import warnings

sns.set_context("poster", font_scale=1.3)

# %%
pd.set_option('display.max_columns', 100)

# %%
# Example for adding path
# write code in ../source and add that to runtime path
# src_dir = os.path.join(os.getcwd(), os.pardir, '../source')
# sys.path.append(src_dir)

# Import like so
# # import my_module from the source directory
# %aimport my_module
# from my_module.build_features import remove_invalid_data

# %%
# where the data is stored
datadir = os.path.join(os.getenv('HOME'), 'data/DATA_CTA/SampleDataSet-MOSBE&SCz-2012-1001--2016-0531/USE THIS ONE/')

# %%
sheet = 'Client'

cols = [
    'Personal ID',
    'Race',
    'Ethnicity',
    'Gender',
    'Veteran Status',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_client = pd.read_csv(infile, header=0, index_col=0, usecols=cols)
df_client = df_client.dropna(how='all')

# drop people that we don't have demographic information for
df_client = df_client.dropna(how='any', subset=['Race', 'Ethnicity', 'Gender'])

# fill in missing values
df_client['Veteran Status'] = df_client['Veteran Status'].fillna(value='')

# Remove "(HUD) from strings
cols = ['Race', 'Ethnicity', 'Veteran Status']
for col in cols:
    df_client[col] = df_client[col].apply(lambda x: x.replace(' (HUD)', ''))

# put the nans back
df_client.loc[df_client['Veteran Status'] == '', 'Veteran Status'] = np.nan

# and encode booleans
col = 'Veteran Status'
df_client.loc[df_client[col] == 'Yes', col] = True
df_client.loc[df_client[col] == 'No', col] = False
df_client.loc[df_client[col] == 'Not Applicable - Child', col] = False
df_client.loc[df_client[col] == 'Client refused', col] = np.nan
df_client.loc[df_client[col] == "Client doesn't know", col] = np.nan
df_client.loc[df_client[col] == 'Data not collected', col] = np.nan

# %%
df_client.head()
# Out:
#                                   Race                Ethnicity  Gender  \
# Personal ID
# 173781                           White          Hispanic/Latino  Female
# 173782                           White          Hispanic/Latino    Male
# 173783                           White          Hispanic/Latino  Female
# 173800       Black or African American  Non-Hispanic/Non-Latino  Female
# 173803                           White          Hispanic/Latino  Female
#
#             Veteran Status
# Personal ID
# 173781               False
# 173782               False
# 173783               False
# 173800               False
# 173803               False

# %%
sheet = 'Enrollment'

cols = [
    'Personal ID',
    'Project Entry ID',
    'Client Age at Entry',
    'Last Permanent Zip',
    'Entry Date',
    'Exit Date',
    'Project ID',
    'Housing Status @ Project Start',
    'Living situation before program entry?',
    'Client Location',
    'Household ID',
    'Relationship to HoH',
    'Disabling Condition',
    'Continuously Homeless One Year',
    'Times Homeless Past Three Years',
    'Months Homeless This Time',
    'Chronic Homeless',
    'In Permanent Housing',
    'Residential Move In Date',
    'Domestic Violence Victim',
    'DV When Occurred',
    'DV Currently Fleeing',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_enroll = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                        parse_dates=['Entry Date', 'Exit Date', 'Residential Move In Date'],
                        infer_datetime_format=True)

df_enroll = df_enroll.dropna(axis=0, how='all')
# df_enroll.index = df_enroll.index.astype('int')

# drop anyone for whom we don't have age
df_enroll = df_enroll.dropna(subset=['Client Age at Entry'])

# turn these into integers
cols = ['Project Entry ID', 'Client Age at Entry', 'Project ID', 'Household ID']
for col in cols:
    df_enroll[col] = df_enroll[col].astype('int')

# Remove "(HUD) from strings
cols = ['Housing Status @ Project Start',
        'Living situation before program entry?',
        'Disabling Condition',
        'Continuously Homeless One Year',
        'Domestic Violence Victim',
        'DV When Occurred',
        'DV Currently Fleeing',
        ]
for col in cols:
    df_enroll[col] = df_enroll[col].fillna(value='')
    df_enroll[col] = df_enroll[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_enroll.loc[df_enroll[col] == '', col] = np.nan

# encode booleans

# cols = [
#     'Disabling Condition',
#     'Continuously Homeless One Year',
#     'Chronic Homeless',
#     'In Permanent Housing',
#     'Domestic Violence Victim',
#     'DV Currently Fleeing', ]

col = 'Disabling Condition'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False
df_enroll.loc[df_enroll[col] == 'Not Applicable - Child', col] = False
df_enroll.loc[df_enroll[col] == 'Client refused', col] = np.nan
df_enroll.loc[df_enroll[col] == "Client doesn't know", col] = np.nan
df_enroll.loc[df_enroll[col] == 'Data not collected', col] = np.nan

col = 'Continuously Homeless One Year'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False
df_enroll.loc[df_enroll[col] == 'Client refused', col] = np.nan
df_enroll.loc[df_enroll[col] == "Client doesn't know", col] = np.nan
df_enroll.loc[df_enroll[col] == 'Data not collected', col] = np.nan

col = 'Chronic Homeless'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False

col = 'In Permanent Housing'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False

col = 'Domestic Violence Victim'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False
df_enroll.loc[df_enroll[col] == 'Not Applicable - Child', col] = False
df_enroll.loc[df_enroll[col] == 'Client refused', col] = np.nan
df_enroll.loc[df_enroll[col] == "Client doesn't know", col] = np.nan
df_enroll.loc[df_enroll[col] == 'Data not collected', col] = np.nan

col = 'DV Currently Fleeing'
df_enroll.loc[df_enroll[col] == 'Yes', col] = True
df_enroll.loc[df_enroll[col] == 'No', col] = False
df_enroll.loc[df_enroll[col] == 'Client refused', col] = np.nan
df_enroll.loc[df_enroll[col] == "Client doesn't know", col] = np.nan
df_enroll.loc[df_enroll[col] == 'Data not collected', col] = np.nan

# %%
df_enroll.head()
# Out:
#              Project Entry ID  Client Age at Entry Last Permanent Zip  \
# Personal ID
# 173781                 252608                   34              93907
# 173781                 314080                   35              93907
# 173782                 122915                    1                NaN
# 173782                 314084                   10              93905
# 173783                 122916                    2                NaN
#
#             Entry Date  Exit Date  Project ID Housing Status @ Project Start  \
# Personal ID
# 173781      2014-02-28 2014-02-28        2104        At-risk of homelessness
# 173781      2014-05-06 2014-09-30        2101          Category 1 - Homeless
# 173782      2004-11-29        NaT        2114                            NaN
# 173782      2014-05-06 2014-09-30        2101          Category 1 - Homeless
# 173783      2004-11-29        NaT        2114                            NaN
#
#                         Living situation before program entry?  \
# Personal ID
# 173781            Rental by client, no ongoing housing subsidy
# 173781       Emergency shelter, including hotel or motel pa...
# 173782                                                     NaN
# 173782       Emergency shelter, including hotel or motel pa...
# 173783                                                     NaN
#
#             Client Location  Household ID        Relationship to HoH  \
# Personal ID
# 173781                  NaN        252608                        NaN
# 173781               CA-506        314080  Head of household's child
# 173782               CA-506        122914                        NaN
# 173782               CA-506        314080  Head of household's child
# 173783               CA-506        122914                        NaN
#
#             Disabling Condition Continuously Homeless One Year  \
# Personal ID
# 173781                      NaN                            NaN
# 173781                      NaN                          False
# 173782                      NaN                            NaN
# 173782                    False                           True
# 173783                      NaN                            NaN
#
#             Times Homeless Past Three Years Months Homeless This Time  \
# Personal ID
# 173781                                  NaN                       NaN
# 173781                                    2                       NaN
# 173782                                  NaN                       NaN
# 173782                                    2                       NaN
# 173783                                  NaN                       NaN
#
#             Chronic Homeless In Permanent Housing Residential Move In Date  \
# Personal ID
# 173781                 False                  NaN                      NaT
# 173781                 False                  NaN                      NaT
# 173782                 False                  NaN                      NaT
# 173782                 False                  NaN                      NaT
# 173783                 False                  NaN                      NaT
#
#             Domestic Violence Victim               DV When Occurred  \
# Personal ID
# 173781                          True           More than a year ago
# 173781                          True  From six to twelve months ago
# 173782                           NaN                            NaN
# 173782                          True  From six to twelve months ago
# 173783                           NaN                            NaN
#
#             DV Currently Fleeing
# Personal ID
# 173781                       NaN
# 173781                       NaN
# 173782                       NaN
# 173782                       NaN
# 173783                       NaN

# %%
sheet = 'Disability'

cols = [
    'Personal ID',
    'Disability Type',
    'Receiving Services For',
    'Disabilities ID',
    'Project Entry ID',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_disability = pd.read_csv(infile, header=0, index_col=0, usecols=cols)

df_disability = df_disability.dropna(axis=0, how='all')
# df_disability.index = df_disability.index.astype('int')

# turn these into integers
cols = ['Disabilities ID', 'Project Entry ID']
for col in cols:
    df_disability[col] = df_disability[col].astype('int')

# Remove "(HUD) from strings
cols = ['Disability Type',
        'Receiving Services For',
        ]
for col in cols:
    df_disability[col] = df_disability[col].fillna(value='')
    df_disability[col] = df_disability[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_disability.loc[df_disability[col] == '', col] = np.nan

# encode booleans
col = 'Receiving Services For'
df_disability.loc[df_disability[col] == 'Yes', col] = True
df_disability.loc[df_disability[col] == 'No', col] = False
df_disability.loc[df_disability[col] == 'Client refused', col] = np.nan
df_disability.loc[df_disability[col] == "Client doesn't know", col] = np.nan
df_disability.loc[df_disability[col] == 'Data not collected', col] = np.nan

# %%
df_disability.head()
# Out:
#             Disability Type Receiving Services For  Disabilities ID  \
# Personal ID
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
# 173848             Physical                   True           971050
#
#              Project Entry ID
# Personal ID
# 173848                 382788
# 173848                 383070
# 173848                 383336
# 173848                 383701
# 173848                 383839

# %%
sheet = 'HealthInsurance'

cols = [
    'Personal ID',
    'Health Insurance Information Date',
    'Health Insurance',
    'Data Collection Stage',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_healthins = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                           parse_dates=['Health Insurance Information Date'],
                           infer_datetime_format=True)

df_healthins = df_healthins.dropna(axis=0, how='all')
# df_healthins.index = df_healthins.index.astype('int')

# %%
df_healthins.head()
# Out:
#             Health Insurance Information Date  \
# Personal ID
# 173781                             2014-05-06
# 173782                             2014-05-06
# 173783                             2014-05-06
# 173848                             2014-08-22
# 173848                             2014-08-22
#
#                               Health Insurance Data Collection Stage
# Personal ID
# 173781                                MEDICAID         Project Entry
# 173782                                MEDICARE         Project Entry
# 173783                                MEDICAID         Project Entry
# 173848                                MEDICAID         Project Entry
# 173848       State Health Insurance for Adults         Project Entry

# %%
sheet = 'Benefit'

cols = [
    'Personal ID',
    'Non-Cash Benefit',
    'Data Collection Stage',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_benefit = pd.read_csv(infile, header=0, index_col=0, usecols=cols)

df_benefit = df_benefit.dropna(axis=0, how='all')
# df_benefit.index = df_benefit.index.astype('int')

# Drop any project missing the code
df_benefit = df_benefit.dropna(how='any', subset=['Non-Cash Benefit'])

# Remove "(HUD) from strings
cols = ['Non-Cash Benefit',
        ]
for col in cols:
    df_benefit[col] = df_benefit[col].fillna(value='')
    df_benefit[col] = df_benefit[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_benefit.loc[df_benefit[col] == '', col] = np.nan

# %%
df_benefit.head()
# Out:
#                                               Non-Cash Benefit  \
# Personal ID
# 173781       Supplemental Nutrition Assistance Program (Foo...
# 173781       Supplemental Nutrition Assistance Program (Foo...
# 173803       Supplemental Nutrition Assistance Program (Foo...
# 173848       Supplemental Nutrition Assistance Program (Foo...
# 173848       Supplemental Nutrition Assistance Program (Foo...
#
#             Data Collection Stage
# Personal ID
# 173781              Project Entry
# 173781              Project Entry
# 173803              Project Entry
# 173848              Project Entry
# 173848              Project Entry

# %%
# TODO: turn dollar strings into integers, need to account for commas

sheet = 'Income Entry & Exit'

cols = [
    'Personal ID',
    'Project Entry ID',
    'Entry Alimony',
    'Entry Child Support',
    'Entry Earned',
    'Entry GA',
    'Entry Other',
    'Entry Pension',
    'Entry Private Disability',
    'Entry Social Security Retirement',
    'Entry SSDI',
    'Entry SSI',
    'Entry TANF',
    'Entry Unemployment',
    'Entry VA Non-Service',
    'Entry VA Service Connected',
    "Entry Worker's Compensation",
    'Entry Total Income',
    'Exit Alimony',
    'Exit Child Support',
    'Exit Earned',
    'Exit GA',
    'Exit Other',
    'Exit Pension',
    'Exit Private Disability',
    'Exit Social Security Retirement',
    'Exit SSDI',
    'Exit SSI',
    'Exit TANF',
    'Exit Unemployment',
    'Exit VA Non-Service',
    'Exit VA Service Connected',
    "Exit Worker's Compensation",
    'Exit Total Income',
    'Income Change',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_income = pd.read_csv(infile, header=0, index_col=0, usecols=cols)

df_income = df_income.dropna(axis=0, how='all')
# df_income.index = df_income.index.astype('int')

# turn these into integers
cols = ['Project Entry ID']
for col in cols:
    df_income[col] = df_income[col].astype('int')

# assume all nans are $0
df_income = df_income.fillna(value='0')

# turn the dollar strings into integers
for col in df_income.columns:
    if col != 'Project Entry ID':
        df_income[col] = df_income[col].str.replace(',', '')
        df_income[col] = df_income[col].str.replace(r'[^-+\d.]', '').astype(int)

# %%
df_income.head()
# Out:
#              Project Entry ID  Entry Alimony  Entry Child Support  \
# Personal ID
# 173781                 252608              0                    0
# 173781                 314080              0                    0
# 173782                 122915              0                    0
# 173782                 314084              0                    0
# 173783                 122916              0                    0
#
#              Entry Earned  Entry GA  Entry Other  Entry Pension  \
# Personal ID
# 173781                  0         0            0              0
# 173781                  0         0            0              0
# 173782                  0         0            0              0
# 173782                  0         0            0              0
# 173783                  0         0            0              0
#
#              Entry Private Disability  Entry Social Security Retirement  \
# Personal ID
# 173781                              0                                 0
# 173781                              0                                 0
# 173782                              0                                 0
# 173782                              0                                 0
# 173783                              0                                 0
#
#              Entry SSDI  Entry SSI  Entry TANF  Entry Unemployment  \
# Personal ID
# 173781                0          0         607                   0
# 173781                0          0        1143                   0
# 173782                0          0           0                   0
# 173782                0          0           0                   0
# 173783                0          0           0                   0
#
#              Entry VA Non-Service  Entry VA Service Connected  \
# Personal ID
# 173781                          0                           0
# 173781                          0                           0
# 173782                          0                           0
# 173782                          0                           0
# 173783                          0                           0
#
#              Entry Worker's Compensation  Entry Total Income  Exit Alimony  \
# Personal ID
# 173781                                 0                 607             0
# 173781                                 0                1143             0
# 173782                                 0                   0             0
# 173782                                 0                   0             0
# 173783                                 0                   0             0
#
#              Exit Child Support  Exit Earned  Exit GA  Exit Other  \
# Personal ID
# 173781                        0            0        0           0
# 173781                        0            0        0           0
# 173782                        0            0        0           0
# 173782                        0            0        0           0
# 173783                        0            0        0           0
#
#              Exit Pension  Exit Private Disability  \
# Personal ID
# 173781                  0                        0
# 173781                  0                        0
# 173782                  0                        0
# 173782                  0                        0
# 173783                  0                        0
#
#              Exit Social Security Retirement  Exit SSDI  Exit SSI  Exit TANF  \
# Personal ID
# 173781                                     0          0         0        607
# 173781                                     0          0         0       1143
# 173782                                     0          0         0          0
# 173782                                     0          0         0          0
# 173783                                     0          0         0          0
#
#              Exit Unemployment  Exit VA Non-Service  \
# Personal ID
# 173781                       0                    0
# 173781                       0                    0
# 173782                       0                    0
# 173782                       0                    0
# 173783                       0                    0
#
#              Exit VA Service Connected  Exit Worker's Compensation  \
# Personal ID
# 173781                               0                           0
# 173781                               0                           0
# 173782                               0                           0
# 173782                               0                           0
# 173783                               0                           0
#
#              Exit Total Income  Income Change
# Personal ID
# 173781                     607              0
# 173781                    1143              0
# 173782                       0              0
# 173782                       0              0
# 173783                       0              0

# %%
sheet = 'Service'

cols =  [
    'Personal ID',
    'Services ID',
    'Date Provided',
    'Date Ended',
    'Service Code',
    'Description',
    'Project ID',
    'Record Type',
    'Project Entry ID',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_service = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                         parse_dates=['Date Provided', 'Date Ended'],
                         infer_datetime_format=True)

df_service = df_service.dropna(axis=0, how='all')
# df_service.index = df_service.index.astype('int')

# Drop anyone missing these IDs
df_service = df_service.dropna(how='any', subset=['Project ID', 'Project Entry ID'])

# turn these into integers
cols = ['Project ID', 'Project Entry ID']
for col in cols:
    df_service[col] = df_service[col].astype('int')

# %%
df_service.head()
# Out:
#             Services ID Date Provided Date Ended Service Code  \
# Personal ID
# 175155          7312345    2013-04-01 2013-04-02      BH-1800
# 180665          7312348    2013-04-01 2013-04-02      BH-1800
# 184317          7312343    2013-04-01 2013-04-02      BH-1800
# 184431          7312350    2013-04-01 2013-04-02      BH-1800
# 184502          7312340    2013-04-01 2013-04-02      BH-1800
#
#                    Description  Project ID Record Type  Project Entry ID
# Personal ID
# 175155       Emergency Shelter        2840   Bed Night            382789
# 180665       Emergency Shelter        2840   Bed Night            382791
# 184317       Emergency Shelter        2840   Bed Night            382790
# 184431       Emergency Shelter        2840   Bed Night            483580
# 184502       Emergency Shelter        2840   Bed Night            382785

# %%
sheet = 'Project'

cols = [
    'Project ID',
    'Project Name',
    'Project Type Code',
    'Address City',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_project = pd.read_csv(infile, header=0, index_col=1, usecols=cols)

df_project.head()

df_project = df_project.dropna(axis=0, how='all')
# df_project.index = df_project.index.astype('int')

# Drop any project missing the code
df_project = df_project.dropna(how='any', subset=['Project Type Code'])

# Remove "(HUD) from strings
cols = ['Project Type Code',
        ]
for col in cols:
    df_project[col] = df_project[col].fillna(value='')
    df_project[col] = df_project[col].apply(lambda x: x.replace(' (HUD)', ''))
    # put the nans back
    df_project.loc[df_project[col] == '', col] = np.nan

# %%
df_project.head()
# Out:
#                           Project Name        Project Type Code Address City
# Project ID
# 2142             MOSBE CHS - Elm House     Transitional housing          NaN
# 2142             MOSBE CHS - Elm House     Transitional housing          NaN
# 3417          MOSBE CHS - RHY - BCP ES        Emergency Shelter     Monterey
# 3417          MOSBE CHS - RHY - BCP ES        Emergency Shelter      Seaside
# 3418        MOSBE CHS - RHY - BCP - HP  Homelessness Prevention     Monterey

# %%
sheet = 'BedInventory'

cols = [
    'Project ID',
    'Inventory ID',
    'Inventory Household Type',
    'HMIS Participating Beds',
    'Inventory Start Date',
    'Inventory End Date',
    'Unit Inventory',
    'Bed Inventory',
    'Vet Bed Inventory',
    'Youth Bed Inventory',
    'Youth Bed Age Group',
    ]

infile = os.path.join(datadir, '{s}.csv'.format(s=sheet))

df_bedinv = pd.read_csv(infile, header=0, index_col=0, usecols=cols,
                        parse_dates=['Inventory Start Date', 'Inventory End Date'],
                        infer_datetime_format=True)

df_bedinv = df_bedinv.dropna(axis=0, how='all')
# df_bedinv.index = df_bedinv.index.astype('int')

# turn these into integers, assume zero if NaN
cols = ['Inventory ID', 'HMIS Participating Beds', 'Unit Inventory', 'Bed Inventory', 'Vet Bed Inventory', 'Youth Bed Inventory']
for col in cols:
    # df_bedinv[col] = df_bedinv.loc[~df_bedinv[col].isnull(), col].apply(lambda x: int(x))
    df_bedinv[col] = df_bedinv[col].fillna(value=0)
    df_bedinv[col] = df_bedinv[col].astype('int')

# %%
df_bedinv.head()
# Out:
#             Inventory ID                          Inventory Household Type  \
# Project ID
# 2088                 144  Households with at least one adult and one child
# 2088                 655  Households with at least one adult and one child
# 2095                 194                       Households without children
# 2095                 678                       Households without children
# 2101                 145  Households with at least one adult and one child
#
#             HMIS Participating Beds Inventory Start Date Inventory End Date  \
# Project ID
# 2088                             36           2001-01-01         2013-09-30
# 2088                             36           2013-10-01                NaT
# 2095                              0           2004-01-01         2013-09-30
# 2095                              0           2013-10-01                NaT
# 2101                             24           1992-01-01         2013-09-30
#
#             Unit Inventory  Bed Inventory  Vet Bed Inventory  \
# Project ID
# 2088                     9             36                  0
# 2088                     9             36                  0
# 2095                     2              2                  0
# 2095                     4              4                  0
# 2101                     5             24                  0
#
#             Youth Bed Inventory Youth Bed Age Group
# Project ID
# 2088                          0                 NaN
# 2088                          0                 NaN
# 2095                          2     Only Ages 18-24
# 2095                          4   Only Under Age 18
# 2101                          0                 NaN

# %%
df_benefit.shape
df_client.shape
df_healthins.shape
df_enroll.shape
df_service.shape
df_disability.shape
# Out:
# (47784, 2)

# %%
# # Kernel breaks down when this code is run

# merge dataframes where key is 'Personal ID'
df_full_without_income = df_healthins.merge(df_service, left_index=True, right_index=True, how='left').merge(df_enroll, left_index=True, right_index=True, how='left').merge(df_disability, left_index=True, right_index=True, how='left').merge(df_client, left_index=True, right_index=True, how='left')# create dataframe that contains client information, and the benefit that is received.

# %%
# create dataframe of a selection of columns from dataframes
df_client_benefit = df_benefit.merge(df_client, left_index=True, right_index=True, how='left')
df_client_benefit_enroll = df_client_benefit.merge(df_enroll[['Project ID', 'Project Entry ID', 'Entry Date', 'Exit Date', 'Chronic Homeless', 'Domestic Violence Victim']], left_index=True, right_index=True, how='left')

# drop duplicate rows
df_client_benefit_enroll = df_client_benefit_enroll.drop_duplicates()

# rename df_client_benefit_enroll to df
df = df_client_benefit_enroll

# %%
df.to_csv('SFHomeless_2015-10-07_1.1.csv')

# %%
# column maken van index
df['Personal ID'] = df.index

# %%
# collect only the first and last visit of each client
# 2 steps:
# 1. create dataframe of first visit
# 2. create dataframe of last visit

# %%
# first visit
# 1. select only entries where Data Collection Stage is Project Entry
df_first = df[df['Data Collection Stage'] == 'Project Entry']

# 2. sort on ascending Entry Date, so first visit is on top
df_first = df_first.sort('Entry Date', ascending = True)

# 3. keep only the first Entry Date of each client
df_first = df_first.groupby('Personal ID').first()

# %%
# last visit
# 1. select only entries where Data Collection Stage is Project Entry
df_last = df[df['Data Collection Stage'] == 'Project Exit']

# 2. sort on ascending Entry Date, so first visit is on top
df_last = df_last.sort('Entry Date', ascending = False)

# 3. keep only the first Entry Date of each client
df_last = df_last.groupby('Personal ID').first()

# %%
# append df_last to df_first
df_first_last = df_first.append(df_last)

# sort by Personal ID
df_first_last.sort_index()
# Out:
#                                               Non-Cash Benefit  \
# Personal ID
# 173781       Supplemental Nutrition Assistance Program (Foo...
# 173781       Supplemental Nutrition Assistance Program (Foo...
# 173803       Supplemental Nutrition Assistance Program (Foo...
# 173803       Supplemental Nutrition Assistance Program (Foo...
# 173848       Supplemental Nutrition Assistance Program (Foo...
# 173848       Supplemental Nutrition Assistance Program (Foo...
# 173885       Supplemental Nutrition Assistance Program (Foo...
# 173899       Supplemental Nutrition Assistance Program (Foo...
# 173899       Supplemental Nutrition Assistance Program (Foo...
# 173901       Supplemental Nutrition Assistance Program (Foo...
# 173901       Supplemental Nutrition Assistance Program (Foo...
# 173982       Supplemental Nutrition Assistance Program (Foo...
# 173982       Supplemental Nutrition Assistance Program (Foo...
# 173984       Supplemental Nutrition Assistance Program (Foo...
# 173984       Supplemental Nutrition Assistance Program (Foo...
# 174002       Supplemental Nutrition Assistance Program (Foo...
# 174002       Supplemental Nutrition Assistance Program (Foo...
# 174004       Supplemental Nutrition Assistance Program (Foo...
# 174004       Supplemental Nutrition Assistance Program (Foo...
# 174020                                            Other Source
# 174027                                            Other Source
# 174051       Supplemental Nutrition Assistance Program (Foo...
# 174051       Supplemental Nutrition Assistance Program (Foo...
# 174064                                            Other Source
# 174064                                            Other Source
# 174086                                            Other Source
# 174091          Special Supplemental Nutrition Program for WIC
# 174091       Supplemental Nutrition Assistance Program (Foo...
# 174112       Supplemental Nutrition Assistance Program (Foo...
# 174112       Supplemental Nutrition Assistance Program (Foo...
# ...                                                        ...
# 281199       Supplemental Nutrition Assistance Program (Foo...
# 281199       Supplemental Nutrition Assistance Program (Foo...
# 281203       Supplemental Nutrition Assistance Program (Foo...
# 281203       Supplemental Nutrition Assistance Program (Foo...
# 281204       Supplemental Nutrition Assistance Program (Foo...
# 281204       Supplemental Nutrition Assistance Program (Foo...
# 281205       Supplemental Nutrition Assistance Program (Foo...
# 281205       Supplemental Nutrition Assistance Program (Foo...
# 281210       Supplemental Nutrition Assistance Program (Foo...
# 281210       Supplemental Nutrition Assistance Program (Foo...
# 281211       Supplemental Nutrition Assistance Program (Foo...
# 281211       Supplemental Nutrition Assistance Program (Foo...
# 281212       Supplemental Nutrition Assistance Program (Foo...
# 281212       Supplemental Nutrition Assistance Program (Foo...
# 281223       Supplemental Nutrition Assistance Program (Foo...
# 281223       Supplemental Nutrition Assistance Program (Foo...
# 281226       Supplemental Nutrition Assistance Program (Foo...
# 281226       Supplemental Nutrition Assistance Program (Foo...
# 281227       Supplemental Nutrition Assistance Program (Foo...
# 281227       Supplemental Nutrition Assistance Program (Foo...
# 281229       Supplemental Nutrition Assistance Program (Foo...
# 281229       Supplemental Nutrition Assistance Program (Foo...
# 281235       Supplemental Nutrition Assistance Program (Foo...
# 281235       Supplemental Nutrition Assistance Program (Foo...
# 281236       Supplemental Nutrition Assistance Program (Foo...
# 281236       Supplemental Nutrition Assistance Program (Foo...
# 281241       Supplemental Nutrition Assistance Program (Foo...
# 281241       Supplemental Nutrition Assistance Program (Foo...
# 281243                            TANF Transportation Services
# 281243                            TANF Transportation Services
#
#             Data Collection Stage                       Race  \
# Personal ID
# 173781              Project Entry                      White
# 173781               Project Exit                      White
# 173803              Project Entry                      White
# 173803               Project Exit                      White
# 173848              Project Entry                      White
# 173848               Project Exit                      White
# 173885              Project Entry                      White
# 173899              Project Entry                      White
# 173899               Project Exit                      White
# 173901               Project Exit  Black or African American
# 173901              Project Entry  Black or African American
# 173982              Project Entry                      White
# 173982               Project Exit                      White
# 173984               Project Exit                      Other
# 173984              Project Entry                      Other
# 174002               Project Exit                      White
# 174002              Project Entry                      White
# 174004               Project Exit                      White
# 174004              Project Entry                      White
# 174020              Project Entry                      White
# 174027              Project Entry                      White
# 174051              Project Entry                      White
# 174051               Project Exit                      White
# 174064               Project Exit  Black or African American
# 174064              Project Entry  Black or African American
# 174086              Project Entry                      White
# 174091               Project Exit                      White
# 174091              Project Entry                      White
# 174112               Project Exit                      White
# 174112              Project Entry                      White
# ...                           ...                        ...
# 281199              Project Entry                      White
# 281199               Project Exit                      White
# 281203               Project Exit  Black or African American
# 281203              Project Entry  Black or African American
# 281204               Project Exit                      White
# 281204              Project Entry                      White
# 281205              Project Entry                      White
# 281205               Project Exit                      White
# 281210              Project Entry                      White
# 281210               Project Exit                      White
# 281211              Project Entry                      White
# 281211               Project Exit                      White
# 281212               Project Exit                      White
# 281212              Project Entry                      White
# 281223               Project Exit                      White
# 281223              Project Entry                      White
# 281226               Project Exit  Black or African American
# 281226              Project Entry  Black or African American
# 281227               Project Exit                      White
# 281227              Project Entry                      White
# 281229               Project Exit                      White
# 281229              Project Entry                      White
# 281235               Project Exit                      White
# 281235              Project Entry                      White
# 281236               Project Exit         Data not collected
# 281236              Project Entry         Data not collected
# 281241              Project Entry                      White
# 281241               Project Exit                      White
# 281243              Project Entry                      White
# 281243               Project Exit                      White
#
#                            Ethnicity  Gender Veteran Status  Project ID  \
# Personal ID
# 173781               Hispanic/Latino  Female          False        2104
# 173781               Hispanic/Latino  Female          False        2101
# 173803               Hispanic/Latino  Female          False        2101
# 173803               Hispanic/Latino  Female          False        2101
# 173848       Non-Hispanic/Non-Latino  Female          False        2102
# 173848       Non-Hispanic/Non-Latino  Female          False        3207
# 173885               Hispanic/Latino  Female          False        2101
# 173899               Hispanic/Latino  Female          False        2840
# 173899               Hispanic/Latino  Female          False        2840
# 173901       Non-Hispanic/Non-Latino  Female          False        2120
# 173901       Non-Hispanic/Non-Latino  Female          False        2101
# 173982       Non-Hispanic/Non-Latino  Female          False        2115
# 173982       Non-Hispanic/Non-Latino  Female          False        2115
# 173984               Hispanic/Latino  Female          False        2840
# 173984               Hispanic/Latino  Female          False        2840
# 174002               Hispanic/Latino    Male          False        3419
# 174002               Hispanic/Latino    Male          False        2816
# 174004       Non-Hispanic/Non-Latino  Female          False        2086
# 174004       Non-Hispanic/Non-Latino  Female          False        2086
# 174020               Hispanic/Latino    Male          False        2820
# 174027               Hispanic/Latino    Male          False        2820
# 174051               Hispanic/Latino  Female          False        2121
# 174051               Hispanic/Latino  Female          False        2121
# 174064       Non-Hispanic/Non-Latino    Male          False        3320
# 174064       Non-Hispanic/Non-Latino    Male          False        2820
# 174086               Hispanic/Latino  Female          False        2820
# 174091               Hispanic/Latino  Female          False        2115
# 174091               Hispanic/Latino  Female          False        2101
# 174112               Hispanic/Latino  Female          False        2102
# 174112               Hispanic/Latino  Female          False        2102
# ...                              ...     ...            ...         ...
# 281199       Non-Hispanic/Non-Latino  Female          False        2936
# 281199       Non-Hispanic/Non-Latino  Female          False        2936
# 281203       Non-Hispanic/Non-Latino  Female          False        2102
# 281203       Non-Hispanic/Non-Latino  Female          False        2102
# 281204               Hispanic/Latino  Female          False        2102
# 281204               Hispanic/Latino  Female          False        2102
# 281205               Hispanic/Latino  Female          False         NaN
# 281205               Hispanic/Latino  Female          False         NaN
# 281210               Hispanic/Latino    Male            NaN        3184
# 281210               Hispanic/Latino    Male            NaN        3184
# 281211               Hispanic/Latino    Male          False        3443
# 281211               Hispanic/Latino    Male          False        3443
# 281212               Hispanic/Latino  Female          False        3443
# 281212               Hispanic/Latino  Female          False        3443
# 281223       Non-Hispanic/Non-Latino  Female          False        2936
# 281223       Non-Hispanic/Non-Latino  Female          False        2936
# 281226       Non-Hispanic/Non-Latino    Male          False        3184
# 281226       Non-Hispanic/Non-Latino    Male          False        3184
# 281227               Hispanic/Latino  Female          False        2936
# 281227               Hispanic/Latino  Female          False        2936
# 281229               Hispanic/Latino  Female          False        3443
# 281229               Hispanic/Latino  Female          False        3443
# 281235       Non-Hispanic/Non-Latino    Male          False        2936
# 281235       Non-Hispanic/Non-Latino    Male          False        2936
# 281236               Hispanic/Latino  Female          False        2947
# 281236               Hispanic/Latino  Female          False        3463
# 281241       Non-Hispanic/Non-Latino    Male          False        2936
# 281241       Non-Hispanic/Non-Latino    Male          False        2936
# 281243       Non-Hispanic/Non-Latino    Male          False        3419
# 281243       Non-Hispanic/Non-Latino    Male          False        3419
#
#              Project Entry ID Entry Date  Exit Date Chronic Homeless  \
# Personal ID
# 173781                 252608 2014-02-28 2014-02-28            False
# 173781                 314080 2014-05-06 2014-09-30            False
# 173803                 201286 2013-02-08 2013-04-27            False
# 173803                 201286 2013-02-08 2013-04-27            False
# 173848                 399509 2013-06-07 2013-11-13            False
# 173848                 446669 2015-03-26 2016-04-04            False
# 173885                 313112 2014-04-25 2014-06-02            False
# 173899                 447699 2015-03-20 2015-03-21            False
# 173899                 497611 2016-05-27 2016-05-28            False
# 173901                 227104 2013-09-16 2013-09-30            False
# 173901                 207049 2013-03-24 2013-04-27            False
# 173982                 174152 2011-12-22 2012-10-05            False
# 173982                 174152 2011-12-22 2012-10-05            False
# 173984                 486002 2015-05-07 2015-05-08            False
# 173984                 486002 2015-05-07 2015-05-08            False
# 174002                 494821 2016-04-01        NaT            False
# 174002                 494356 2016-03-14        NaT            False
# 174004                 410589 2014-09-17        NaT            False
# 174004                 410589 2014-09-17        NaT            False
# 174020                 137015 2005-07-10 2015-06-30            False
# 174027                 137013 2004-10-20 2015-06-30            False
# 174051                 220734 2013-05-21 2013-06-13            False
# 174051                 220734 2013-05-21 2013-06-13            False
# 174064                 412412 2014-11-20 2015-06-30            False
# 174064                 137021 2004-09-10 2015-06-30            False
# 174086                 137005 2008-07-10 2015-06-30            False
# 174091                 319538 2014-05-06 2015-02-16            False
# 174091                 207050 2013-03-25 2013-03-27            False
# 174112                 378039 2014-05-24 2014-06-23            False
# 174112                 378039 2014-05-24 2014-06-23            False
# ...                       ...        ...        ...              ...
# 281199                 497590 2016-03-14        NaT            False
# 281199                 497590 2016-03-14        NaT            False
# 281203                 497596 2016-05-20        NaT            False
# 281203                 497596 2016-05-20        NaT            False
# 281204                 497597 2016-05-18        NaT            False
# 281204                 497597 2016-05-18        NaT            False
# 281205                    NaN        NaT        NaT              NaN
# 281205                    NaN        NaT        NaT              NaN
# 281210                 497632 2016-05-28        NaT            False
# 281210                 497632 2016-05-28        NaT            False
# 281211                 497713 2014-03-13 2014-03-14            False
# 281211                 497713 2014-03-13 2014-03-14            False
# 281212                 497714 2014-03-13 2014-03-14            False
# 281212                 497714 2014-03-13 2014-03-14            False
# 281223                 497731 2016-05-02        NaT            False
# 281223                 497731 2016-05-02        NaT            False
# 281226                 497744 2016-05-27        NaT            False
# 281226                 497744 2016-05-27        NaT            False
# 281227                 497745 2016-05-02        NaT            False
# 281227                 497745 2016-05-02        NaT            False
# 281229                 497770 2016-05-03 2016-05-04            False
# 281229                 497770 2016-05-03 2016-05-04            False
# 281235                 497783 2016-02-11        NaT            False
# 281235                 497783 2016-02-11        NaT            False
# 281236                 497784 2016-05-12        NaT            False
# 281236                 497787 2016-05-12        NaT            False
# 281241                 497788 2016-04-07        NaT            False
# 281241                 497788 2016-04-07        NaT            False
# 281243                 497789 2016-05-01        NaT            False
# 281243                 497789 2016-05-01        NaT            False
#
#             Domestic Violence Victim
# Personal ID
# 173781                          True
# 173781                          True
# 173803                          True
# 173803                          True
# 173848                          True
# 173848                          True
# 173885                          True
# 173899                         False
# 173899                         False
# 173901                          True
# 173901                          True
# 173982                          True
# 173982                          True
# 173984                          True
# 173984                          True
# 174002                         False
# 174002                         False
# 174004                          True
# 174004                          True
# 174020                         False
# 174027                         False
# 174051                         False
# 174051                         False
# 174064                         False
# 174064                         False
# 174086                         False
# 174091                          True
# 174091                          True
# 174112                          True
# 174112                          True
# ...                              ...
# 281199                         False
# 281199                         False
# 281203                         False
# 281203                         False
# 281204                         False
# 281204                         False
# 281205                           NaN
# 281205                           NaN
# 281210                         False
# 281210                         False
# 281211                         False
# 281211                         False
# 281212                           NaN
# 281212                           NaN
# 281223                          True
# 281223                          True
# 281226                         False
# 281226                         False
# 281227                         False
# 281227                         False
# 281229                         False
# 281229                         False
# 281235                          True
# 281235                          True
# 281236                         False
# 281236                         False
# 281241                          True
# 281241                          True
# 281243                         False
# 281243                         False
#
# [7718 rows x 12 columns]

# %%
df_first_last.to_csv('SFHomeless_2015-10-07_1.2.csv')
