# %% [markdown]
# The purpose of this notebook is to encode categorical features using one-hot encoding.
#
# Future usage of the dataset may need to consider dropping a reference category so this reference case is encoded when all values are zero.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# # the "1" means: always reload modules marked with "%aimport"
# %autoreload 2

from __future__ import absolute_import, division, print_function
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os, sys
# from tqdm import tqdm
# import warnings

# sns.set_context("poster", font_scale=0.9)
sns.set_context("notebook", font_scale=1.0)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# add the data functions to the path
src_data_dir = os.path.join(os.getcwd(), os.pardir, 'src/data')
sys.path.append(src_data_dir)

# functions to load the data
import homeless_dataset as hd

# %%
datadir_raw = os.path.join(os.getenv('HOME'), 'Dropbox', 'C4SF-datasci-homeless', 'raw')
datadir_proc = os.path.join(os.getenv('HOME'), 'Dropbox', 'C4SF-datasci-homeless', 'processed')

# %%
# load in and process the data in separate sheets

df_client = hd.process_data_client(simplify_strings=True, datadir=datadir_raw)

df_enroll = hd.process_data_enrollment(simplify_strings=True, datadir=datadir_raw)

# Only keep rows with entry dates starting in 2012
df_enroll = df_enroll[df_enroll['Entry Date'] >= '2012']
# Only keep rows with exit dates before 2016-06-01
df_enroll = df_enroll[df_enroll['Exit Date'] <= '2016-06-01']

df_project = hd.process_data_project(simplify_strings=True, datadir=datadir_raw)

# calculate the numer of times in permanent housing
# only choosing one entry per day if enrolled multiple times in one day
df_times_in_ph = df_enroll[['Entry Date', 'In Permanent Housing']].reset_index().groupby(
    by=['Personal ID', 'Entry Date'], as_index=False).max().set_index(
    'Personal ID')[['In Permanent Housing']].astype(int).groupby(
    level=0).sum()
df_times_in_ph = df_times_in_ph.rename(columns={'In Permanent Housing': 'times_in_permanent_housing'})
df_client = df_client.merge(df_times_in_ph, how='left', left_index=True, right_index=True)
df_client['times_in_permanent_housing'] = df_client['times_in_permanent_housing'].fillna(value=0).astype(int)

# not currently using
# df_income = hd.process_data_income(simplify_strings=True, datadir=datadir_raw)
# df_service = hd.process_data_service(simplify_strings=True, datadir=datadir_raw)
# df_bedinv = hd.process_data_bedinventory(simplify_strings=True, datadir=datadir_raw)

# %%
# Join the client information with enrollment information.
# Inner join because we want to only keep individuals
# for whom we have both client and enrollment information.
df = df_client.merge(df_enroll, how='inner', left_index=True, right_index=True)

# add Project Type Code to DataFrame
df = df.merge(df_project[['Project Name',
                          'Project Type Code',
                          'Address City',
                          'Address Postal Code',
                         ]], left_on=['Project ID'], right_index=True)

# sort by entry date
df = df.sort_values('Entry Date')

# rename the columns to have no spaces
df = hd.rename_columns(df)

# %%
df.head(3)
# Out:
#               race  ethnicity  gender veteran_status  \
# Personal ID
# 214224       white  nonlatino    male          False
# 194592       white  nonlatino    male           True
# 179384       white     latino  female          False
#
#              times_in_permanent_housing  project_entry_id  \
# Personal ID
# 214224                                0            203474
# 194592                                1            150135
# 179384                                0            155873
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 214224                        60              00000 2012-01-01 2013-09-08
# 194592                        53              91103 2012-01-02 2013-08-31
# 179384                        50              93245 2012-01-03 2016-01-28
#
#              project_id housing_status_project_start  \
# Personal ID
# 214224             2938                 cat1homeless
# 194592             2134                 cat1homeless
# 179384             2086                 cat1homeless
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 214224                                      hotel             NaN
# 194592                                     family             NaN
# 179384                                    streets          CA-506
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 214224             203474                True                          False
# 194592             150135                True                          False
# 179384             155873               False                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 214224                                  NaN                       NaN
# 194592                                  NaN                       NaN
# 179384                                  NaN                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 214224                 False                False                      NaT
# 194592                 False                False                      NaT
# 179384                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 214224                         False                    NaN
# 194592                         False                    NaN
# 179384                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 214224                     False            616                          NaN
# 194592                     False            607                          NaN
# 179384                     False           1486                          NaN
#
#             head_of_household  \
# Personal ID
# 214224                  False
# 194592                  False
# 179384                   True
#
#                                                  project_name  \
# Personal ID
# 214224                 SCz - HSC - Page Smith Community House
# 194592            MOSBE Veterans Transition Center - Outreach
# 179384       MOSBE The Salvation Army - Good Samaritan Center
#
#                project_type_code address_city  address_postal_code
# Personal ID
# 214224       transitionalhousing   Santa Cruz                95060
# 194592                     other       Marina                93933
# 179384              servicesonly          NaN                93955

# %% [markdown]
# # Encode yes/no for some categorical features
#
# - noncash_benefit
# - health_insurance
# - disability_type
#
# One row per person, with columns for each non-benefit, insurance, and disability type.
#
# These tables describe whether a person was logged as having ever received a particular non-cash benefit, insurance type, or having had a disability. It is not possible to align when these were logged with the project entry date, so this is the best we can do to make use of these features.
#
# TODO: If not one-hot encoding, another way to encode the above categories is to turn the category values from the last X years into a string of the sorted set of values.

# %%
# read data and process

# process non-cash benefits
df_benefit = hd.process_data_benefit(simplify_strings=True, datadir=datadir_raw)
# remove any empty rows
df_benefit = df_benefit.dropna(subset=['Non-Cash Benefit'])
# rename the columns to have no spaces
df_benefit = hd.rename_columns(df_benefit)

# process health insurance
df_healthins = hd.process_data_healthins(simplify_strings=True, datadir=datadir_raw)
df_healthins.loc[df_healthins['Health Insurance'] == 'unknown', 'Health Insurance'] = np.nan
# remove any empty rows
df_healthins = df_healthins.dropna(subset=['Health Insurance'])
# rename the columns to have no spaces
df_healthins = hd.rename_columns(df_healthins)

# process disability
df_disability = hd.process_data_disability(simplify_strings=True, datadir=datadir_raw)
# remove any empty rows
df_disability = df_disability.dropna(subset=['Disability Type'])
# rename the columns to have no spaces
df_disability = hd.rename_columns(df_disability)

# simplify into one row per person

# did they ever receive any of these benefits?
df_benefit, cols = hd.encode_categorical_features(df_benefit, ['noncash_benefit'], astype='int')
df_benefit = df_benefit[cols].groupby(level=0).max()

# did they ever have any of these health insurances?
df_healthins, cols = hd.encode_categorical_features(df_healthins, ['health_insurance'], astype='int')
df_healthins = df_healthins[cols].groupby(level=0).max()

# did they ever have any of these disabilities?
df_disability, cols = hd.encode_categorical_features(df_disability, ['disability_type'], astype='int')
df_disability = df_disability[cols].groupby(level=0).max()

# %% [markdown]
# # Categorical variables: One-hot encoding
#
# ## Dummy coding (AKA treatment coding)
#
# - Drop one reference column, resulting in n-1 columns for n categorical values.
# - If you do not drop a reference column, there will exist collinearities in the data.
# - Regression with these columns tests the hypothesis of whether there is a difference compared to the (dropped) reference category.
# - NB: I don't know whether I'm using good reference columns (mostly the "unknown" values). This doesn't seem like the best choice.
#
# Sum the number of times each of these categories occurs:
# - housing_status_project_start
# - living_situation_before_program_entry
# - project_type_code
#
# TODO: If not one-hot encoding, another way to encode the above categories is to turn the category values from the last X years into a string of the sorted set of values.
#
# Boolean (1/0) for these:
# - race
# - ethnicity
# - gender

# %%
# whether to encode categorical variables
# True = split each value into its own numeric 1/0 column
# False = keep as strings
encode_categ = True

# whether to drop a reference column
drop_ref = False

if encode_categ == True:
    # initialize
    cols_categorical_max = []
    cols_categorical_sum = []
    
    if drop_ref == True:
        ref_cols_max = [
            'race_white',
            'ethnicity_nonlatino',
            'gender_male',
            # 'race_unknown',
            # 'ethnicity_unknown',
            # 'gender_unknown',
        ]

        ref_cols_sum = [
            'housing_status_project_start_other',
            'living_situation_before_program_entry_other',
            'project_type_code_other',
            #'housing_status_project_start_unknown',
            #'living_situation_before_program_entry_unknown',
            #'project_type_code_other',
        ]

# %%
# collapse some categories to make things simpler

# race
df.loc[(df.loc[:, 'race'] == 'other'), 'race'] = 'unknown'

# gender
df.loc[(df.loc[:, 'gender'] == 'other'), 'gender'] = 'unknown'

df['transsexual'] = False
df.loc[(df.loc[:, 'gender'] == 'transmtof') | (df.loc[:, 'gender'] == 'transftom'), 'transsexual'] = True

df.loc[(df.loc[:, 'gender'] == 'transmtof'), 'gender'] = 'female'
df.loc[(df.loc[:, 'gender'] == 'transftom'), 'gender'] = 'male'

# %%
# drop those with unknown demographic information

# number of enrollment entries
# gender: 89
# ethnicity: 2242
# race: 1986

# df = df.loc[~(df.loc[:, 'gender'] == 'unknown') &
#             ~(df.loc[:, 'ethnicity'] == 'unknown') &
#             ~(df.loc[:, 'race'] == 'unknown'), :]

# %%
df.head(1)
# Out:
#               race  ethnicity gender veteran_status  \
# Personal ID
# 214224       white  nonlatino   male          False
#
#              times_in_permanent_housing  project_entry_id  \
# Personal ID
# 214224                                0            203474
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 214224                        60              00000 2012-01-01 2013-09-08
#
#              project_id housing_status_project_start  \
# Personal ID
# 214224             2938                 cat1homeless
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 214224                                      hotel             NaN
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 214224             203474                True                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 214224                                  NaN                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 214224                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 214224                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 214224                     False            616                          NaN
#
#             head_of_household                            project_name  \
# Personal ID
# 214224                  False  SCz - HSC - Page Smith Community House
#
#                project_type_code address_city  address_postal_code transsexual
# Personal ID
# 214224       transitionalhousing   Santa Cruz                95060       False

# %%
# these columns will receive the max value, resulting in a boolean 1/0
if encode_categ == True:
    df, cols = hd.encode_categorical_features(df, ['race'], astype='int')
    cols_categorical_max.extend(cols)
    df = df.drop(['race'], axis=1)

    df, cols = hd.encode_categorical_features(df, ['ethnicity'], astype='int')
    cols_categorical_max.extend(cols)
    df = df.drop(['ethnicity'], axis=1)

    df, cols = hd.encode_categorical_features(df, ['gender'], astype='int')
    cols_categorical_max.extend(cols)
    df = df.drop(['gender'], axis=1)

    if drop_ref == True:
        cols_categorical_max = [x for x in cols_categorical_max if x not in ref_cols_max]

        # drop a reference column, if it exists
        for rc in ref_cols_max:
            if rc in df.columns:
                df = df.drop([rc], axis=1)

# these columns will be encoded as the number of times one of these categories was logged
if encode_categ == True:
    df, cols = hd.encode_categorical_features(df, ['housing_status_project_start'], astype='int')
    cols_categorical_sum.extend(cols)
    df = df.drop(['housing_status_project_start'], axis=1)

    df, cols = hd.encode_categorical_features(df, ['living_situation_before_program_entry'], astype='int')
    cols_categorical_sum.extend(cols)
    df = df.drop(['living_situation_before_program_entry'], axis=1)

    df, cols = hd.encode_categorical_features(df, ['project_type_code'], astype='int')
    cols_categorical_sum.extend(cols)
    df = df.drop(['project_type_code'], axis=1)

    if drop_ref == True:
        cols_categorical_sum = [x for x in cols_categorical_sum if x not in ref_cols_sum]

        # drop a reference column, if it exists
        for rc in ref_cols_sum:
            if rc in df.columns:
                df = df.drop([rc], axis=1)

# %%
df.head(3)
# Out:
#             veteran_status  times_in_permanent_housing  project_entry_id  \
# Personal ID
# 214224               False                           0            203474
# 194592                True                           1            150135
# 179384               False                           0            155873
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 214224                        60              00000 2012-01-01 2013-09-08
# 194592                        53              91103 2012-01-02 2013-08-31
# 179384                        50              93245 2012-01-03 2016-01-28
#
#              project_id client_location  household_id disabling_condition  \
# Personal ID
# 214224             2938             NaN        203474                True
# 194592             2134             NaN        150135                True
# 179384             2086          CA-506        155873               False
#
#             continuously_homeless_one_year times_homeless_past_three_years  \
# Personal ID
# 214224                               False                             NaN
# 194592                               False                             NaN
# 179384                               False                             NaN
#
#             months_homeless_this_time chronic_homeless in_permanent_housing  \
# Personal ID
# 214224                            NaN            False                False
# 194592                            NaN            False                False
# 179384                            NaN            False                False
#
#             residential_move_in_date domestic_violence_victim  \
# Personal ID
# 214224                           NaT                    False
# 194592                           NaT                    False
# 179384                           NaT                    False
#
#             months_ago_dv_occurred dv_currently_fleeing  days_enrolled  \
# Personal ID
# 214224                         NaN                False            616
# 194592                         NaN                False            607
# 179384                         NaN                False           1486
#
#              days_to_residential_move_in head_of_household  \
# Personal ID
# 214224                               NaN             False
# 194592                               NaN             False
# 179384                               NaN              True
#
#                                                  project_name address_city  \
# Personal ID
# 214224                 SCz - HSC - Page Smith Community House   Santa Cruz
# 194592            MOSBE Veterans Transition Center - Outreach       Marina
# 179384       MOSBE The Salvation Army - Good Samaritan Center          NaN
#
#              address_postal_code transsexual  race_amerindian  \
# Personal ID
# 214224                     95060       False                0
# 194592                     93933       False                0
# 179384                     93955       False                0
#
#              race_pacificisl  race_white  race_asian  race_unknown  \
# Personal ID
# 214224                     0           1           0             0
# 194592                     0           1           0             0
# 179384                     0           1           0             0
#
#              race_black  ethnicity_latino  ethnicity_unknown  \
# Personal ID
# 214224                0                 0                  0
# 194592                0                 0                  0
# 179384                0                 1                  0
#
#              ethnicity_nonlatino  gender_unknown  gender_female  gender_male  \
# Personal ID
# 214224                         1               0              0            1
# 194592                         1               0              0            1
# 179384                         0               0              1            0
#
#              housing_status_project_start_housed  \
# Personal ID
# 214224                                         0
# 194592                                         0
# 179384                                         0
#
#              housing_status_project_start_atrisk  \
# Personal ID
# 214224                                         0
# 194592                                         0
# 179384                                         0
#
#              housing_status_project_start_cat3homelessfedstatutes  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              housing_status_project_start_cat1homeless  \
# Personal ID
# 214224                                               1
# 194592                                               1
# 179384                                               1
#
#              housing_status_project_start_cat4fleeingdv  \
# Personal ID
# 214224                                                0
# 194592                                                0
# 179384                                                0
#
#              housing_status_project_start_cat2risklosing  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
#
#              housing_status_project_start_unknown  \
# Personal ID
# 214224                                          0
# 194592                                          0
# 179384                                          0
#
#              living_situation_before_program_entry_longtermcare  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_rentalgdptip  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_rentalvash  \
# Personal ID
# 214224                                                      0
# 194592                                                      0
# 179384                                                      0
#
#              living_situation_before_program_entry_halfwayhouse  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_ownedsubsidy  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_hospitalpsych  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_hotel  \
# Personal ID
# 214224                                                 1
# 194592                                                 0
# 179384                                                 0
#
#              living_situation_before_program_entry_streets  \
# Personal ID
# 214224                                                   0
# 194592                                                   0
# 179384                                                   1
#
#              living_situation_before_program_entry_foster  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
#
#              living_situation_before_program_entry_emershelter  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_rentalother  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_hospital  \
# Personal ID
# 214224                                                    0
# 194592                                                    0
# 179384                                                    0
#
#              living_situation_before_program_entry_rental  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
#
#              living_situation_before_program_entry_transitionalhousing  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_unknown  \
# Personal ID
# 214224                                                   0
# 194592                                                   0
# 179384                                                   0
#
#              living_situation_before_program_entry_safehaven  \
# Personal ID
# 214224                                                     0
# 194592                                                     0
# 179384                                                     0
#
#              living_situation_before_program_entry_permanenthousing  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_owned  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
#
#              living_situation_before_program_entry_detoxcenter  \
# Personal ID
# 214224                                                       0
# 194592                                                       0
# 179384                                                       0
#
#              living_situation_before_program_entry_friend  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
#
#              living_situation_before_program_entry_jail  \
# Personal ID
# 214224                                                0
# 194592                                                0
# 179384                                                0
#
#              living_situation_before_program_entry_family  \
# Personal ID
# 214224                                                  0
# 194592                                                  1
# 179384                                                  0
#
#              living_situation_before_program_entry_other  \
# Personal ID
# 214224                                                 0
# 194592                                                 0
# 179384                                                 0
#
#              project_type_code_permanentsupportivehousing  \
# Personal ID
# 214224                                                  0
# 194592                                                  0
# 179384                                                  0
#
#              project_type_code_other  project_type_code_emergencyshelter  \
# Personal ID
# 214224                             0                                   0
# 194592                             1                                   0
# 179384                             0                                   0
#
#              project_type_code_rapidrehousing  \
# Personal ID
# 214224                                      0
# 194592                                      0
# 179384                                      0
#
#              project_type_code_homelessnessprevention  \
# Personal ID
# 214224                                              0
# 194592                                              0
# 179384                                              0
#
#              project_type_code_transitionalhousing  \
# Personal ID
# 214224                                           1
# 194592                                           0
# 179384                                           0
#
#              project_type_code_streetoutreach  project_type_code_servicesonly
# Personal ID
# 214224                                      0                               0
# 194592                                      0                               0
# 179384                                      0                               1

# %%
# using these lists of features

features_binary = [
    'veteran_status',
    'disabling_condition',
    'continuously_homeless_one_year',
    'chronic_homeless',
    'in_permanent_housing',
    'domestic_violence_victim',
    'dv_currently_fleeing',
    'head_of_household',
    'transsexual',
]

features_not_using = [
    'project_entry_id',
    'last_permanent_zip',
    'project_id',
    'client_location',
    'household_id',
    'project_name',
    'address_city',
    'address_postal_code',
]

# just keeping track of other features here in comments

# features_categorical = [
#     'race',
#     'ethnicity',
#     'gender',
#     'housing_status_project_start',
#     'living_situation_before_program_entry',
#     'project_type_code',
# #     'noncash_benefit',
# #     'disability_type',
# #     'health_insurance',
# ]

# features_quant = [
#     'client_age_at_entry',
#     'times_homeless_past_three_years',
#     'months_homeless_this_time',
#     'months_ago_dv_occurred',
#     'days_enrolled',
#     'days_to_residential_move_in',
#     'times_in_permanent_housing',
# ]

# features_date = [
#     'entry_date',
#     'exit_date',
#     'residential_move_in_date',
#     ]

# %%
df = df.drop(features_not_using, axis=1)

# %%
# df, cols_categorical = hd.encode_categorical_features(df, features_categorical, astype='int')

# %%
# set up to count the number of times a person was in the system
df['enrollments'] = 1

if encode_categ == True:
    # for each person, aggregate their one-hot encoded features
    agg_categorical = {}
    for col in cols_categorical_sum:
        agg_categorical[col] = 'sum'
    for col in cols_categorical_max:
        agg_categorical[col] = 'max'

# create feature vectors for each person by subselecting or aggregating their enrollments;
# one row per person
agg = {
    # binary
    'veteran_status': 'max',
    'disabling_condition': 'max',
    'continuously_homeless_one_year': 'max',
    'chronic_homeless': 'max',
    'domestic_violence_victim': 'max',
    'dv_currently_fleeing': 'max',
    'head_of_household': 'max',
    'transsexual': 'max',
    # quantitative
    'enrollments': 'sum',
    'client_age_at_entry': 'last',
    'times_homeless_past_three_years': 'last',
    'months_homeless_this_time': 'last',
    'months_ago_dv_occurred': 'last',
    'days_enrolled': 'sum',
    'times_in_permanent_housing': 'max',
    #     # categorical
    #     'race': 'first',
    #     'ethnicity': 'first',
    #     'gender': 'first',
    #     'housing_status_project_start': 'last',
    #     'living_situation_before_program_entry': 'last',
    #     'project_type_code': 'last',
    #     'noncash_benefit': 'last',
    #     'disability_type': 'last',
    #     'health_insurance': 'last',
    # outcome related
    'in_permanent_housing': 'last',
    'days_to_residential_move_in': 'last',
    }

if encode_categ == True:
    agg.update(agg_categorical)

df_features = df.reset_index().groupby(by=['Personal ID']).agg(agg)

# convert booleans to integers
for col in features_binary:
    df_features[col] = df_features[col].astype(int)

# sort the columns
df_features = df_features[sorted(df_features.columns)]

# %%
# for col in df_features.columns:
#     if df_features[col].isnull().mean() > 0:
#         print(col, df_features[col].isnull().mean())

# # columsn with nans
# cols_fillna = [
#     'days_to_residential_move_in',
#     'times_homeless_past_three_years',
#     'months_homeless_this_time',
#     'months_ago_dv_occurred',
# ]

# %%
# join benefits, health insurance, diability

df_features = df_features.merge(df_benefit, how='left', left_index=True, right_index=True)
cols = df_benefit.columns.tolist()
df_features[cols] = df_features[cols].fillna(value=0)

df_features = df_features.merge(df_healthins, how='left', left_index=True, right_index=True)
cols = df_healthins.columns.tolist()
df_features[cols] = df_features[cols].fillna(value=0)

df_features = df_features.merge(df_disability, how='left', left_index=True, right_index=True)
cols = df_disability.columns.tolist()
df_features[cols] = df_features[cols].fillna(value=0)

# %%
# number of people in the dataset
df_features.shape
# Out:
# (11362, 96)

# %%
# glance at the data
df_features.head()
# Out:
#              chronic_homeless  client_age_at_entry  \
# Personal ID
# 173781                      0                   35
# 173782                      0                   10
# 173783                      0                   12
# 173803                      0                   32
# 173804                      0                   11
#
#              continuously_homeless_one_year  days_enrolled  \
# Personal ID
# 173781                                    0            147
# 173782                                    1            147
# 173783                                    1            147
# 173803                                    0             78
# 173804                                    0             78
#
#              days_to_residential_move_in  disabling_condition  \
# Personal ID
# 173781                               NaN                    0
# 173782                               NaN                    0
# 173783                               NaN                    0
# 173803                               NaN                    0
# 173804                               NaN                    0
#
#              domestic_violence_victim  dv_currently_fleeing  enrollments  \
# Personal ID
# 173781                              1                     0            2
# 173782                              1                     0            1
# 173783                              1                     0            1
# 173803                              1                     0            1
# 173804                              0                     0            1
#
#              ethnicity_latino  ethnicity_nonlatino  ethnicity_unknown  \
# Personal ID
# 173781                      1                    0                  0
# 173782                      1                    0                  0
# 173783                      1                    0                  0
# 173803                      1                    0                  0
# 173804                      1                    0                  0
#
#              gender_female  gender_male  gender_unknown  head_of_household  \
# Personal ID
# 173781                   1            0               0                  0
# 173782                   0            1               0                  0
# 173783                   1            0               0                  0
# 173803                   1            0               0                  0
# 173804                   1            0               0                  0
#
#              housing_status_project_start_atrisk  \
# Personal ID
# 173781                                         1
# 173782                                         0
# 173783                                         0
# 173803                                         0
# 173804                                         0
#
#              housing_status_project_start_cat1homeless  \
# Personal ID
# 173781                                               1
# 173782                                               1
# 173783                                               1
# 173803                                               1
# 173804                                               1
#
#              housing_status_project_start_cat2risklosing  \
# Personal ID
# 173781                                                 0
# 173782                                                 0
# 173783                                                 0
# 173803                                                 0
# 173804                                                 0
#
#              housing_status_project_start_cat3homelessfedstatutes  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              housing_status_project_start_cat4fleeingdv  \
# Personal ID
# 173781                                                0
# 173782                                                0
# 173783                                                0
# 173803                                                0
# 173804                                                0
#
#              housing_status_project_start_housed  \
# Personal ID
# 173781                                         0
# 173782                                         0
# 173783                                         0
# 173803                                         0
# 173804                                         0
#
#              housing_status_project_start_unknown  in_permanent_housing  \
# Personal ID
# 173781                                          0                     0
# 173782                                          0                     0
# 173783                                          0                     0
# 173803                                          0                     0
# 173804                                          0                     0
#
#              living_situation_before_program_entry_detoxcenter  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_emershelter  \
# Personal ID
# 173781                                                       1
# 173782                                                       1
# 173783                                                       1
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_family  \
# Personal ID
# 173781                                                  0
# 173782                                                  0
# 173783                                                  0
# 173803                                                  0
# 173804                                                  0
#
#              living_situation_before_program_entry_foster  \
# Personal ID
# 173781                                                  0
# 173782                                                  0
# 173783                                                  0
# 173803                                                  0
# 173804                                                  0
#
#              living_situation_before_program_entry_friend  \
# Personal ID
# 173781                                                  0
# 173782                                                  0
# 173783                                                  0
# 173803                                                  1
# 173804                                                  1
#
#              living_situation_before_program_entry_halfwayhouse  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_hospital  \
# Personal ID
# 173781                                                    0
# 173782                                                    0
# 173783                                                    0
# 173803                                                    0
# 173804                                                    0
#
#              living_situation_before_program_entry_hospitalpsych  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_hotel  \
# Personal ID
# 173781                                                 0
# 173782                                                 0
# 173783                                                 0
# 173803                                                 0
# 173804                                                 0
#
#              living_situation_before_program_entry_jail  \
# Personal ID
# 173781                                                0
# 173782                                                0
# 173783                                                0
# 173803                                                0
# 173804                                                0
#
#              living_situation_before_program_entry_longtermcare  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_other  \
# Personal ID
# 173781                                                 0
# 173782                                                 0
# 173783                                                 0
# 173803                                                 0
# 173804                                                 0
#
#              living_situation_before_program_entry_owned  \
# Personal ID
# 173781                                                 0
# 173782                                                 0
# 173783                                                 0
# 173803                                                 0
# 173804                                                 0
#
#              living_situation_before_program_entry_ownedsubsidy  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_permanenthousing  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_rental  \
# Personal ID
# 173781                                                  1
# 173782                                                  0
# 173783                                                  0
# 173803                                                  0
# 173804                                                  0
#
#              living_situation_before_program_entry_rentalgdptip  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_rentalother  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_rentalvash  \
# Personal ID
# 173781                                                      0
# 173782                                                      0
# 173783                                                      0
# 173803                                                      0
# 173804                                                      0
#
#              living_situation_before_program_entry_safehaven  \
# Personal ID
# 173781                                                     0
# 173782                                                     0
# 173783                                                     0
# 173803                                                     0
# 173804                                                     0
#
#              living_situation_before_program_entry_streets  \
# Personal ID
# 173781                                                   0
# 173782                                                   0
# 173783                                                   0
# 173803                                                   0
# 173804                                                   0
#
#              living_situation_before_program_entry_transitionalhousing  \
# Personal ID
# 173781                                                       0
# 173782                                                       0
# 173783                                                       0
# 173803                                                       0
# 173804                                                       0
#
#              living_situation_before_program_entry_unknown  \
# Personal ID
# 173781                                                   0
# 173782                                                   0
# 173783                                                   0
# 173803                                                   0
# 173804                                                   0
#
#              months_ago_dv_occurred  months_homeless_this_time  \
# Personal ID
# 173781                         12.0                        NaN
# 173782                         12.0                        NaN
# 173783                         12.0                        NaN
# 173803                         12.0                        NaN
# 173804                          NaN                        NaN
#
#              project_type_code_emergencyshelter  \
# Personal ID
# 173781                                        1
# 173782                                        1
# 173783                                        1
# 173803                                        1
# 173804                                        1
#
#              project_type_code_homelessnessprevention  \
# Personal ID
# 173781                                              0
# 173782                                              0
# 173783                                              0
# 173803                                              0
# 173804                                              0
#
#              project_type_code_other  \
# Personal ID
# 173781                             0
# 173782                             0
# 173783                             0
# 173803                             0
# 173804                             0
#
#              project_type_code_permanentsupportivehousing  \
# Personal ID
# 173781                                                  0
# 173782                                                  0
# 173783                                                  0
# 173803                                                  0
# 173804                                                  0
#
#              project_type_code_rapidrehousing  project_type_code_servicesonly  \
# Personal ID
# 173781                                      0                               0
# 173782                                      0                               0
# 173783                                      0                               0
# 173803                                      0                               0
# 173804                                      0                               0
#
#              project_type_code_streetoutreach  \
# Personal ID
# 173781                                      1
# 173782                                      0
# 173783                                      0
# 173803                                      0
# 173804                                      0
#
#              project_type_code_transitionalhousing  race_amerindian  \
# Personal ID
# 173781                                           0                0
# 173782                                           0                0
# 173783                                           0                0
# 173803                                           0                0
# 173804                                           0                0
#
#              race_asian  race_black  race_pacificisl  race_unknown  \
# Personal ID
# 173781                0           0                0             0
# 173782                0           0                0             0
# 173783                0           0                0             0
# 173803                0           0                0             0
# 173804                0           0                0             0
#
#              race_white  times_homeless_past_three_years  \
# Personal ID
# 173781                1                              2.0
# 173782                1                              2.0
# 173783                1                              2.0
# 173803                1                              NaN
# 173804                1                              NaN
#
#              times_in_permanent_housing  transsexual  veteran_status  \
# Personal ID
# 173781                                0            0               0
# 173782                                0            0               0
# 173783                                0            0               0
# 173803                                0            0               0
# 173804                                0            0               0
#
#              noncash_benefit_other  noncash_benefit_temprental  \
# Personal ID
# 173781                         0.0                         0.0
# 173782                         0.0                         0.0
# 173783                         0.0                         0.0
# 173803                         0.0                         0.0
# 173804                         0.0                         0.0
#
#              noncash_benefit_foodstamps  noncash_benefit_tanfother  \
# Personal ID
# 173781                              1.0                        0.0
# 173782                              0.0                        0.0
# 173783                              0.0                        0.0
# 173803                              1.0                        0.0
# 173804                              0.0                        0.0
#
#              noncash_benefit_tanfchildcare  \
# Personal ID
# 173781                                 0.0
# 173782                                 0.0
# 173783                                 0.0
# 173803                                 0.0
# 173804                                 0.0
#
#              noncash_benefit_tanftransportation  noncash_benefit_wic  \
# Personal ID
# 173781                                      0.0                  0.0
# 173782                                      0.0                  0.0
# 173783                                      0.0                  0.0
# 173803                                      0.0                  0.0
# 173804                                      0.0                  0.0
#
#              noncash_benefit_publichousing  health_insurance_medicare  \
# Personal ID
# 173781                                 0.0                        0.0
# 173782                                 0.0                        1.0
# 173783                                 0.0                        0.0
# 173803                                 0.0                        0.0
# 173804                                 0.0                        0.0
#
#              health_insurance_pirvate  health_insurance_stateadult  \
# Personal ID
# 173781                            0.0                          0.0
# 173782                            0.0                          0.0
# 173783                            0.0                          0.0
# 173803                            0.0                          0.0
# 173804                            0.0                          0.0
#
#              health_insurance_employer  health_insurance_medicaid  \
# Personal ID
# 173781                             0.0                        1.0
# 173782                             0.0                        0.0
# 173783                             0.0                        1.0
# 173803                             0.0                        0.0
# 173804                             0.0                        0.0
#
#              health_insurance_statechild  health_insurance_cobra  \
# Personal ID
# 173781                               0.0                     0.0
# 173782                               0.0                     0.0
# 173783                               0.0                     0.0
# 173803                               0.0                     0.0
# 173804                               0.0                     0.0
#
#              health_insurance_veteranadmin  disability_type_hivaids  \
# Personal ID
# 173781                                 0.0                      0.0
# 173782                                 0.0                      0.0
# 173783                                 0.0                      0.0
# 173803                                 0.0                      0.0
# 173804                                 0.0                      0.0
#
#              disability_type_other  disability_type_dualdiagnosis  \
# Personal ID
# 173781                         0.0                            0.0
# 173782                         0.0                            0.0
# 173783                         0.0                            0.0
# 173803                         0.0                            0.0
# 173804                         0.0                            0.0
#
#              disability_type_alcoholdrug  disability_type_developmental  \
# Personal ID
# 173781                               0.0                            0.0
# 173782                               0.0                            0.0
# 173783                               0.0                            0.0
# 173803                               0.0                            0.0
# 173804                               0.0                            0.0
#
#              disability_type_substance  disability_type_physical  \
# Personal ID
# 173781                             0.0                       0.0
# 173782                             0.0                       0.0
# 173783                             0.0                       0.0
# 173803                             0.0                       0.0
# 173804                             0.0                       0.0
#
#              disability_type_chronichealth  disability_type_hearing  \
# Personal ID
# 173781                                 0.0                      0.0
# 173782                                 0.0                      0.0
# 173783                                 0.0                      0.0
# 173803                                 0.0                      0.0
# 173804                                 0.0                      0.0
#
#              disability_type_alcohol  disability_type_vision  \
# Personal ID
# 173781                           0.0                     0.0
# 173782                           0.0                     0.0
# 173783                           0.0                     0.0
# 173803                           0.0                     0.0
# 173804                           0.0                     0.0
#
#              disability_type_drug  disability_type_mentalhealth
# Personal ID
# 173781                        0.0                           0.0
# 173782                        0.0                           0.0
# 173783                        0.0                           0.0
# 173803                        0.0                           0.0
# 173804                        0.0                           0.0

# %%
df_features.describe()
# Out:
#        chronic_homeless  client_age_at_entry  continuously_homeless_one_year  \
# count      11362.000000         11362.000000                    11362.000000
# mean           0.059849            33.622250                        0.185443
# std            0.237217            20.246602                        0.388673
# min            0.000000             0.000000                        0.000000
# 25%            0.000000            16.000000                        0.000000
# 50%            0.000000            34.000000                        0.000000
# 75%            0.000000            51.000000                        0.000000
# max            1.000000           101.000000                        1.000000
#
#        days_enrolled  days_to_residential_move_in  disabling_condition  \
# count   11362.000000                   747.000000         11362.000000
# mean      207.853459                    72.552878             0.390512
# std       330.189494                    81.557515             0.487887
# min         0.000000                     1.000000             0.000000
# 25%        26.000000                    16.000000             0.000000
# 50%        96.000000                    48.000000             0.000000
# 75%       258.000000                    97.000000             1.000000
# max      5040.000000                   730.000000             1.000000
#
#        domestic_violence_victim  dv_currently_fleeing   enrollments  \
# count              11362.000000          11362.000000  11362.000000
# mean                   0.183154              0.001672      5.123130
# std                    0.386810              0.040861     18.586563
# min                    0.000000              0.000000      1.000000
# 25%                    0.000000              0.000000      1.000000
# 50%                    0.000000              0.000000      2.000000
# 75%                    0.000000              0.000000      2.000000
# max                    1.000000              1.000000    577.000000
#
#        ethnicity_latino  ethnicity_nonlatino  ethnicity_unknown  \
# count      11362.000000         11362.000000       11362.000000
# mean           0.458282             0.521827           0.019891
# std            0.498278             0.499545           0.139631
# min            0.000000             0.000000           0.000000
# 25%            0.000000             0.000000           0.000000
# 50%            0.000000             1.000000           0.000000
# 75%            1.000000             1.000000           0.000000
# max            1.000000             1.000000           1.000000
#
#        gender_female   gender_male  gender_unknown  head_of_household  \
# count   11362.000000  11362.000000    11362.000000       11362.000000
# mean        0.426685      0.572346        0.000968           0.409347
# std         0.494618      0.494760        0.031101           0.491735
# min         0.000000      0.000000        0.000000           0.000000
# 25%         0.000000      0.000000        0.000000           0.000000
# 50%         0.000000      1.000000        0.000000           0.000000
# 75%         1.000000      1.000000        0.000000           1.000000
# max         1.000000      1.000000        1.000000           1.000000
#
#        housing_status_project_start_atrisk  \
# count                         11362.000000
# mean                              0.091445
# std                               1.094995
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              94.000000
#
#        housing_status_project_start_cat1homeless  \
# count                               11362.000000
# mean                                    4.110720
# std                                    17.805798
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     1.000000
# 75%                                     2.000000
# max                                   577.000000
#
#        housing_status_project_start_cat2risklosing  \
# count                                 11362.000000
# mean                                      0.273543
# std                                       1.394907
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                     112.000000
#
#        housing_status_project_start_cat3homelessfedstatutes  \
# count                                       11362.000000
# mean                                            0.008537
# std                                             0.673160
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            71.000000
#
#        housing_status_project_start_cat4fleeingdv  \
# count                                11362.000000
# mean                                     0.003609
# std                                      0.066903
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                      3.000000
#
#        housing_status_project_start_housed  \
# count                         11362.000000
# mean                              0.183506
# std                               1.441290
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              98.000000
#
#        housing_status_project_start_unknown  in_permanent_housing  \
# count                          11362.000000          11362.000000
# mean                               0.451769              0.101039
# std                                4.627732              0.301393
# min                                0.000000              0.000000
# 25%                                0.000000              0.000000
# 50%                                0.000000              0.000000
# 75%                                0.000000              0.000000
# max                              339.000000              1.000000
#
#        living_situation_before_program_entry_detoxcenter  \
# count                                       11362.000000
# mean                                            0.048759
# std                                             0.498831
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            31.000000
#
#        living_situation_before_program_entry_emershelter  \
# count                                       11362.000000
# mean                                            1.087661
# std                                             9.930667
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           410.000000
#
#        living_situation_before_program_entry_family  \
# count                                  11362.000000
# mean                                       0.404506
# std                                        4.263718
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      339.000000
#
#        living_situation_before_program_entry_foster  \
# count                                  11362.000000
# mean                                       0.007129
# std                                        0.192826
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                       14.000000
#
#        living_situation_before_program_entry_friend  \
# count                                  11362.000000
# mean                                       0.317814
# std                                        4.238691
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      196.000000
#
#        living_situation_before_program_entry_halfwayhouse  \
# count                                       11362.000000
# mean                                            0.002112
# std                                             0.063596
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             4.000000
#
#        living_situation_before_program_entry_hospital  \
# count                                    11362.000000
# mean                                         0.097078
# std                                          3.099897
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                        195.000000
#
#        living_situation_before_program_entry_hospitalpsych  \
# count                                       11362.000000
# mean                                            0.035557
# std                                             1.038458
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            94.000000
#
#        living_situation_before_program_entry_hotel  \
# count                                 11362.000000
# mean                                      0.155166
# std                                       2.041671
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                     116.000000
#
#        living_situation_before_program_entry_jail  \
# count                                11362.000000
# mean                                     0.055976
# std                                      1.498595
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                    118.000000
#
#        living_situation_before_program_entry_longtermcare  \
# count                                       11362.000000
# mean                                            0.000440
# std                                             0.031113
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             3.000000
#
#        living_situation_before_program_entry_other  \
# count                                 11362.000000
# mean                                      0.099630
# std                                       2.026434
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                     127.000000
#
#        living_situation_before_program_entry_owned  \
# count                                 11362.000000
# mean                                      0.011530
# std                                       0.207145
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       8.000000
#
#        living_situation_before_program_entry_ownedsubsidy  \
# count                                       11362.000000
# mean                                            0.003080
# std                                             0.189248
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            19.000000
#
#        living_situation_before_program_entry_permanenthousing  \
# count                                       11362.000000
# mean                                            0.015666
# std                                             0.831410
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            86.000000
#
#        living_situation_before_program_entry_rental  \
# count                                  11362.000000
# mean                                       0.420877
# std                                        5.479149
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      551.000000
#
#        living_situation_before_program_entry_rentalgdptip  \
# count                                       11362.000000
# mean                                            0.000088
# std                                             0.009382
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        living_situation_before_program_entry_rentalother  \
# count                                       11362.000000
# mean                                            0.107816
# std                                             3.405584
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                           300.000000
#
#        living_situation_before_program_entry_rentalvash  \
# count                                      11362.000000
# mean                                           0.048407
# std                                            1.453361
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.000000
# 75%                                            0.000000
# max                                          135.000000
#
#        living_situation_before_program_entry_safehaven  \
# count                                     11362.000000
# mean                                          0.053600
# std                                           1.996087
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                         125.000000
#
#        living_situation_before_program_entry_streets  \
# count                                   11362.000000
# mean                                        1.663175
# std                                        11.013143
# min                                         0.000000
# 25%                                         0.000000
# 50%                                         0.000000
# 75%                                         0.000000
# max                                       299.000000
#
#        living_situation_before_program_entry_transitionalhousing  \
# count                                       11362.000000
# mean                                            0.091269
# std                                             0.761980
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            37.000000
#
#        living_situation_before_program_entry_unknown  months_ago_dv_occurred  \
# count                                   11362.000000             1910.000000
# mean                                        0.395793               16.102618
# std                                         3.127194                9.192029
# min                                         0.000000                3.000000
# 25%                                         0.000000                6.000000
# 50%                                         0.000000               24.000000
# 75%                                         0.000000               24.000000
# max                                       106.000000               24.000000
#
#        months_homeless_this_time  project_type_code_emergencyshelter  \
# count                1726.000000                        11362.000000
# mean                    6.976246                            3.856275
# std                     9.969520                           18.603163
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     1.000000                            0.000000
# 75%                    12.000000                            1.000000
# max                    24.000000                          573.000000
#
#        project_type_code_homelessnessprevention  project_type_code_other  \
# count                              11362.000000             11362.000000
# mean                                   0.194772                 0.222584
# std                                    0.522361                 0.836312
# min                                    0.000000                 0.000000
# 25%                                    0.000000                 0.000000
# 50%                                    0.000000                 0.000000
# 75%                                    0.000000                 0.000000
# max                                    8.000000                22.000000
#
#        project_type_code_permanentsupportivehousing  \
# count                                  11362.000000
# mean                                       0.015138
# std                                        0.165025
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                        5.000000
#
#        project_type_code_rapidrehousing  project_type_code_servicesonly  \
# count                      11362.000000                    11362.000000
# mean                           0.155518                        0.409435
# std                            0.724306                        0.865139
# min                            0.000000                        0.000000
# 25%                            0.000000                        0.000000
# 50%                            0.000000                        0.000000
# 75%                            0.000000                        0.000000
# max                           26.000000                        6.000000
#
#        project_type_code_streetoutreach  \
# count                      11362.000000
# mean                           0.092325
# std                            0.369623
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            7.000000
#
#        project_type_code_transitionalhousing  race_amerindian    race_asian  \
# count                           11362.000000     11362.000000  11362.000000
# mean                                0.177081         0.064601      0.020419
# std                                 0.503112         0.245832      0.141435
# min                                 0.000000         0.000000      0.000000
# 25%                                 0.000000         0.000000      0.000000
# 50%                                 0.000000         0.000000      0.000000
# 75%                                 0.000000         0.000000      0.000000
# max                                 4.000000         1.000000      1.000000
#
#          race_black  race_pacificisl  race_unknown    race_white  \
# count  11362.000000     11362.000000  11362.000000  11362.000000
# mean       0.107551         0.015842      0.021475      0.770111
# std        0.309827         0.124871      0.144968      0.420780
# min        0.000000         0.000000      0.000000      0.000000
# 25%        0.000000         0.000000      0.000000      1.000000
# 50%        0.000000         0.000000      0.000000      1.000000
# 75%        0.000000         0.000000      0.000000      1.000000
# max        1.000000         1.000000      1.000000      1.000000
#
#        times_homeless_past_three_years  times_in_permanent_housing  \
# count                      5202.000000                11362.000000
# mean                          1.346790                    0.139236
# std                           1.122937                    1.042184
# min                           0.000000                    0.000000
# 25%                           1.000000                    0.000000
# 50%                           1.000000                    0.000000
# 75%                           2.000000                    0.000000
# max                           4.000000                   68.000000
#
#         transsexual  veteran_status  noncash_benefit_other  \
# count  11362.000000    11362.000000           11362.000000
# mean       0.002640        0.192836               0.019187
# std        0.051319        0.394543               0.137187
# min        0.000000        0.000000               0.000000
# 25%        0.000000        0.000000               0.000000
# 50%        0.000000        0.000000               0.000000
# 75%        0.000000        0.000000               0.000000
# max        1.000000        1.000000               1.000000
#
#        noncash_benefit_temprental  noncash_benefit_foodstamps  \
# count                11362.000000                11362.000000
# mean                     0.002728                    0.265094
# std                      0.052165                    0.441403
# min                      0.000000                    0.000000
# 25%                      0.000000                    0.000000
# 50%                      0.000000                    0.000000
# 75%                      0.000000                    1.000000
# max                      1.000000                    1.000000
#
#        noncash_benefit_tanfother  noncash_benefit_tanfchildcare  \
# count               11362.000000                   11362.000000
# mean                    0.005457                       0.006689
# std                     0.073671                       0.081516
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                     0.000000                       0.000000
# 75%                     0.000000                       0.000000
# max                     1.000000                       1.000000
#
#        noncash_benefit_tanftransportation  noncash_benefit_wic  \
# count                        11362.000000         11362.000000
# mean                             0.007481             0.026844
# std                              0.086173             0.161634
# min                              0.000000             0.000000
# 25%                              0.000000             0.000000
# 50%                              0.000000             0.000000
# 75%                              0.000000             0.000000
# max                              1.000000             1.000000
#
#        noncash_benefit_publichousing  health_insurance_medicare  \
# count                   11362.000000               11362.000000
# mean                        0.014522                   0.076571
# std                         0.119635                   0.265921
# min                         0.000000                   0.000000
# 25%                         0.000000                   0.000000
# 50%                         0.000000                   0.000000
# 75%                         0.000000                   0.000000
# max                         1.000000                   1.000000
#
#        health_insurance_pirvate  health_insurance_stateadult  \
# count              11362.000000                 11362.000000
# mean                   0.008801                     0.026580
# std                    0.093405                     0.160859
# min                    0.000000                     0.000000
# 25%                    0.000000                     0.000000
# 50%                    0.000000                     0.000000
# 75%                    0.000000                     0.000000
# max                    1.000000                     1.000000
#
#        health_insurance_employer  health_insurance_medicaid  \
# count               11362.000000               11362.000000
# mean                    0.009593                   0.329255
# std                     0.097479                   0.469964
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   1.000000
# max                     1.000000                   1.000000
#
#        health_insurance_statechild  health_insurance_cobra  \
# count                 11362.000000            11362.000000
# mean                      0.031421                0.002200
# std                       0.174459                0.046858
# min                       0.000000                0.000000
# 25%                       0.000000                0.000000
# 50%                       0.000000                0.000000
# 75%                       0.000000                0.000000
# max                       1.000000                1.000000
#
#        health_insurance_veteranadmin  disability_type_hivaids  \
# count                   11362.000000             11362.000000
# mean                        0.137828                 0.015842
# std                         0.344734                 0.124871
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 0.000000
# max                         1.000000                 1.000000
#
#        disability_type_other  disability_type_dualdiagnosis  \
# count           11362.000000                   11362.000000
# mean                0.000264                       0.000088
# std                 0.016248                       0.009382
# min                 0.000000                       0.000000
# 25%                 0.000000                       0.000000
# 50%                 0.000000                       0.000000
# 75%                 0.000000                       0.000000
# max                 1.000000                       1.000000
#
#        disability_type_alcoholdrug  disability_type_developmental  \
# count                 11362.000000                   11362.000000
# mean                      0.040222                       0.020331
# std                       0.196488                       0.141136
# min                       0.000000                       0.000000
# 25%                       0.000000                       0.000000
# 50%                       0.000000                       0.000000
# 75%                       0.000000                       0.000000
# max                       1.000000                       1.000000
#
#        disability_type_substance  disability_type_physical  \
# count               11362.000000              11362.000000
# mean                    0.000440                  0.100070
# std                     0.020974                  0.300107
# min                     0.000000                  0.000000
# 25%                     0.000000                  0.000000
# 50%                     0.000000                  0.000000
# 75%                     0.000000                  0.000000
# max                     1.000000                  1.000000
#
#        disability_type_chronichealth  disability_type_hearing  \
# count                   11362.000000             11362.000000
# mean                        0.076219                 0.000088
# std                         0.265360                 0.009382
# min                         0.000000                 0.000000
# 25%                         0.000000                 0.000000
# 50%                         0.000000                 0.000000
# 75%                         0.000000                 0.000000
# max                         1.000000                 1.000000
#
#        disability_type_alcohol  disability_type_vision  disability_type_drug  \
# count             11362.000000            11362.000000          11362.000000
# mean                  0.027196                0.000264              0.034765
# std                   0.162661                0.016248              0.183192
# min                   0.000000                0.000000              0.000000
# 25%                   0.000000                0.000000              0.000000
# 50%                   0.000000                0.000000              0.000000
# 75%                   0.000000                0.000000              0.000000
# max                   1.000000                1.000000              1.000000
#
#        disability_type_mentalhealth
# count                  11362.000000
# mean                       0.124538
# std                        0.330209
# min                        0.000000
# 25%                        0.000000
# 50%                        0.000000
# 75%                        0.000000
# max                        1.000000

# %%
# save it for easy loading
filename = '2017-01-22_homeless_summary_categorical_numeric.csv'
df_features.to_csv(os.path.join(datadir_proc, filename))
