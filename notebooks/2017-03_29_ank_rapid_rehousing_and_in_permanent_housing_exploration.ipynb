# %% [markdown]
# This notebook explores whether rapid rehousing is essentially a signal for getting into permanent housing.
#
# autor: annalie

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# # the "1" means: always reload modules marked with "%aimport"
# %autoreload 2

from __future__ import absolute_import, division, print_function
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os, sys
# from tqdm import tqdm
# import warnings

# sns.set_context("poster", font_scale=0.9)
sns.set_context("notebook", font_scale=1.0)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1000)

# add the data functions to the path
annalie = 'data/c4sf/C4SF-datasci-homeless/raw/'
datadir = os.path.join(os.getenv('HOME'), annalie)

src_data_dir = os.path.join(os.getcwd(), os.pardir, 'src/data')
sys.path.append(src_data_dir)

# functions to load the data
import dataset_homeless as ds

# %%
# load in and process the data in separate sheets

df_client = ds.process_data_client(simplify_strings=True, datadir=datadir)

df_enroll = ds.process_data_enrollment(simplify_strings=True, datadir=datadir)

# Only keep rows with entry dates starting in 2012
df_enroll = df_enroll[df_enroll['Entry Date'] >= '2012']
# Only keep rows with exit dates before 2016-06-01
df_enroll = df_enroll[df_enroll['Exit Date'] <= '2016-06-01']

df_disability = ds.process_data_disability(simplify_strings=True, datadir=datadir)

df_healthins = ds.process_data_healthins(simplify_strings=True, datadir=datadir)

df_benefit = ds.process_data_benefit(simplify_strings=True, datadir=datadir)

df_income = ds.process_data_income(simplify_strings=True, datadir=datadir)

df_project = ds.process_data_project(simplify_strings=True, datadir=datadir)

df_service = ds.process_data_service(simplify_strings=True, datadir=datadir)

df_bedinv = ds.process_data_bedinventory(simplify_strings=True, datadir=datadir)

# Join the client information with enrollment information.
# Inner join because we want to only keep individuals
# for whom we have both client and enrollment information.
df = df_client.merge(df_enroll, how='inner', left_index=True, right_index=True)

# just choose the first non-cash benefit; this is too simple!
# TODO: join on the exact Project ID, and possible Date
df = df.merge(df_benefit.reset_index().groupby(by=['Personal ID'])[['Non-Cash Benefit']].nth(0),
              how='left', left_index=True, right_index=True)
# # possible fix for above, but this isn't working properly (results in too many rows);
# # probably need date too, but they do not align
# df.reset_index().merge(df_benefit.reset_index()[['Personal ID', 'Project Entry ID', 'Non-Cash Benefit']].drop_duplicates(),
#                        how='left',
#                        on=['Personal ID', 'Project Entry ID'],
#                       ).drop_duplicates().set_index('Personal ID')

df['Non-Cash Benefit'] = df['Non-Cash Benefit'].fillna('None')

# add information about their disability status
# just choose the first disability; this is too simple!
# TODO: join on the exact Project ID
df = df.merge(df_disability.reset_index().groupby(by=['Personal ID'])[['Disability Type']].nth(0),
              how='left', left_index=True, right_index=True)
# # possible fix for above, but this isn't working properly (results in too many rows);
# # probably need date too, but they do not align
# df.reset_index().merge(df_disability.reset_index()[['Personal ID', 'Project Entry ID', 'Disability Type']].drop_duplicates(),
#                        how='left',
#                        on=['Personal ID', 'Project Entry ID'],
#                       ).drop_duplicates().set_index('Personal ID')

df['Disability Type'] = df['Disability Type'].fillna('None')

# add Project Type Code to DataFrame
df = df.merge(df_project[['Project Name',
                          'Project Type Code',
                          'Address City',
                          'Address Postal Code',
                         ]], left_on=['Project ID'], right_index=True)

# sort by entry date
df = df.sort_values('Entry Date')

# rename the columns to have no spaces
df = ds.rename_columns(df)

# %%
df_resetidx = df.reset_index()

df.shape
len(df_resetidx['Personal ID'].unique())
# Out:
# 11362

# %%
df.head()
# Out:
#               race  ethnicity  gender veteran_status  project_entry_id  \
# Personal ID
# 214224       white  nonlatino    male          False            203474
# 194592       white  nonlatino    male           True            150135
# 179384       white     latino  female          False            155873
# 183019       white     latino    male          False            155872
# 182885       black  nonlatino    male          False            153810
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 214224                        60              00000 2012-01-01 2013-09-08
# 194592                        53              91103 2012-01-02 2013-08-31
# 179384                        50              93245 2012-01-03 2016-01-28
# 183019                        28              93950 2012-01-03 2012-10-26
# 182885                        48              93911 2012-01-04 2013-05-02
#
#              project_id housing_status_project_start  \
# Personal ID
# 214224             2938                 cat1homeless
# 194592             2134                 cat1homeless
# 179384             2086                 cat1homeless
# 183019             2086                 cat1homeless
# 182885             2086                 cat1homeless
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 214224                                      hotel             NaN
# 194592                                     family             NaN
# 179384                                    streets          CA-506
# 183019                                    streets          CA-506
# 182885                                emershelter             NaN
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 214224             203474                True                          False
# 194592             150135                True                          False
# 179384             155873               False                          False
# 183019             155872               False                          False
# 182885             153810               False                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 214224                                  NaN                       NaN
# 194592                                  NaN                       NaN
# 179384                                  NaN                       NaN
# 183019                                  NaN                       NaN
# 182885                                  NaN                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 214224                 False                False                      NaT
# 194592                 False                False                      NaT
# 179384                 False                False                      NaT
# 183019                 False                False                      NaT
# 182885                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 214224                         False                    NaN
# 194592                         False                    NaN
# 179384                         False                    NaN
# 183019                         False                    NaN
# 182885                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 214224                     False            616                          NaN
# 194592                     False            607                          NaN
# 179384                     False           1486                          NaN
# 183019                     False            297                          NaN
# 182885                     False            484                          NaN
#
#             head_of_household noncash_benefit disability_type  \
# Personal ID
# 214224                  False            None        physical
# 194592                  False      foodstamps    mentalhealth
# 179384                   True            None            None
# 183019                  False            None            None
# 182885                  False            None            None
#
#                                                  project_name  \
# Personal ID
# 214224                 SCz - HSC - Page Smith Community House
# 194592            MOSBE Veterans Transition Center - Outreach
# 179384       MOSBE The Salvation Army - Good Samaritan Center
# 183019       MOSBE The Salvation Army - Good Samaritan Center
# 182885       MOSBE The Salvation Army - Good Samaritan Center
#
#                project_type_code address_city  address_postal_code
# Personal ID
# 214224       transitionalhousing   Santa Cruz                95060
# 194592                     other       Marina                93933
# 179384              servicesonly          NaN                93955
# 183019              servicesonly          NaN                93955
# 182885              servicesonly          NaN                93955

# %%
len(df.isin(['compass']))
# zzz*inactive*MOSBE CCHAS (John XXIII) - Bus Passes                            76
# zzz*Inactive* SCz - FIT - ESG Homeless Prevention                             75
# SCz-Veterans Resource Center- SSVF - Priority 1 SCz - RRH Santa Cruz          67
# zzz*Inactive* SCz - FIT - ESG Rapid Rehousing                                 65
# MOSBE SOP - Transitional Housing - Lexington Court                            62
# SCz - FIT - RRH SSVF - HSC Clients                                            59
# MOSBE HRC - SSVF- P1 - VTC HP                                                 58
# SCz-Veterans Resource Center- SSVF - Priority 1 SCz - HP Santa Cruz           58
# zzz*inactive* MOSBE Interim - MCHOME - Lexington                              56
# MOSBE SOP - Hamilton Family Units -DO NOT USE-                                55
# SCz - HSC - NO DATA HERE                                                      54
# SCz - FIT - HUD/DA (Clean & Sober)                                            53
# MOSBE Interim - Sunflower Gardens - PSH                                       50
# zzz*inactive*MOSBE CCHAS (John XXIII) - Services                              50
# ZZZ* INACTIVE*ZZZ-MOSBE HRC - SSVF-P2 VRSi - Santa Cruz Clients               50
# ZZZ*INACTIVE*ZZZ- MOSBE HRC - SSVF-P2 VRSi- Monterey/San Benito Clients       48
# MOSBE HRC - SSVF- P1 - CCCIL HP                                               46
# MOSBE The Salvation Army - Good Samaritan Center                              46
# SCz - FIT - HP SSVF - HSC Clients                                             44
# MOSBE HRC - SSVF- P1 - HRC HP                                                 42
# SCz - FIT - Brommer                                                           40
# SCz - Salvation Army- Winter (Cold Weather) Shelter                           38
# MOSBE The Salvation Army - Casa de las Palmas                                 34
# SCz - County Office of Education                                              34
# MOSBE Franciscan Workers - House of Peace                                     33
# SCz - Encompass - River Street Shelter PATH                                   32
# MOSBE Franciscan Workers of Junipero Serra                                    32
# SCz - FIT - HP SSVF - FIT Clients                                             30
# SCz - HSD -CHAMP                                                              27
# MOSBE CHS - Safe Passage                                                      27
# MOSBE The Salvation Army - Phase II                                           22
# SCz - FIT - RRH SSVF - FIT Clients                                            22
# MOSBE CSUMB - Chinatown Project                                               22
# SCz-FIT-County Planning Department Grant                                      19
# MOSBE San Benito County - Helping Hands                                       17
# MOSBE CHS - RHY - BCP ES                                                      16
# zzz*inactive*MOSBE CCHAS (John XXIII) - Emergency Shelter                     16
# MOSBE CHS - Elm House                                                         16
# zzz*inactive*MOSBE CCHAS (John XXIII) - Calm Waters (Master)                  14
# MOSBE Interim - Sandy Shores                                                  14
# MOSBE Interim - MCHOME S+C                                                    14
# MOSBE Franciscan Workers - Drop-in Center                                     14
# MOSBE HRC - SSVF- P2 - HRC RRH                                                14
# SCz - Front St.                                                               13
# zzz*inactive*MOSBE CCHAS (John XXIII) - Casa de Paz (Master)                  12
# MOSBE Community Human Services (CHS)                                          12
# SCz - FIT - HP SSVF - PVSS Clients                                            11
# MOSBE HRC - SSVF- P2  HRC- RRH - Santa Cruz Clients                           10
# MOSBE Interim - MCHOPE                                                        10
# SCz - HPHP-S+CG1,2,3                                                          10
# SCz - Encompass - Anderson                                                     9
# SCz - HPHP-MATCH Housing Inebriates I                                          9
# MOSBE Interim - Sunflower Gardens - THU                                        8
# MOSBE San Benito Homeless Coalition                                            6
# SCz - HPHP-MATCH Housing Inebriates II                                         6
# MOSBE HRC - SSVF- P2 - HRC HP                                                  4
# MOSBE SOP - Winter Warming Shelter                                             4
# MOSBE HRC - SSVF- P2  HRC- HP - Santa Cruz Clients                             4
# MOSBE Housing Authority - S + C Vouchers                                       4
# zzz*inactive*MOSBE CCHAS (John XXIII) - Calm Waters Families                   4
# SCz - HPHP-S+CG7                                                               3
# SCz - HPHP-MATCH Housing Inebriates III                                        3
# SCz - HPHP-S+CG4 Puentes Going Home                                            2
# MOSBE HRC - FSP                                                                2
# SCz - HSD -CHAMP- FIT Clients                                                  2
# zzz*Inactive* SCz - Salvation Army - Corner House (HUD)                        2
# SCz - HPHP-Nuevo Sol (HUD)                                                     2
# SCz - HSC - 180/2020                                                           2
# zzz*inactive*MOSBE CCHAS (John XXIII) Other Rental Assistance                  2
# zzz*inactive*MOSBE CCHAS (John XXIII)                                          2
# SCz - FIT - RRH SSVF - PVSS Clients                                            2
# MOSBE Interim                                                                  2
# zzz*inactive*MOSBE MC Behavioral Health - PATH Enrolled                        1
# SCz - HSC - HUD Bonus Program                                                  1
# SCz - PVSS                                                                     1
# SCz - HSC - CFET Program                                                       1
# SCz - HPHP-S+CG6                                                               1
# SCz - HSC - HSC PSH                                                            1
# Name: project_name, dtype: int64

# %% [markdown]
#     Number of records (ids) in df: 58209
#     Number of unique ids in df: 11362

# %% [markdown]
# ### Number of times in permanent housing

# %%
# create new column with a numeric value for the variable 'In Permanent Housing'
df_enroll['category In Permanent Housing'] = df_enroll['In Permanent Housing'].apply(lambda x: 1 if x==True else 0)

# create a dataframe of only the variables that are to be grouped
# select only the people that have been in permanent housing before
# group dataframe by Personal ID and sum the times that this person was in permanent housing
# rename the column with the sum of the grouped rows to the number of times this person had been in permanent housing
df_housing = df_enroll.reset_index()[['Personal ID', 'category In Permanent Housing']]

df_housing = df_housing[df_housing['category In Permanent Housing']==1] \
                        .groupby(by=['Personal ID']) \
                        .sum() \
                        .rename(columns={'category In Permanent Housing': 'times_in_permanent_housing'})

# merge the dataframe that contains the number of times enrolled with the large dataframe
df = df.merge(df_housing, how='left', left_index=True, right_index=True)
# replace the missing values in the column times_enrolled with 0 
df['times_in_permanent_housing'].fillna(0, inplace=True)

df.head()
# Out:
#               race ethnicity  gender veteran_status  project_entry_id  \
# Personal ID
# 173781       white    latino  female          False            252608
# 173781       white    latino  female          False            314080
# 173782       white    latino    male          False            314084
# 173783       white    latino  female          False            314085
# 173803       white    latino  female          False            201286
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 173781                        34              93907 2014-02-28 2014-02-28
# 173781                        35              93907 2014-05-06 2014-09-30
# 173782                        10              93905 2014-05-06 2014-09-30
# 173783                        12              93905 2014-05-06 2014-09-30
# 173803                        32              93905 2013-02-08 2013-04-27
#
#              project_id housing_status_project_start  \
# Personal ID
# 173781             2104                       atrisk
# 173781             2101                 cat1homeless
# 173782             2101                 cat1homeless
# 173783             2101                 cat1homeless
# 173803             2101                 cat1homeless
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 173781                                     rental             NaN
# 173781                                emershelter          CA-506
# 173782                                emershelter          CA-506
# 173783                                emershelter          CA-506
# 173803                                     friend             NaN
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 173781             252608               False                          False
# 173781             314080               False                          False
# 173782             314080               False                           True
# 173783             314080               False                           True
# 173803             201286               False                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 173781                                  NaN                       NaN
# 173781                                    2                       NaN
# 173782                                    2                       NaN
# 173783                                    2                       NaN
# 173803                                  NaN                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 173781                 False                False                      NaT
# 173781                 False                False                      NaT
# 173782                 False                False                      NaT
# 173783                 False                False                      NaT
# 173803                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 173781                          True                     24
# 173781                          True                     12
# 173782                          True                     12
# 173783                          True                     12
# 173803                          True                     12
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 173781                     False              0                          NaN
# 173781                     False            147                          NaN
# 173782                     False            147                          NaN
# 173783                     False            147                          NaN
# 173803                     False             78                          NaN
#
#             head_of_household noncash_benefit disability_type  \
# Personal ID
# 173781                  False      foodstamps            None
# 173781                  False      foodstamps            None
# 173782                  False            None            None
# 173783                  False            None            None
# 173803                  False      foodstamps            None
#
#                                                   project_name  \
# Personal ID
# 173781       MOSBE SOP - Mobile Outreach Shelter Program - ...
# 173781                           MOSBE SOP - Natividad Shelter
# 173782                           MOSBE SOP - Natividad Shelter
# 173783                           MOSBE SOP - Natividad Shelter
# 173803                           MOSBE SOP - Natividad Shelter
#
#             project_type_code address_city  address_postal_code  \
# Personal ID
# 173781         streetoutreach          NaN                93933
# 173781       emergencyshelter       Marina                93933
# 173782       emergencyshelter       Marina                93933
# 173783       emergencyshelter       Marina                93933
# 173803       emergencyshelter       Marina                93933
#
#              times_in_permanent_housing
# Personal ID
# 173781                              0.0
# 173781                              0.0
# 173782                              0.0
# 173783                              0.0
# 173803                              0.0

# %%
# number of records in the dataset
df.shape
# Out:
# (58209, 34)

# %% [markdown]
# ### Determine whether rapid rehousing is essentially a signal for getting into permanent housing
# - show the distribution of the people that received rapid rehousing and received permanent housing versus the people that did not receive permanent housing

# %%
# address postal code for the same organization (project name) is not consistent, therefore, remove this variable
# remove duplicated rows

df2 = df.drop('address_postal_code', axis=1)
df2 = df2.drop_duplicates()
df2.shape
# Out:
# (54400, 33)

# %%
df2.project_type_code.unique()
# Out:
# array(['streetoutreach', 'emergencyshelter', 'other',
#        'transitionalhousing', 'servicesonly', 'homelessnessprevention',
#        'rapidrehousing', 'permanentsupportivehousing'], dtype=object)

# %%
# select only the cases where 'project_type_code' is 'rapidrehousing'
df_rapidrehousing = df2[(df2['project_type_code'] == 'rapidrehousing')]

# df_rapidrehousing = df_rapidrehousing[['project_type_code', 'in_permanent_housing']]

# %%
pd.value_counts(df_rapidrehousing['in_permanent_housing'].values, sort=False)
# Out:
# False    627
# True     615
# dtype: int64

# %% [markdown]
# ### When address postal code is removed from the dataset, rapid rehousing leads in more cases not to permanent housing compared to receiving permanent housing

# %%
df_rapidrehousing['in_permanent_housing'].value_counts().plot(kind='bar')

# %% [markdown]
# Almost 50% of the people that received rapidrehousing got in permanent housing, whereas the other 50% didn't

# %% [markdown]
# ### Determine how long people spend in rapid rehousing before they receive permanent housing
# Assume that people that received permanent housing were for a shorter amount of time in rapid rehousing than 	people that did not receive permanent housing
# 1. Show a frequency distribution of the time that people spend in rapid rehousing and received permanent housing (*days to residential move in*)
# 2. Show a frequency distribution of the time that people spend in rapid rehousing and did not receive permanent 	housing (*days enrolled*)

# %%
# 1.
# create dataframe of people that were in rapid rehousing and received permanent housing 
# and where days to residential move in is not missing 
df_rapidrehousing_permanent_housing = df_rapidrehousing[(df_rapidrehousing['in_permanent_housing'] == True) & df_rapidrehousing['days_to_residential_move_in'].notnull()]
df_rapidrehousing_permanent_housing.head()
# Out:
#               race  ethnicity gender veteran_status  project_entry_id  \
# Personal ID
# 174275       white  nonlatino   male           True            469696
# 174757       white     latino   male           True            432480
# 174839       black     latino   male           True            443047
# 175160       black  nonlatino   male           True            471957
# 176042       white  nonlatino   male           True            445127
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 174275                        48              93905 2015-01-20 2015-06-01
# 174757                        53              93901 2014-10-01 2015-09-04
# 174839                        65              93940 2015-03-19 2016-04-21
# 175160                        60              93901 2015-06-11 2015-09-29
# 176042                        58              93901 2015-03-17 2015-06-23
#
#              project_id housing_status_project_start  \
# Personal ID
# 174275             3385                 cat1homeless
# 174757             3382                 cat1homeless
# 174839             3387                 cat1homeless
# 175160             3385                 cat1homeless
# 176042             3382                      unknown
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 174275                                    streets          CA-506
# 174757                                    streets          CA-506
# 174839                        transitionalhousing          CA-506
# 175160                                    streets          CA-508
# 176042                                    streets          CA-506
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 174275             469696                True                           True
# 174757             432480                True                           True
# 174839             443047                True                          False
# 175160             471957               False                          False
# 176042             445127                True                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 174275                                    2                       NaN
# 174757                                    2                        24
# 174839                                    2                        24
# 175160                                    1                         7
# 176042                                    1                         0
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 174275                  True                 True               2015-02-01
# 174757                  True                 True               2015-08-19
# 174839                 False                 True               2016-03-07
# 175160                 False                 True               2015-06-16
# 176042                 False                 True               2015-05-15
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 174275                         False                    NaN
# 174757                         False                    NaN
# 174839                         False                    NaN
# 175160                         False                    NaN
# 176042                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 174275                     False            132                         12.0
# 174757                     False            338                        322.0
# 174839                     False            399                        354.0
# 175160                     False            110                          5.0
# 176042                     False             98                         59.0
#
#             head_of_household noncash_benefit disability_type  \
# Personal ID
# 174275                   True            None   chronichealth
# 174757                   True      foodstamps    mentalhealth
# 174839                   True            None   chronichealth
# 175160                   True      foodstamps        physical
# 176042                   True      foodstamps   chronichealth
#
#                                                   project_name  \
# Personal ID
# 174275                          MOSBE HRC - SSVF- P1 - HRC RRH
# 174757       MOSBE HRC - SSVF- P2 HRC - RRH- Monterey/San B...
# 174839                          MOSBE HRC - SSVF- P1 - VTC RRH
# 175160                          MOSBE HRC - SSVF- P1 - HRC RRH
# 176042       MOSBE HRC - SSVF- P2 HRC - RRH- Monterey/San B...
#
#             project_type_code address_city  times_in_permanent_housing
# Personal ID
# 174275         rapidrehousing      Salinas                         2.0
# 174757         rapidrehousing      Salinas                         2.0
# 174839         rapidrehousing      Salinas                         1.0
# 175160         rapidrehousing      Salinas                         1.0
# 176042         rapidrehousing      Salinas                         1.0

# %%
df_rapidrehousing_permanent_housing_resetidx = df_rapidrehousing_permanent_housing.reset_index()

df_rapidrehousing_permanent_housing.shape
# len(df_rapidrehousing_permanent_housing_resetidx['Personal ID'].unique())
# Out:
# (532, 33)

# %% [markdown]
# Number of people that received rapid rehousing and permanent housing:
#
# - 532 records
# - 516 unique ids

# %%
# count number of records where times_in_permanent_housing > 1.0
len(df_rapidrehousing_permanent_housing[(df_rapidrehousing_permanent_housing['times_in_permanent_housing'] > 1.0)])
# Out:
# 117

# %%
# max number of days to residential move in
df_rapidrehousing_permanent_housing['days_to_residential_move_in'].max()
# Out:
# 443.0

# %%
n = 443
ax = df_rapidrehousing_permanent_housing['days_to_residential_move_in'].value_counts().plot(kind='bar', title='Frequency distribution for number of days to residential move in')
ticks = ax.xaxis.get_ticklocs()
ax.xaxis.set_ticks(ticks[::n])

ax.figure.show()

# %%
# 2.
# create dataframe of people that were in rapid rehousing and did not receive permanent housing 
df_rapidrehousing_not_permanent_housing = df_rapidrehousing[(df_rapidrehousing['in_permanent_housing'] == False)]

# %%
df_rapidrehousing_not_permanent_housing.shape
# Out:
# (627, 33)

# %%
# max number of days enrolled
df_rapidrehousing_not_permanent_housing['days_enrolled'].max()
# Out:
# 835

# %%
n = 835
ax = df_rapidrehousing_not_permanent_housing['days_enrolled'].value_counts().plot(kind='bar', title='Frequency distribution for number of days enrolled for people that did not receive permanent housing')
ticks = ax.xaxis.get_ticklocs()
ax.xaxis.set_ticks(ticks[::n])

ax.figure.show()

# %% [markdown]
# ### Determine of those people that have received permanent housing before, whether rapid rehousing was effective
# - show of the people that received permanent housing multiple times the % that received rapid rehousing as their first project

# %%
# show number of records that has received permanent housing multiple times 
len(df2)
len(df2[df2['times_in_permanent_housing'] > 1.0])
# Out:
# 993

# %%
# create a dataframe that contains the people that received permanent housing before
df_perm_housing_before = df2[df2['times_in_permanent_housing'] > 1.0]

# %%
# keep the first record of each Personal ID 
# calculate the % of the people that were in rapid rehousing

# reset index
df_perm_housing_before_resetidx = df_perm_housing_before.reset_index()

# get the first row of each group
df_first_project = df_perm_housing_before_resetidx.groupby('Personal ID').first()

# count project type codes
pd.value_counts(df_first_project['project_type_code'].values, sort=False)
# Out:
# rapidrehousing                40
# streetoutreach                 5
# transitionalhousing            9
# servicesonly                  23
# homelessnessprevention        63
# emergencyshelter              37
# other                         26
# permanentsupportivehousing     3
# dtype: int64

# %%
df_first_project['project_type_code'].value_counts().plot(kind='bar', title='first project type for people that received permanent housing, but returned as homeless')

# %%
df_first_project.shape
# Out:
# (206, 33)

# %%
# percentage of people that received rapid rehousing and later returned as homelessness
40/206*100
# Out:
# 19.41747572815534

# %% [markdown]
# ## Compare results for permanent housing over different organisations

# %%
df.columns
# Out:
# Index([u'race', u'ethnicity', u'gender', u'veteran_status',
#        u'project_entry_id', u'client_age_at_entry', u'last_permanent_zip',
#        u'entry_date', u'exit_date', u'project_id',
#        u'housing_status_project_start',
#        u'living_situation_before_program_entry', u'client_location',
#        u'household_id', u'disabling_condition',
#        u'continuously_homeless_one_year', u'times_homeless_past_three_years',
#        u'months_homeless_this_time', u'chronic_homeless',
#        u'in_permanent_housing', u'residential_move_in_date',
#        u'domestic_violence_victim', u'months_ago_dv_occurred',
#        u'dv_currently_fleeing', u'days_enrolled',
#        u'days_to_residential_move_in', u'head_of_household',
#        u'noncash_benefit', u'disability_type', u'project_name',
#        u'project_type_code', u'address_city', u'address_postal_code'],
#       dtype='object')

# %%
print ('unique organizations: ', len(df['project_name'].unique()))
print ('unique zipcodes: ', len(df['address_postal_code'].unique()))
print (df['address_city'].unique())
# Out:
# unique organizations:  131
# unique zipcodes:  18
# ['Santa Cruz' 'Marina' nan 'Salinas' 'Hollister' 'Watsonville' 'Monterey'
#  'Seaside' 'Capitola' 'Menlo Park']

# %%
# create dataframe for only Monterey

df_monterey = df[df['address_city']=='Monterey']
print ('unique organizations in Monterey:', len(df_monterey['project_name'].unique()))
df_monterey.head(1)
# Out:
# unique organizations in Monterey: 13
#               race ethnicity gender veteran_status  project_entry_id  \
# Personal ID
# 196614       white    latino   male          False            182710
#
#              client_age_at_entry last_permanent_zip entry_date  exit_date  \
# Personal ID
# 196614                        28              93933 2012-02-03 2014-10-14
#
#              project_id housing_status_project_start  \
# Personal ID
# 196614             2141                       housed
#
#             living_situation_before_program_entry client_location  \
# Personal ID
# 196614                        transitionalhousing          CA-506
#
#              household_id disabling_condition continuously_homeless_one_year  \
# Personal ID
# 196614             182710                True                          False
#
#             times_homeless_past_three_years months_homeless_this_time  \
# Personal ID
# 196614                                    0                       NaN
#
#             chronic_homeless in_permanent_housing residential_move_in_date  \
# Personal ID
# 196614                 False                False                      NaT
#
#             domestic_violence_victim months_ago_dv_occurred  \
# Personal ID
# 196614                         False                    NaN
#
#             dv_currently_fleeing  days_enrolled  days_to_residential_move_in  \
# Personal ID
# 196614                     False            984                          NaN
#
#             head_of_household noncash_benefit disability_type  \
# Personal ID
# 196614                   True      foodstamps    mentalhealth
#
#                                 project_name project_type_code address_city  \
# Personal ID
# 196614       MOSBE Interim - MCHOME Enrolled    streetoutreach     Monterey
#
#              address_postal_code
# Personal ID
# 196614                     93942

# %%
# get counts and percentage for permanent housing per organization

print (len(df_monterey))
df_monterey = df_monterey.drop('address_postal_code', axis=1)
df_monterey = df_monterey.drop_duplicates()
print (len(df_monterey))
df_monterey
# Out:
# 1187
# 1095
#                    race  ethnicity     gender veteran_status  \
# Personal ID
# 196614            white     latino       male          False
# 182034            white  nonlatino       male          False
# 182224            white  nonlatino       male          False
# 226482            white     latino       male          False
# 198746            white  nonlatino       male           True
# 185915            white  nonlatino       male          False
# 176873            white  nonlatino     female          False
# 179085            white  nonlatino       male          False
# 183879            white     latino     female          False
# 276839            white     latino       male          False
# 222733            white  nonlatino       male          False
# 222743            white  nonlatino       male          False
# 226306            white  nonlatino     female          False
# 226398            white    unknown     female          False
# 221999            black  nonlatino     female          False
# 230588            white     latino       male          False
# 184274            white  nonlatino     female          False
# 224314            black  nonlatino       male          False
# 229270            white  nonlatino     female          False
# 184597       pacificisl  nonlatino       male          False
# 177607            white  nonlatino     female          False
# 226578            white  nonlatino       male          False
# 177607            white  nonlatino     female          False
# 174769            black  nonlatino     female          False
# 218593            white  nonlatino       male          False
# 235990            white     latino       male          False
# 181791            white  nonlatino     female          False
# 230013            white  nonlatino       male          False
# 185172            black  nonlatino     female          False
# 183084            black  nonlatino     female          False
# 271187            white  nonlatino       male          False
# 234516            white  nonlatino     female          False
# 237327            black  nonlatino     female          False
# 234252            white  nonlatino       male          False
# 276906            white  nonlatino       male          False
# 276319            black  nonlatino       male          False
# 276856            white  nonlatino     female          False
# 276849            white  nonlatino       male          False
# 276836            white  nonlatino       male          False
# 178690            white     latino     female          False
# 235806       amerindian  nonlatino     female          False
# 234220            white     latino       male          False
# 176984            white  nonlatino     female          False
# 243558            white  nonlatino       male          False
# 182505            white  nonlatino     female          False
# 174598       amerindian  nonlatino     female          False
# 181735            white  nonlatino       male          False
# 182506            white     latino       male          False
# 243701       amerindian  nonlatino     female          False
# 276405            white     latino       male          False
# 250492       amerindian  nonlatino       male           True
# 251768            white     latino     female          False
# 251769            white     latino     female          False
# 251766            white     latino       male           True
# 249937            white     latino       male           True
# 251337            white  nonlatino       male           True
# 251349            white  nonlatino       male           True
# 251351            black  nonlatino       male           True
# 251353            black  nonlatino       male           True
# 251799            black  nonlatino     female          False
# 251343       pacificisl  nonlatino     female           True
# 189479            black  nonlatino     female          False
# 252090            black  nonlatino       male           True
# 251743            white     latino       male           True
# 251706            white  nonlatino       male           True
# 251702            black  nonlatino       male           True
# 251789            asian  nonlatino     female          False
# 252582            white     latino       male           True
# 251801            white     latino     female          False
# 243505            white  nonlatino     female          False
# 251950            white     latino       male           True
# 252011            black  nonlatino       male           True
# 252016            black  nonlatino     female          False
# 252043            white  nonlatino       male           True
# 252045            white  nonlatino     female          False
# 252046            white  nonlatino       male          False
# 252084            white  nonlatino     female          False
# 252082            white  nonlatino       male           True
# 252587            white  nonlatino       male           True
# 252152            black  nonlatino       male           True
# 252155            black  nonlatino     female          False
# 252154            black  nonlatino     female          False
# 252590       amerindian     latino       male           True
# 252914            black  nonlatino       male           True
# 252910            white  nonlatino       male           True
# 252909            white  nonlatino       male           True
# 252845            white  nonlatino       male           True
# 243586            white  nonlatino       male          False
# 253280            asian  nonlatino       male           True
# 253245            black  nonlatino       male           True
# 253890            black  nonlatino       male          False
# 253599            white     latino       male          False
# 253572            white  nonlatino       male           True
# 253595            white  nonlatino       male           True
# 253597            white     latino     female          False
# 253651            white     latino       male          False
# 253650            white     latino     female          False
# 253648            white  nonlatino     female          False
# 253647            white     latino       male           True
# 253710            white  nonlatino     female           True
# 253713            black  nonlatino     female           True
# 244995            white  nonlatino     female          False
# 253793            black     latino       male           True
# 253795            white  nonlatino     female          False
# 253794            white  nonlatino       male           True
# 254105            white     latino       male          False
# 254158            white  nonlatino       male           True
# 254095            white  nonlatino       male           True
# 254099            white     latino     female           True
# 254102            white     latino     female          False
# 254104            white     latino       male           True
# 178178            white     latino  transmtof          False
# 254456            white  nonlatino       male           True
# 254189            black  nonlatino       male           True
# 254185            white  nonlatino     female           True
# 254489            black  nonlatino       male           True
# 252071            black  nonlatino       male           True
# 254487            white     latino       male           True
# 254492            white     latino       male           True
# 254496            white     latino     female          False
# 254494            white     latino     female          False
# 226890            white  nonlatino     female          False
# 254560            white  nonlatino       male           True
# 254554            white  nonlatino       male           True
# 254562            white  nonlatino     female          False
# 254621            white  nonlatino       male           True
# 276408            white  nonlatino       male          False
# 254729            black  nonlatino       male           True
# 254849            white  nonlatino       male           True
# 254861            white     latino     female           True
# 254846            white  nonlatino       male           True
# 254851            white     latino       male           True
# 254845            white  nonlatino     female           True
# 254825            white  nonlatino       male           True
# 254811            black  nonlatino     female          False
# 254809            black  nonlatino       male           True
# 254866            white  nonlatino     female           True
# 254867            white  nonlatino       male          False
# 255026            white     latino       male           True
# 255055            black  nonlatino       male           True
# 255089            white  nonlatino       male           True
# 182291            white  nonlatino     female          False
# 255458            black  nonlatino       male           True
# 255557            white  nonlatino       male          False
# 255428            white  nonlatino       male           True
# 255671            white     latino       male           True
# 255589            black  nonlatino       male           True
# 255592            white  nonlatino       male           True
# 255591            black  nonlatino     female          False
# 255590            black  nonlatino     female          False
# 255686            white     latino       male           True
# 255687            white  nonlatino       male           True
# 256254            white  nonlatino       male           True
# 256251            white  nonlatino       male           True
# 256250            white  nonlatino       male           True
# 256258       amerindian  nonlatino     female          False
# 256388            black  nonlatino       male           True
# 256257       amerindian  nonlatino       male           True
# 256248            white  nonlatino       male           True
# 256390            black  nonlatino     female          False
# 214120            white  nonlatino       male           True
# 256259            white     latino       male           True
# 276260            white     latino     female          False
# 256261            white  nonlatino       male           True
# 256276            white     latino       male           True
# 256278            white     latino       male          False
# 256279            white  nonlatino     female          False
# 252811            white  nonlatino       male          False
# 256755            white     latino     female          False
# 256752            white     latino       male           True
# 256753            white     latino     female          False
# 256754            white     latino     female          False
# 256639            white  nonlatino       male           True
# 256971            white  nonlatino     female           True
# 259527            white     latino       male          False
# 256970            white  nonlatino       male           True
# 256958            white     latino       male           True
# 256968            white     latino     female          False
# 256967            white     latino       male           True
# 256993            black  nonlatino     female          False
# 256992       amerindian  nonlatino     female          False
# 256990            black  nonlatino       male           True
# 256987            white     latino       male           True
# 256995            black  nonlatino     female          False
# 257018       pacificisl  nonlatino       male           True
# 257186            white  nonlatino       male           True
# 243423            white  nonlatino       male           True
# 257261       pacificisl  nonlatino     female           True
# 257579            white  nonlatino       male           True
# 257680            white  nonlatino       male           True
# 257587            white  nonlatino       male           True
# 257589            black  nonlatino       male           True
# 257588            white  nonlatino     female          False
# 257586            white  nonlatino       male           True
# 257591            black  nonlatino       male          False
# 261145            black  nonlatino       male           True
# 257649            white  nonlatino       male           True
# 257662            white  nonlatino       male           True
# 254043            white  nonlatino     female          False
# 276380            white     latino     female          False
# 257735            white     latino       male           True
# 257753            white     latino       male           True
# 257755            white     latino     female          False
# 257907            white  nonlatino       male           True
# 243505            white  nonlatino     female          False
# 258076            white  nonlatino     female          False
# 258073            white     latino       male           True
# 258405            black  nonlatino       male           True
# 258338            black  nonlatino       male           True
# 258345            white  nonlatino       male           True
# 258425            white     latino       male           True
# 276295            white  nonlatino       male          False
# 258598       amerindian  nonlatino       male           True
# 258833       amerindian     latino       male           True
# 258830            black  nonlatino     female          False
# 258836            white  nonlatino       male           True
# 258828            black  nonlatino       male           True
# 258877            white  nonlatino       male          False
# 258901            white     latino       male          False
# 258891       amerindian  nonlatino       male           True
# 258900            white     latino     female          False
# 258879            white  nonlatino       male          False
# 258878            white  nonlatino     female          False
# 258871            white  nonlatino     female           True
# 258876            white  nonlatino     female          False
# 259097            white  nonlatino       male          False
# 258985            white  nonlatino       male           True
# 258984            white  nonlatino       male           True
# 259069            white  nonlatino       male           True
# 271302            white     latino       male          False
# 260367       amerindian     latino       male          False
# 259288            white  nonlatino       male           True
# 262047            white  nonlatino     female          False
# 262048            white     latino     female          False
# 259399            white  nonlatino       male           True
# 259470            white     latino       male           True
# 259485            white  nonlatino       male           True
# 259494            white     latino       male          False
# 259495            white     latino     female          False
# 259498            white     latino     female          False
# 259497            white     latino     female          False
# 259496            white     latino       male          False
# 259491            white     latino     female          False
# 259490            white  nonlatino       male           True
# 179036            white     latino     female          False
# 259770       amerindian  nonlatino     female           True
# 259705            white  nonlatino       male           True
# 277386            white  nonlatino     female          False
# 248727            white  nonlatino       male          False
# 260312            white  nonlatino       male           True
# 179148            white     latino     female          False
# 260299            white  nonlatino       male          False
# 260297            white  nonlatino     female           True
# 260295            white  nonlatino       male           True
# 260414            white  nonlatino       male           True
# 260415            white  nonlatino     female          False
# 260421            black  nonlatino       male           True
# 260422            white  nonlatino     female          False
# 260423            white  nonlatino     female          False
# 260425       pacificisl  nonlatino       male           True
# 260214            white  nonlatino       male          False
# 260588            white  nonlatino       male           True
# 260591            white  nonlatino     female          False
# 260590            white  nonlatino     female          False
# 260589            white  nonlatino     female           True
# 262067            white  nonlatino       male           True
# 262068            white     latino       male           True
# 262093            white  nonlatino       male           True
# 262122            white  nonlatino       male           True
# 239012            white  nonlatino       male          False
# 253651            white     latino       male          False
# 262155            white  nonlatino       male           True
# 253650            white     latino     female          False
# 239007            white     latino       male          False
# 253647            white     latino       male           True
# 253648            white  nonlatino     female          False
# 262189            black     latino       male          False
# 262186            white     latino     female           True
# 262159            black  nonlatino       male          False
# 262158            black  nonlatino       male          False
# 262157            black  nonlatino     female          False
# 261436            white     latino     female          False
# 173989            white     latino       male          False
# 262318            black  nonlatino       male           True
# 252016            black  nonlatino     female          False
# 252011            black  nonlatino       male           True
# 276339            white     latino       male          False
# 260194            white     latino       male           True
# 276332            white     latino       male          False
# 271315       pacificisl  nonlatino       male          False
# 262405            white  nonlatino     female           True
# 262418            white  nonlatino       male           True
# 261254            white  nonlatino     female          False
# 276358            white     latino       male          False
# 262518            white  nonlatino       male           True
# 262530            white     latino       male           True
# 262513            white     latino       male           True
# 262479            white     latino       male           True
# 262626            white     latino     female           True
# 262619            white     latino       male           True
# 262768            white  nonlatino       male           True
# 262755            white  nonlatino     female          False
# 262754            white     latino     female          False
# 262753            white     latino       male           True
# 255671            white     latino       male           True
# 262733            white  nonlatino     female          False
# 262734            white  nonlatino     female          False
# 262736            black  nonlatino       male           True
# 262731            white  nonlatino       male           True
# 276372            white     latino       male          False
# 276375            black  nonlatino       male          False
# 256755            white     latino     female          False
# 256754            white     latino     female          False
# 256753            white     latino     female          False
# 256752            white     latino       male           True
# 263043            white  nonlatino       male           True
# 263045            white     latino     female          False
# 263054            white  nonlatino       male           True
# 263057            black  nonlatino       male           True
# 263060            white  nonlatino       male           True
# 179121            black  nonlatino     female          False
# 177085            white     latino       male          False
# 247138            white  nonlatino       male          False
# 174027            white     latino       male          False
# 177627            white     latino     female          False
# 179760            white  nonlatino       male          False
# 178178            white     latino  transmtof          False
# 260451            white     latino       male          False
# 186262            white     latino       male          False
# 181845            white     latino       male          False
# 263436            black  nonlatino       male           True
# 263438            black  nonlatino       male           True
# 263440            white  nonlatino       male           True
# 263442            white  nonlatino       male           True
# 263435            black  nonlatino       male           True
# 263422            white  nonlatino       male           True
# 263531            white     latino       male          False
# 263513            white     latino       male          False
# 263528            white     latino       male          False
# 263528            white     latino       male          False
# 263523            white     latino       male          False
# 263514            white     latino     female          False
# 263529            white  nonlatino     female           True
# 263527            white     latino     female          False
# 263512            white  nonlatino     female          False
# 263526            white     latino     female          False
# 263527            white     latino     female          False
# 263520            white     latino       male           True
# 263517            white  nonlatino       male           True
# 263526            white     latino     female          False
# 263522            white     latino     female          False
# 263523            white     latino       male          False
# 263511            white     latino       male           True
# 263522            white     latino     female          False
# 271289            white     latino     female          False
# 263925            black  nonlatino       male           True
# 263929            black     latino       male          False
# 245932            asian  nonlatino       male           True
# 263915            white  nonlatino       male           True
# 263927            white     latino     female          False
# 264809            white  nonlatino     female          False
# 263928            black     latino     female          False
# 264077            black  nonlatino     female          False
# 245179            white  nonlatino       male          False
# 264052       amerindian  nonlatino       male           True
# 264075            black  nonlatino       male           True
# 264080            white     latino       male           True
# 264266            white     latino     female          False
# 264265            white  nonlatino     female          False
# 264262            white  nonlatino       male           True
# 264260            white  nonlatino       male           True
# 276434            white  nonlatino     female          False
# 271059            white  nonlatino       male          False
# 264394            white  nonlatino       male          False
# 264393            white  nonlatino       male          False
# 244339            black  nonlatino       male          False
# 264391            white  nonlatino       male           True
# 252587            white  nonlatino       male           True
# 264402            white  nonlatino       male           True
# 264400            black  nonlatino     female           True
# 264399            black  nonlatino     female          False
# 264398            black  nonlatino       male           True
# 264392            white  nonlatino       male           True
# 264417            black  nonlatino     female           True
# 264420            black  nonlatino     female          False
# 264421            black  nonlatino     female          False
# 264452            white  nonlatino       male           True
# 264457            white  nonlatino     female          False
# 264458            white  nonlatino       male          False
# 258264            white     latino       male          False
# 258264            white     latino       male          False
# 271060       pacificisl  nonlatino       male          False
# 264666            white  nonlatino     female          False
# 264664            white  nonlatino       male           True
# 264745            white  nonlatino       male           True
# 264746            white     latino     female          False
# 264747            white     latino       male          False
# 264748            white     latino       male          False
# 264750            white     latino       male          False
# 254487            white     latino       male           True
# 264765            white     latino       male          False
# 264828            asian  nonlatino       male           True
# 264825            white     latino       male          False
# 264824            white     latino     female          False
# 264823            white     latino       male           True
# 264819            white     latino       male           True
# 264778            white  nonlatino       male           True
# ...                 ...        ...        ...            ...
# 271337            black  nonlatino       male          False
# 258747            white     latino       male          False
# 186093            white  nonlatino     female          False
# 265716            white     latino       male           True
# 265720            white     latino       male          False
# 265719            white  nonlatino     female          False
# 276600            white  nonlatino       male          False
# 253295            white  nonlatino       male          False
# 258405            black  nonlatino       male           True
# 263927            white     latino     female          False
# 263928            black     latino     female          False
# 264452            white  nonlatino       male           True
# 264457            white  nonlatino     female          False
# 264458            white  nonlatino       male          False
# 267981       amerindian     latino       male           True
# 263929            black     latino       male          False
# 263925            black  nonlatino       male           True
# 264797            black  nonlatino     female          False
# 250489            white     latino       male          False
# 252783            asian  nonlatino       male          False
# 249901            white  nonlatino       male          False
# 276809            asian  nonlatino     female           True
# 276768            white  nonlatino       male          False
# 252868            white  nonlatino       male          False
# 276774            white     latino       male          False
# 263436            black  nonlatino       male           True
# 276781            white  nonlatino     female          False
# 276986            white  nonlatino     female          False
# 275454            black  nonlatino       male          False
# 251307            white  nonlatino       male          False
# 277001            white     latino       male           True
# 253711            white     latino       male          False
# 268811            white  nonlatino     female          False
# 244248            black  nonlatino       male          False
# 249980            asian  nonlatino       male          False
# 247444            white  nonlatino       male          False
# 181139            white  nonlatino     female          False
# 270254            white  nonlatino       male           True
# 256028            white  nonlatino     female          False
# 251334            white  nonlatino       male          False
# 260740            black  nonlatino       male           True
# 180891            white     latino       male          False
# 180887            black  nonlatino       male          False
# 253025            white     latino       male          False
# 244339            black  nonlatino       male          False
# 186678            white     latino     female          False
# 265851            white  nonlatino       male           True
# 269643            white  nonlatino     female          False
# 219192            white     latino       male          False
# 179778            white     latino  transmtof          False
# 186262            white     latino       male          False
# 179754            asian  nonlatino       male          False
# 254095            white  nonlatino       male           True
# 177085            white     latino       male          False
# 174295            white     latino       male          False
# 174294            white     latino     female          False
# 174020            white     latino       male          False
# 174027            white     latino       male          False
# 271242            white     latino       male          False
# 277013            white  nonlatino     female          False
# 237418            white     latino       male          False
# 180323            white     latino       male          False
# 178607            white     latino       male          False
# 178604            white     latino     female          False
# 174064            black  nonlatino       male          False
# 236331       pacificisl     latino     female          False
# 236332            white     latino     female          False
# 276932            white     latino     female          False
# 178606            white     latino       male          False
# 252978            black  nonlatino       male          False
# 253711            white     latino       male          False
# 251334            white  nonlatino       male          False
# 276667            white  nonlatino       male          False
# 271341            white     latino     female           True
# 184191            asian     latino       male          False
# 270286            white     latino       male          False
# 255445       pacificisl  nonlatino       male          False
# 257018       pacificisl  nonlatino       male           True
# 277002            white  nonlatino     female          False
# 179829            white     latino       male          False
# 180337            white     latino       male          False
# 249560            black  nonlatino       male          False
# 252687            white  nonlatino       male          False
# 270286            white     latino       male          False
# 270287            white  nonlatino       male          False
# 277114            white     latino     female          False
# 178660            black  nonlatino       male          False
# 252783            asian  nonlatino       male          False
# 277114            white     latino     female          False
# 277386            white  nonlatino     female          False
# 253890            black  nonlatino       male          False
# 186678            white     latino     female          False
# 276766            white  nonlatino       male          False
# 241914            white  nonlatino       male          False
# 178677       pacificisl  nonlatino       male          False
# 189268            black  nonlatino       male          False
# 189288            white  nonlatino     female          False
# 270891            white  nonlatino       male           True
# 177481            white     latino     female          False
# 177480            white     latino       male          False
# 177479            white     latino       male          False
# 270907            black  nonlatino       male           True
# 270906            white  nonlatino     female          False
# 270899            black  nonlatino       male           True
# 270893            white  nonlatino     female           True
# 265301            white  nonlatino       male           True
# 177457            white     latino     female          False
# 237419            white     latino     female          False
# 260450            white     latino       male          False
# 237418            white     latino       male          False
# 182257            black  nonlatino     female          False
# 182258            white     latino     female          False
# 270973            white  nonlatino       male           True
# 277166            white  nonlatino     female          False
# 277386            white  nonlatino     female          False
# 260450            white     latino       male          False
# 262513            white     latino       male           True
# 180931            white     latino     female          False
# 217637            white     latino     female          False
# 217653            white     latino       male          False
# 217652            white     latino       male          False
# 174647            white     latino     female          False
# 174644            white     latino     female          False
# 174646            white     latino     female          False
# 180930            white     latino       male          False
# 174648            white     latino       male          False
# 180929            white     latino       male          False
# 253466            white  nonlatino     female          False
# 270136            white  nonlatino       male           True
# 259142            asian  nonlatino     female          False
# 260425       pacificisl  nonlatino       male           True
# 259142            asian  nonlatino     female          False
# 241914            white  nonlatino       male          False
# 174086            white     latino     female          False
# 229367            white     latino     female          False
# 229368            white     latino     female          False
# 229366            white     latino       male          False
# 229313            white     latino       male          False
# 255557            white  nonlatino       male          False
# 197629            white  nonlatino     female          False
# 255557            white  nonlatino       male          False
# 174292            black  nonlatino       male          False
# 174260            white  nonlatino       male          False
# 253973            white  nonlatino       male          False
# 271648            white  nonlatino       male          False
# 271671            white  nonlatino       male          False
# 181921            asian  nonlatino       male          False
# 181921            asian  nonlatino       male          False
# 180036            white     latino       male          False
# 174146            white     latino     female          False
# 272004            white  nonlatino       male          False
# 251764            black  nonlatino       male          False
# 254357            white  nonlatino       male          False
# 271188            white    unknown       male          False
# 179801            black  nonlatino       male          False
# 272004            white  nonlatino       male          False
# 272004            white  nonlatino       male          False
# 179074            white  nonlatino       male          False
# 180887            black  nonlatino       male          False
# 271546       pacificisl  nonlatino       male          False
# 272058            white  nonlatino       male          False
# 272174            white  nonlatino       male          False
# 185885            white     latino     female          False
# 185886            white     latino     female          False
# 185884            white     latino       male          False
# 185886            white     latino     female          False
# 185885            white     latino     female          False
# 185884            white     latino       male          False
# 261493            white  nonlatino       male          False
# 273017            black  nonlatino       male          False
# 261493            white  nonlatino       male          False
# 278158       pacificisl  nonlatino       male          False
# 273017            black  nonlatino       male          False
# 272379            white  nonlatino     female          False
# 272379            white  nonlatino     female          False
# 193898            white  nonlatino     female          False
# 193898            white  nonlatino     female          False
# 278187            white  nonlatino       male          False
# 257261       pacificisl  nonlatino     female           True
# 278043            white  nonlatino       male          False
# 242380            white     latino       male          False
# 272690            white  nonlatino       male           True
# 277735            white     latino       male          False
# 195945            white     latino       male          False
# 277809            white     latino       male          False
# 272942            white     latino     female          False
# 272943            white     latino       male          False
# 272941            white     latino       male           True
# 272944            white     latino       male          False
# 277647            white     latino       male          False
# 252095       pacificisl  nonlatino       male          False
# 193898            white  nonlatino     female          False
# 179760            white  nonlatino       male          False
# 247119            white     latino       male          False
# 277591            white  nonlatino       male          False
# 179074            white  nonlatino       male          False
# 277348            white  nonlatino       male          False
# 278054            white     latino       male          False
# 278188            white     latino     female          False
# 272945            white  nonlatino     female          False
# 258264            white     latino       male          False
# 274212            white     latino       male          False
# 274212            white     latino       male          False
# 184191            asian     latino       male          False
# 261492            white  nonlatino       male          False
# 257763            white  nonlatino       male          False
# 257475            white     latino       male          False
# 273012            white     latino       male          False
# 244384            black  nonlatino       male          False
# 244384            black  nonlatino       male          False
# 271187            white  nonlatino       male          False
# 277648            asian  nonlatino       male          False
# 173885            white     latino     female          False
# 261249            white     latino       male          False
# 248727            white  nonlatino       male          False
# 276443            white     latino       male          False
# 241895            white     latino       male          False
# 239007            white     latino       male          False
# 264392            white  nonlatino       male           True
# 253630            white     latino       male          False
# 274533            white  nonlatino       male           True
# 264393            white  nonlatino       male          False
# 264394            white  nonlatino       male          False
# 253630            white     latino       male          False
# 274545            white  nonlatino       male           True
# 259423            white  nonlatino       male          False
# 259423            white  nonlatino       male          False
# 273090            white  nonlatino  transmtof          False
# 271341            white     latino     female           True
# 251764            black  nonlatino       male          False
# 274902            black  nonlatino     female          False
# 274901            black  nonlatino       male           True
# 274893            white     latino       male           True
# 276329            white  nonlatino       male          False
# 257880            white     latino       male          False
# 237441            white  nonlatino       male          False
# 266904            black  nonlatino       male          False
# 178266            white     latino       male          False
# 180839            white  nonlatino       male          False
# 278174            black  nonlatino       male          False
# 272995       pacificisl  nonlatino       male          False
# 277217            white  nonlatino     female          False
emergencyshelter     Monterey
# 279961             emergencyshelter     Monterey
# 276974             emergencyshelter     Monterey
# 279913             emergencyshelter     Monterey
# 276597             emergencyshelter     Monterey
# 279952             emergencyshelter     Monterey
# 276597             emergencyshelter     Monterey
# 276472             emergencyshelter     Monterey
# 279961             emergencyshelter     Monterey
# 276597             emergencyshelter     Monterey
# 225356             emergencyshelter     Monterey
# 225356             emergencyshelter     Monterey
# 279952             emergencyshelter     Monterey
# 225356             emergencyshelter     Monterey
# 276597             emergencyshelter     Monterey
# 276472             emergencyshelter     Monterey
# 279961             emergencyshelter     Monterey
# 278967               streetoutreach     Monterey
# 279952             emergencyshelter     Monterey
# 279961             emergencyshelter     Monterey
# 279952             emergencyshelter     Monterey
# 279700       homelessnessprevention     Monterey
# 279699       homelessnessprevention     Monterey
# 279698       homelessnessprevention     Monterey
# 279695       homelessnessprevention     Monterey
# 279697       homelessnessprevention     Monterey
# 279952             emergencyshelter     Monterey
# 279913             emergencyshelter     Monterey
# 276975             emergencyshelter     Monterey
# 276468             emergencyshelter     Monterey
# 225356             emergencyshelter     Monterey
# 280676               streetoutreach     Monterey
#
# [1095 rows x 32 columns]

# %%
pd.value_counts(df_monterey['in_permanent_housing'].values, sort=False)
# Out:
# False    947
# True     148
# dtype: int64

# %%
# group by organization

# use selection of dataframe
df_monterey_organization = df_monterey[['project_name', 'in_permanent_housing']]
print ('number of records registered in Monterey:', len(df_monterey_organization))
print ('---')
# group by organization and count how many people are registered per organization
print (df_monterey_organization.groupby('project_name').size())
print ('---')
# group by organization and count how many people received in permanent housing 
df_monterey_organization_permhousing = df_monterey_organization[df_monterey_organization['in_permanent_housing']==True]
print ('number of records registered in Monterey and received permanent housing:', len(df_monterey_organization_permhousing))
print ('---')
print (df_monterey_organization_permhousing.groupby('project_name').size())
# Out:
# number of records registered in Monterey: 1095
# ---
# project_name
# MOSBE CHS - RHY - BCP - HP                                                89
# MOSBE CHS - RHY - BCP ES                                                   8
# MOSBE CHS - RHY SOP                                                      106
# MOSBE CHS - Safe Place Warming Shelter                                    64
# MOSBE Interim                                                              1
# MOSBE Interim - MCHOME Enrolled                                           91
# SCz-Veterans Resource Center - HP SSVF - Monterey/San Benito Clients     423
# SCz-Veterans Resource Center - RRH SSVF - Monterey/San Benito Clients     90
# zzz*inactive*MOSBE CCHAS (John XXIII) - Bus Passes                        38
# zzz*inactive*MOSBE CCHAS (John XXIII) - Food                              89
# zzz*inactive*MOSBE CCHAS (John XXIII) ADAP                                94
# zzz*inactive*MOSBE CCHAS (John XXIII) Other Rental Assistance              1
# zzz*inactive*MOSBE MC Behavioral Health - PATH Enrolled                    1
# dtype: int64
# ---
# number of records registered in Monterey and received permanent housing: 148
# ---
# project_name
# MOSBE CHS - RHY - BCP - HP                                                3
# MOSBE Interim - MCHOME Enrolled                                          18
# SCz-Veterans Resource Center - HP SSVF - Monterey/San Benito Clients     70
# SCz-Veterans Resource Center - RRH SSVF - Monterey/San Benito Clients    46
# zzz*inactive*MOSBE CCHAS (John XXIII) - Bus Passes                        1
# zzz*inactive*MOSBE CCHAS (John XXIII) - Food                              5
# zzz*inactive*MOSBE CCHAS (John XXIII) ADAP                                5
# dtype: int64
